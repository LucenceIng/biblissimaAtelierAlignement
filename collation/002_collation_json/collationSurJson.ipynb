# %%
#importer collatex
from collatex import *
#importer json
import json

# %%
#on crée le json 
json_input = """{
  "witnesses" : [
    {
      "id" : "A",
      "content" : "Mais au povre home doit l’en doner tex choses qui soient plus boenes que beles"
    },
    {
      "id" : "B",
      "content" : "mais aux povres hommes doit on telles choses donner qui soient plus bonnes que belles"
    },
    {
      "id" : "C",
      "content" : "Mais au povre home doit l’en douner tex choses qui soient plus boines que beles"
    }
  ]
}"""
#on le charge en tant que json
doc = json.loads(json_input)

# %%
#vérification
doc

# %%
#collation
print(collate(doc))

# %%
#collation avec segmentation
print(collate(doc,segmentation=False))

# %%
import json
#deuxième import : mot à mot
#+ dans les n, les formes normalisées, se trouvent les lemmes
json_input2 = """{
    "witnesses": [
        {
            "id": "A",
            "tokens": [
                {
                    "t": "Mais",
                    "n": "mais1"
                },
                {
                    "t": "au",
                    "n": "a3+le"
                },
                {
                    "t": "povre",
                    "n": "povre"
                },
                {
                    "t": "home",
                    "n": "ome"
                },
                {
                    "t": "doit",
                    "n": "devoir"
                },
                {
                    "t": "l'",
                    "n": "le"
                },
                {
                    "t": "en",
                    "n": "on"
                },
                {
                    "t": "doner",
                    "n": "doner"
                },
                {
                    "t": "tex",
                    "n": "tel"
                },
                {
                    "t": "choses",
                    "n": "chose"
                },
                {
                    "t": "qui",
                    "n": "qui"
                },
                {
                    "t": "soient",
                    "n": "estre1"
                },
                {
                    "t": "plus",
                    "n": "plus"
                },
                {
                    "t": "boenes",
                    "n": "bon"
                },
                {
                    "t": "que",
                    "n": "que1"
                },
                {
                    "t": "beles",
                    "n": "bel"
                }
            ]
        },
        {
            "id": "B",
           "tokens": [
  
                {
                    "t": "mais ",
                    "n": "mais1"
                },
                {
                    "t": "aux",
                    "n": "a3+le"
                },
                {
                    "t": "povres",
                    "n": "povre"
                },
                {
                    "t": "hommes",
                    "n": "ome"
                },
                {
                    "t": "doit",
                    "n": "devoir"
                },
                {
                    "t": "on",
                    "n": "on"
                },
                {
                    "t": "telles",
                    "n": "tel"
                },
                {
                    "t": "choses",
                    "n": "chose"
                },
                {
                    "t": "donner",
                    "n": "doner"
                },
                
                {
                    "t": "qui",
                    "n": "qui"
                },
                {
                    "t": "soient",
                    "n": "estre1"
                },
                {
                    "t": "plus",
                    "n": "plus"
                },
                {
                    "t": "bonnes",
                    "n": "bon"
                },
                {
                    "t": "que",
                    "n": "que1"
                },
                {
                    "t": "belles",
                    "n": "bel"
                }
            ]
        },
        {
            "id": "C",
            "tokens": [
                {
                    "t": "Mais ",
                    "n": "mais1"
                },
                {
                    "t": "au",
                    "n": "a3+le"
                },
                {
                    "t": "povre",
                    "n": "povre"
                },
                {
                    "t": "home",
                    "n": "ome"
                },
                {
                    "t": "doit",
                    "n": "devoir"
                },
                {
                    "t": "l'",
                    "n": "le"
                },
                {
                    "t": "en",
                    "n": "on"
                },
                {
                    "t": "douner",
                    "n": "doner"
                },
                {
                    "t": "tex",
                    "n": "tel"
                },
                {
                    "t": "choses",
                    "n": "chose"
                },
                {
                    "t": "qui",
                    "n": "qui"
                },
                {
                    "t": "soient",
                    "n": "estre1"
                },
                {
                    "t": "plus",
                    "n": "plus"
                },
                {
                    "t": "boines",
                    "n": "bon"
                },
                {
                    "t": "que",
                    "n": "que1"
                },
                {
                    "t": "beles",
                    "n": "bel"
                }
            ]
        }
    ]
}"""

json2 = json.loads(json_input2)

# %%
collate(json2, output="html2", segmentation=False)

# %%
# collation et sortie en graphe
# on voit les témoins, les formes n et les formes graphiques
# collate(json2,output="svg")
#sortie en graphe simplifié
# ne donne que la valeur de n
# collate(json2,output="svg_simple")
#sortie en graphe simplifié avec une segmentation sur les mots
#collate(json2,output="svg_simple",segmentation=False)
#coll = collate(json2,output="svg_simple",segmentation=False)

# %%
#la lemmatisation contre les problèmes d'alignement

import json
#troisième import : mot à mot, avec l'ajout de l'adverbe très
json_input3 = """{
    "witnesses": [
        {
            "id": "A",
            "tokens": [

                {
                    "t": "qui",
                    "n": "qui"
                },
                {
                    "t": "soient",
                    "n": "estre1"
                },
                {
                    "t": "plus",
                    "n": "plus"
                },
                {
                    "t": "boenes",
                    "n": "bon"
                },
                {
                    "t": "que",
                    "n": "que1"
                },
                {
                    "t": "beles",
                    "n": "bel"
                }
                
            ]
        },
        {
            "id": "B",
           "tokens": [
                
                {
                    "t": "qui",
                    "n": "qui"
                },
                {
                    "t": "soient",
                    "n": "estre1"
                },
                {
                    "t": "plus",
                    "n": "plus"
                },
                
                {
                    "t": "bonnes",
                    "n": "bon"
                },
                {
                    "t": "que",
                    "n": "que1"
                },
                {
                    "t": "tres",
                    "n": "très"
                },
                {
                    "t": "belles",
                    "n": "bel"
                }
            ]
        },
        {
            "id": "C",
                  "tokens" :  [
                  {
                    "t": "qui",
                    "n": "qui"
                },
                {
                    "t": "soient",
                    "n": "estre1"
                },
                {
                    "t": "plus",
                    "n": "plus"
                },
                {
                    "t": "boines",
                    "n": "bon"
                },
                {
                    "t": "que",
                    "n": "que1"
                },
                {
                    "t": "beles",
                    "n": "bel"
                }
            ]
        }
    ]
}"""

json3 = json.loads(json_input3)

# %%
#collation et ouput sous forme de table html2, rend la forme t mais prend en considération l'égalité des formes (n)
collate(json3,output="html2",segmentation=False)

# %%
#collation et output XML, rend la forme t aussi
collate(json3,output="xml",segmentation=False)

# %%
import json
#quatrième import : l'alignement qui ne marchait pas tout à l'heure
json_input4 = """{
    "witnesses": [
        {
            "id": "A",
            "tokens": [
                {
                    "t": "Mais ",
                    "n": "mais1"
                },
                {
                    "t": "au",
                    "n": "a3+le"
                },
                {
                    "t": "povre",
                    "n": "povre"
                },
                {
                    "t": "home",
                    "n": "ome"
                },
                {
                    "t": "doit",
                    "n": "devoir"
                },
                {
                    "t": "l'",
                    "n": "le"
                },
                {
                    "t": "en",
                    "n": "on"
                },
                {
                    "t": "doner",
                    "n": "doner"
                },
                {
                    "t": "tex",
                    "n": "tel"
                },
                {
                    "t": "choses",
                    "n": "chose"
                },
                {
                    "t": "qui",
                    "n": "qui"
                },
                {
                    "t": "soient",
                    "n": "estre1"
                },
                {
                    "t": "plus",
                    "n": "plus"
                },
                {
                    "t": "boenes",
                    "n": "bon"
                },
                {
                    "t": "que",
                    "n": "que1"
                },
                {
                    "t": "beles",
                    "n": "bel"
                },
                  {
                    "t": "et",
                    "n": "et"
                },
                  {
                    "t": "plus",
                    "n": "plus"
                },
                  {
                    "t": "porfitables",
                    "n": "porfitable"
                },
                  {
                    "t": "que",
                    "n": "que1"
                },
                  {
                    "t": "plaisanz",
                    "n": "plaisant"
                }
            ]
        },
        {
            "id": "B",
           "tokens": [
  
                {
                    "t": "mais ",
                    "n": "mais1"
                },
                {
                    "t": "aux",
                    "n": "a3+le"
                },
                {
                    "t": "povres",
                    "n": "povre"
                },
                {
                    "t": "hommes",
                    "n": "ome"
                },
                {
                    "t": "doit",
                    "n": "devoir"
                },
                {
                    "t": "on",
                    "n": "on"
                },
                {
                    "t": "telles",
                    "n": "tel"
                },
                {
                    "t": "choses",
                    "n": "chose"
                },
                {
                    "t": "donner",
                    "n": "doner"
                },
                
                {
                    "t": "qui",
                    "n": "qui"
                },
                {
                    "t": "soient",
                    "n": "estre1"
                },
                {
                    "t": "plus",
                    "n": "plus"
                },
                {
                    "t": "bonnes",
                    "n": "bon"
                },
                {
                    "t": "que",
                    "n": "que1"
                },
                {
                    "t": "belles",
                    "n": "bel"
                }
            ]
        },
        {
            "id": "C",
            "tokens": [
                {
                    "t": "Mais ",
                    "n": "mais1"
                },
                {
                    "t": "au",
                    "n": "a3+le"
                },
                {
                    "t": "povre",
                    "n": "povre"
                },
                {
                    "t": "home",
                    "n": "ome"
                },
                {
                    "t": "doit",
                    "n": "devoir"
                },
                {
                    "t": "l'",
                    "n": "le"
                },
                {
                    "t": "en",
                    "n": "on"
                },
                {
                    "t": "douner",
                    "n": "doner"
                },
                {
                    "t": "tex",
                    "n": "tel"
                },
                {
                    "t": "choses",
                    "n": "chose"
                },
                {
                    "t": "qui",
                    "n": "qui"
                },
                {
                    "t": "soient",
                    "n": "estre1"
                },
                {
                    "t": "plus",
                    "n": "plus"
                },
                {
                    "t": "boines",
                    "n": "bon"
                },
                {
                    "t": "que",
                    "n": "que1"
                },
                {
                    "t": "beles",
                    "n": "bel"
                },
                {
                    "t": "et",
                    "n": "et"
                },
                {
                    "t": "plus",
                    "n": "plus"
                },
                {
                    "t": "profitables",
                    "n": "porfitable"
                },
                {
                    "t": "que",
                    "n": "que1"
                },
                {
                    "t": "plaisans",
                    "n": "plaisant"
                }
            ]
        }
    ]
}"""

json4 = json.loads(json_input4)

# %%
collate(json4,output='html2',segmentation=False)
