# %%
#import des librairies
from lxml import etree
import collections
from xml.etree import ElementTree as et
import os
import numpy as np
import requests
import json
from collatex import *

# %%
A1 =  etree.XML('''
<TEI xmlns="http://www.tei-c.org/ns/1.0">
    <teiHeader>
        <fileDesc>
            <titleStmt>
                <title></title>
            </titleStmt>
            <publicationStmt><p></p></publicationStmt>
            <sourceDesc><p></p></sourceDesc>
        </fileDesc>
        
    </teiHeader>
    <text xml:lang="fr">
        <body xml:lang="fro">
            <div>
                <ab>
                
                        <w xml:id="t1" n="1" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t2" n="2" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t3" n="3" lemma="qui" pos="PROrel" >qui</w>
                        <w xml:id="t4" n="4" lemma="avoir" pos="VERcjg" >avoit</w>
                        <w xml:id="t5" n="5" lemma="laissier" pos="VERppe" >laisse</w>
                        <w xml:id="t6" n="6" lemma="chëoir" pos="VERinf" >cheoir</w>
                        <w xml:id="t7" n="7" lemma="son4" pos="DETpos" >son</w>
                        <w xml:id="t8" n="8" lemma="glaive" pos="NOMcom" >glaive</w>
                        <w xml:id="t9" n="9" lemma="revenir" pos="VERcjg" >revient</w>
                        <w xml:id="t10" n="10" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t11" n="11" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t12" n="12" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t13" n="13" lemma="il" pos="PROper" >le</w>
                        <w xml:id="t14" n="14" lemma="prendre" pos="VERcjg" >prent</w>
                        <w xml:id="t15" n="15" lemma="par" pos="PRE" >par</w>
                        <w xml:id="t16" n="16" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t17" n="17" lemma="heaume" pos="NOMcom" >heaume</w>
                        <w xml:id="t18" n="18" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t19" n="19" lemma="il" pos="PROper" >le</w>
                        <w xml:id="t20" n="20" lemma="tirer" pos="VERcjg" >tire</w>
                        <w xml:id="t21" n="21" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t22" n="22" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t23" n="23" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t24" n="24" lemma="robement" pos="ADVgen" >rudement</w>
                        <w xml:id="t25" n="25" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t26" n="26" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t27" n="27" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t28" n="28" lemma="arrachier" pos="VERcjg" >arrache</w>
                        <w xml:id="t29" n="29" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t30" n="30" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t31" n="31" lemma="teste" pos="NOMcom" >teste</w>
                        <w xml:id="t32" n="32" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t33" n="33" lemma="felonessement" pos="ADVgen" >fellonneusement</w>
                        <w xml:id="t34" n="34" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t35" n="35" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t36" n="36" lemma="il" pos="PROper" >le</w>
                        <w xml:id="t37" n="37" lemma="faire" pos="VERcjg" >fait</w>
                        <w xml:id="t38" n="38" lemma="tomber" pos="VERinf" >tumber</w>
                        <w xml:id="t39" n="39" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t40" n="40" lemma="visage" pos="NOMcom" >visage</w>
                        <w xml:id="t41" n="41" lemma="contre" pos="PRE" >contre</w>
                        <w xml:id="t42" n="42" lemma="terre" pos="NOMcom" >terre</w>
                        <w xml:id="t43" n="43" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t44" n="44" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t45" n="45" lemma="par" pos="PRE" >par</w>
                        <w xml:id="t46" n="46" lemma="un" pos="DETdem" >ung</w>
                        <w xml:id="t47" n="47" lemma="poi" pos="NOMcom" >peu</w>
                        <w xml:id="t48" n="48" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t49" n="49" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t50" n="50" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t51" n="51" lemma="avoir" pos="VERcjg" >a</w>
                        <w xml:id="t52" n="52" lemma="le" pos="DETdef" >les</w>
                        <w xml:id="t53" n="53" lemma="dent2" pos="NOMcom" >dens</w>
                        <w xml:id="t54" n="54" lemma="tot" pos="DETind" >toutes</w>
                        <w xml:id="t55" n="55" lemma="brisier" pos="VERppe" >brisees</w>
                        <w xml:id="t56" n="56" lemma="en1" pos="PRE" >en</w>
                        <w xml:id="t57" n="57" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t58" n="58" lemma="boche" pos="NOMcom" >bouche</w>
                        <w xml:id="t59" n="59" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t60" n="60" lemma="tot" pos="DETind" >tout</w>
                        <w xml:id="t61" n="61" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t62" n="62" lemma="nef2" pos="NOMcom" >nez</w>
                        <w xml:id="t63" n="63" lemma="escorchier" pos="VERppe" >escorchie</w>
                        <w xml:id="t64" n="64" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t65" n="65" lemma="seignier" pos="VERcjg" >saigne</w>
                        <w xml:id="t66" n="66" lemma="mout" pos="ADVgen" >moult</w>
                        <w xml:id="t67" n="67" lemma="fort" pos="ADJqua" >fort</w>
                        <w xml:id="t68" n="68" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t69" n="69" lemma="descendre" pos="VERcjg" >descendroit</w>
                        <w xml:id="t70" n="70" lemma="volentiers" pos="ADVgen" >voulentiers</w>
                        <w xml:id="t71" n="71" lemma="mais1" pos="CONcoo" >mais</w>
                        <w xml:id="t72" n="72" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t73" n="73" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t74" n="74" lemma="doter2" pos="VERcjg" >doubte</w>
                        <w xml:id="t75" n="75" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t76" n="76" lemma="träison" pos="NOMcom" >trayson</w>
                        <w xml:id="t77" n="77" lemma="il" pos="PROper" >Il</w>
                        <w xml:id="t78" n="78" lemma="jeter" pos="VERcjg" >gecte</w>
                        <w xml:id="t79" n="79" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t80" n="80" lemma="heaume" pos="NOMcom" >heaume</w>
                        <w xml:id="t81" n="81" lemma="a3+le" pos="PRE.DETdef" >au</w>
                        <w xml:id="t82" n="82" lemma="loing" pos="NOMcom" >loingz</w>
                        <w xml:id="t83" n="83" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t84" n="84" lemma="metre2" pos="VERcjg" >met</w>
                        <w xml:id="t85" n="85" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t86" n="86" lemma="main2" pos="NOMcom" >main</w>
                        <w xml:id="t87" n="87" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t88" n="88" lemma="le" pos="DETdef" >l</w>
                        <w xml:id="t89" n="89" lemma="espee" pos="NOMcom" >espee</w>
                        <w xml:id="t90" n="90" lemma="puis" pos="ADVgen" >puis</w>
                        <w xml:id="t91" n="91" lemma="venir" pos="VERcjg" >vient</w>
                        <w xml:id="t92" n="92" lemma="a3+le" pos="PRE.DETdef" >au</w>
                        <w xml:id="t93" n="93" lemma="chevalier" pos="NOMcom" >chevalier</w>
                        <w xml:id="t94" n="94" lemma="qui" pos="PROrel" >qui</w>
                        <w xml:id="t95" n="95" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t96" n="96" lemma="relever" pos="VERcjg" >relevoit</w>
                        <w xml:id="t97" n="97" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t98" n="98" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t99" n="99" lemma="doner" pos="VERcjg" >donne</w>
                        <w xml:id="t100" n="100" lemma="de+le" pos="PRE.DETdef" >du</w>
                        <w xml:id="t101" n="101" lemma="plat" pos="NOMcom" >plat</w>
                        <w xml:id="t102" n="102" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t103" n="103" lemma="le" pos="DETdef" >l</w>
                        <w xml:id="t104" n="104" lemma="espee" pos="NOMcom" >espee</w>
                        <w xml:id="t105" n="105" lemma="par" pos="PRE" >par</w>
                        <w xml:id="t106" n="106" lemma="deus" pos="DETcar" >deux</w>
                        <w xml:id="t107" n="107" lemma="foiz" pos="NOMcom" >fois</w>
                        <w xml:id="t108" n="108" lemma="tant" pos="ADVgen" >tant</w>
                        <w xml:id="t109" n="109" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t110" n="110" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t111" n="111" lemma="il" pos="PROper" >l</w>
                        <w xml:id="t112" n="112" lemma="abatre" pos="VERcjg" >abat</w>
                        <w xml:id="t113" n="113" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t114" n="114" lemma="terre" pos="NOMcom" >terre</w>
                        <w xml:id="t115" n="115" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t116" n="116" lemma="saignier" pos="VERcjg" >saigne</w>
                        <w xml:id="t117" n="117" lemma="aussi" pos="ADVgen" >aussi</w>
                        <w xml:id="t118" n="118" lemma="fort" pos="ADVgen" >fort</w>
                        <w xml:id="t119" n="119" lemma="come1" pos="CONsub" >comme</w>
                        <w xml:id="t120" n="120" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t121" n="121" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t122" n="122" lemma="estre1" pos="VERcjg" >estoit</w>
                        <w xml:id="t123" n="123" lemma="navrer" pos="VERppe" >navre</w>
                        <w xml:id="t124" n="124" lemma="avoir" pos="PRE" >a</w>
                        <w xml:id="t125" n="125" lemma="morir" pos="NOMcom" >mort</w>
                        <w xml:id="t126" n="126" lemma="Hector" pos="NOMpro" >Hector</w>
                        <w xml:id="t127" n="127" lemma="torner" pos="VERcjg" >tourne</w>
                        <w xml:id="t128" n="128" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t129" n="129" lemma="dos" pos="NOMcom" >dos</w>
                        <w xml:id="t130" n="130" lemma="vers2" pos="PRE" >vers</w>
                        <w xml:id="t131" n="131" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t132" n="132" lemma="poncel1" pos="NOMcom" >poncel</w>
                        <w xml:id="t133" n="133" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t134" n="134" lemma="soi1" pos="PROper" >s</w>
                        <w xml:id="t135" n="135" lemma="arester" pos="VERcjg" >arreste</w>
                        <w xml:id="t136" n="136" lemma="sor2" pos="PRE" >sur</w>
                        <w xml:id="t137" n="137" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t138" n="138" lemma="poncel1" pos="NOMcom" >poncel</w>
                        <w xml:id="t139" n="139" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t140" n="140" lemma="jurer" pos="VERcjg" >jure</w>
                        <w xml:id="t141" n="141" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t142" n="142" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t143" n="143" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t144" n="144" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t145" n="145" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t146" n="146" lemma="tenir1" pos="VERcjg" >tient</w>
                        <w xml:id="t147" n="147" lemma="por2" pos="PRE" >pour</w>
                        <w xml:id="t148" n="148" lemma="veintre" pos="VERppe" >vaincu</w>
                        <w xml:id="t149" n="149" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t150" n="150" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t151" n="151" lemma="coper" pos="VERcjg" >coupera</w>
                        <w xml:id="t152" n="152" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t153" n="153" lemma="teste" pos="NOMcom" >teste</w>
                        <w xml:id="t154" n="154" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t155" n="155" lemma="cel" pos="PROdem" >celui</w>
                        <w xml:id="t156" n="156" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t157" n="157" lemma="pöoir" pos="VERcjg" >peut</w>
                        <w xml:id="t158" n="158" lemma="mot" pos="NOMcom" >mot</w>
                        <w xml:id="t159" n="159" lemma="dire" pos="VERinf" >dire</w>
                        <w xml:id="t160" n="160" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t161" n="161" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t162" n="162" lemma="estre1" pos="VERcjg" >estoit</w>
                        <w xml:id="t163" n="163" lemma="en1" pos="PRE" >en</w>
                        <w xml:id="t164" n="164" lemma="pasmaison" pos="NOMcom" >pasmoison</w>
                        <w xml:id="t165" n="165" lemma="lors" pos="ADVgen" >Lors</w>
                        <w xml:id="t166" n="166" lemma="descendre" pos="VERcjg" >desceut</w>
                        <w xml:id="t167" n="167" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t168" n="168" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t169" n="169" lemma="terre" pos="NOMcom" >terre</w>
                        <w xml:id="t170" n="170" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t171" n="171" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t172" n="172" lemma="abatre" pos="VERcjg" >abat</w>
                        <w xml:id="t173" n="173" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t174" n="174" lemma="ventaille1" pos="NOMcom" >ventaille</w>
                        <w xml:id="t175" n="175" lemma="jusque" pos="PRE" >jusques</w>
                        <w xml:id="t176" n="176" lemma="sor2" pos="PRE" >sur</w>
                        <w xml:id="t177" n="177" lemma="le" pos="DETdef" >les</w>
                        <w xml:id="t178" n="178" lemma="espaule" pos="NOMcom" >espaulles</w>
                        <w xml:id="t179" n="179" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t180" n="180" lemma="faire" pos="VERcjg" >fait</w>
                        <w xml:id="t181" n="181" lemma="semblant" pos="NOMcom" >semblant</w>
                        <w xml:id="t182" n="182" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t183" n="183" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t184" n="184" lemma="voloir" pos="VERinf" >vouloir</w>
                        <w xml:id="t185" n="185" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t186" n="186" lemma="teste" pos="NOMcom" >teste</w>
                        <w xml:id="t187" n="187" lemma="coper" pos="VERinf" >coupper</w>
                        <w xml:id="t188" n="188" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t189" n="189" lemma="Marganor" pos="NOMpro" >marganor</w>
                        <w xml:id="t190" n="190" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t191" n="191" lemma="acorre" pos="VERppe" >acouru</w>
                        <w xml:id="t192" n="192" lemma="hastivement" pos="ADVgen" >hastivement</w>
                        <w xml:id="t193" n="193" lemma="sans" pos="PRE" >sans</w>
                        <w xml:id="t194" n="194" lemma="heaume" pos="NOMcom" >heaume</w>
                        <w xml:id="t195" n="195" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t196" n="196" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t197" n="197" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t198" n="198" lemma="voloir" pos="VERcjg" >vouloit</w>
                        <w xml:id="t199" n="199" lemma="pas" pos="ADVneg" >pas</w>
                        <w xml:id="t200" n="200" lemma="venir" pos="VERinf" >venir</w>
                        <w xml:id="t201" n="201" lemma="ame" pos="NOMcom" >arme</w>
                        <w xml:id="t202" n="202" lemma="afin" pos="ADVgen" >affin</w>
                        <w xml:id="t203" n="203" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t204" n="204" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t205" n="205" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t206" n="206" lemma="i2" pos="PROadv" >y</w>
                        <w xml:id="t207" n="207" lemma="penser" pos="VERcjg" >pensast</w>
                        <w xml:id="t208" n="208" lemma="träison" pos="NOMcom" >trayson</w>
                        <w xml:id="t209" n="209" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t210" n="210" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t211" n="211" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t212" n="212" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t213" n="213" lemma="assez" pos="ADVgen" >assez</w>
                        <w xml:id="t214" n="214" lemma="en2" pos="PROadv" >en</w>
                        <w xml:id="t215" n="215" lemma="avoir" pos="VERcjg" >a</w>
                        <w xml:id="t216" n="216" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t217" n="217" lemma="mais1" pos="CONcoo" >Mais</w>
                        <w xml:id="t218" n="218" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t219" n="219" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t220" n="220" lemma="il" pos="PROper" >l</w>
                        <w xml:id="t221" n="221" lemma="atendre" pos="VERcjg" >atent</w>
                        <w xml:id="t222" n="222" lemma="pas" pos="ADVneg" >pas</w>
                        <w xml:id="t223" n="223" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t224" n="224" lemma="pié" pos="NOMcom" >pie</w>
                        <w xml:id="t225" n="225" lemma="ainz" pos="ADVgen" >ains</w>
                        <w xml:id="t226" n="226" lemma="monte" pos="VERppe" >monte</w>
                        <w xml:id="t227" n="227" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t228" n="228" lemma="cheval" pos="NOMcom" >cheval</w>
                        <w xml:id="t229" n="229" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t230" n="230" lemma="Marganor" pos="NOMpro" >marganor</w>
                        <w xml:id="t231" n="231" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t232" n="232" lemma="crïer2" pos="VERcjg" >crie</w>
                        <w xml:id="t233" n="233" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t234" n="234" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t235" n="235" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t236" n="236" lemma="ocire" pos="VERcjg" >occie</w>
                        <w xml:id="t237" n="237" lemma="mie" pos="ADVneg" >mie</w>
                        <w xml:id="t238" n="238" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t239" n="239" lemma="chevalier" pos="NOMcom" >chevalier</w>
                        <w xml:id="t240" n="240" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t241" n="241" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t242" n="242" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t243" n="243" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t244" n="244" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t245" n="245" lemma="faire" pos="VERcjg" >fera</w>
                        <w xml:id="t246" n="246" lemma="se" pos="CONsub" >s</w>
                        <w xml:id="t247" n="247" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t248" n="248" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t249" n="249" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t250" n="250" lemma="tenir1" pos="VERcjg" >tient</w>
                        <w xml:id="t251" n="251" lemma="por2" pos="PRE" >pour</w>
                        <w xml:id="t252" n="252" lemma="outre1" pos="ADVgen" >oultre</w>
                        <w xml:id="t253" n="253" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t254" n="254" lemma="Marganor" pos="NOMpro" >marganor</w>
                        <w xml:id="t255" n="255" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t256" n="256" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t257" n="257" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t258" n="258" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t259" n="259" lemma="faire" pos="VERcjg" >fera</w>
                        <w xml:id="t260" n="260" lemma="tenir1" pos="VERinf" >tenir</w>
                        <w xml:id="t261" n="261" lemma="lors" pos="ADVgen" >Lors</w>
                        <w xml:id="t262" n="262" lemma="venir" pos="VERcjg" >vient</w>
                        <w xml:id="t263" n="263" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t264" n="264" lemma="chevalier" pos="NOMcom" >chevalier</w>
                        <w xml:id="t265" n="265" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t266" n="266" lemma="pasmaison" pos="NOMcom" >pasmoison</w>
                        <w xml:id="t267" n="267" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t268" n="268" lemma="salüer" pos="VERcjg" >saulta</w>
                        <w xml:id="t269" n="269" lemma="sus" pos="ADVgen" >sus</w>
                        <w xml:id="t270" n="270" lemma="le" pos="ADVgen" >la</w>
                        <w xml:id="t271" n="271" lemma="où" pos="PROrel" >ou</w>
                        <w xml:id="t272" n="272" lemma="Marganor" pos="NOMpro" >marganor</w>
                        <w xml:id="t273" n="273" lemma="parler" pos="VERcjg" >parloit</w>
                        <w xml:id="t274" n="274" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t275" n="275" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t276" n="276" lemma="puis" pos="ADVgen" >puis</w>
                        <w xml:id="t277" n="277" lemma="metre2" pos="VERcjg" >met</w>
                        <w xml:id="t278" n="278" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t279" n="279" lemma="main2" pos="NOMcom" >main</w>
                        <w xml:id="t280" n="280" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t281" n="281" lemma="le" pos="DETdef" >l</w>
                        <w xml:id="t282" n="282" lemma="espee" pos="NOMcom" >espee</w>
                        <w xml:id="t283" n="283" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t284" n="284" lemma="covrir" pos="VERcjg" >cueuvre</w>
                        <w xml:id="t285" n="285" lemma="son4" pos="DETpos" >sa</w>
                        <w xml:id="t286" n="286" lemma="teste" pos="NOMcom" >teste</w>
                        <w xml:id="t287" n="287" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t288" n="288" lemma="son4" pos="DETpos" >son</w>
                        <w xml:id="t289" n="289" lemma="escu" pos="NOMcom" >escu</w>
                        <w xml:id="t290" n="290" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t291" n="291" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t292" n="292" lemma="apareillier1" pos="VERcjg" >appareille</w>
                        <w xml:id="t293" n="293" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t294" n="294" lemma="soi1" pos="NOMcom" >soy</w>
                        <w xml:id="t295" n="295" lemma="defendre" pos="VERinf" >deffendre</w>
                        <w xml:id="t296" n="296" lemma="coment1" pos="ADVsub" >Comment</w>
                        <w xml:id="t297" n="297" lemma="faire" pos="VERcjg" >fait</w>
                        <w xml:id="t298" n="298" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t299" n="299" lemma="voloir" pos="VERppe" >voullez</w>
                        <w xml:id="t300" n="300" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t301" n="301" lemma="encore" pos="ADVgen" >encores</w>
                        <w xml:id="t302" n="302" lemma="combatre" pos="VERinf" >combatre</w>
                        <w xml:id="t303" n="303" lemma="veraiement" pos="ADVgen" >Vraiement</w>
                        <w xml:id="t304" n="304" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t305" n="305" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t306" n="306" lemma="öir" pos="NOMcom" >oy</w>
                        <w xml:id="t307" n="307" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t308" n="308" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t309" n="309" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t310" n="310" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t311" n="311" lemma="tot" pos="ADVgen" >tout</w>
                        <w xml:id="t312" n="312" lemma="fraindre" pos="VERppe" >fraiz</w>
                        <w xml:id="t313" n="313" lemma="a3" pos="PRE" >A</w>
                        <w xml:id="t314" n="314" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t315" n="315" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t316" n="316" lemma="Marganor" pos="NOMcom" >marganor</w>
                        <w xml:id="t317" n="317" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t318" n="318" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t319" n="319" lemma="combatre" pos="VERcjg" >combatrez</w>
                        <w xml:id="t320" n="320" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t321" n="321" lemma="plus" pos="ADVgen" >plus</w>
                        <w xml:id="t322" n="322" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t323" n="323" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t324" n="324" lemma="estre1" pos="VERcjg" >estes</w>
                        <w xml:id="t325" n="325" lemma="son4" pos="DETpos" >son</w>
                        <w xml:id="t326" n="326" lemma="prisonier" pos="NOMcom" >prisonnier</w>
                        <w xml:id="t327" n="327" lemma="en1" pos="PRE" >En</w>
                        <w xml:id="t328" n="328" lemma="verité" pos="NOMcom" >verite</w>
                        <w xml:id="t329" n="329" lemma="dire" pos="VERppe" >dit</w>
                        <w xml:id="t330" n="330" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t331" n="331" lemma="chevalier" pos="NOMcom" >chevalier</w>
                        <w xml:id="t332" n="332" lemma="son4" pos="DETpos" >son</w>
                        <w xml:id="t333" n="333" lemma="prisonier" pos="NOMcom" >prisonnier</w>
                        <w xml:id="t334" n="334" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t335" n="335" lemma="estre1" pos="VERcjg" >seray</w>
                        <w xml:id="t336" n="336" lemma="je" pos="PROper" >je</w>
                        <w xml:id="t337" n="337" lemma="ja" pos="ADVgen" >ja</w>
                        <w xml:id="t338" n="338" lemma="tant" pos="ADVgen" >tant</w>
                        <w xml:id="t339" n="339" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t340" n="340" lemma="je" pos="PROper" >je</w>
                        <w xml:id="t341" n="341" lemma="vivre1" pos="VERcjg" >vive</w>
                        <w xml:id="t342" n="342" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t343" n="343" lemma="que4" pos="PROrel" >que</w>
                        <w xml:id="t344" n="344" lemma="je" pos="PROper" >je</w>
                        <w xml:id="t345" n="345" lemma="je" pos="PROper" >me</w>
                        <w xml:id="t346" n="346" lemma="pöoir" pos="VERcjg" >puisse</w>
                        <w xml:id="t347" n="347" lemma="defendre" pos="VERinf" >deffendre</w>
                        <w xml:id="t348" n="348" lemma="se" pos="ADVgen" >Si</w>
                        <w xml:id="t349" n="349" lemma="estre1" pos="VERcjg" >serez</w>
                        <w xml:id="t350" n="350" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t351" n="351" lemma="Marganor" pos="NOMpro" >marganor</w>
                        <w xml:id="t352" n="352" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t353" n="353" lemma="je" pos="PROper" >je</w>
                        <w xml:id="t354" n="354" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t355" n="355" lemma="avoir" pos="VERcjg" >ay</w>
                        <w xml:id="t356" n="356" lemma="prometre" pos="VERppe" >promis</w>
                        <w xml:id="t357" n="357" lemma="puis" pos="ADVgen" >Puis</w>
                        <w xml:id="t358" n="358" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t359" n="359" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t360" n="360" lemma="il" pos="PROper" >le</w>
                        <w xml:id="t361" n="361" lemma="voloir" pos="VERcjg" >voullez</w>
                        <w xml:id="t362" n="362" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t363" n="363" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t364" n="364" lemma="chevalier" pos="NOMcom" >chevalier</w>
                        <w xml:id="t365" n="365" lemma="ce1" pos="PROdem" >ce</w>
                        <w xml:id="t366" n="366" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t367" n="367" lemma="je" pos="PROper" >m</w>
                        <w xml:id="t368" n="368" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t369" n="369" lemma="pas" pos="ADVneg" >pas</w>
                        <w xml:id="t370" n="370" lemma="honte" pos="NOMcom" >honte</w>
                        <w xml:id="t371" n="371" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t372" n="372" lemma="vostre" pos="DETpos" >vostre</w>
                        <w xml:id="t373" n="373" lemma="volenté" pos="NOMcom" >voulente</w>
                        <w xml:id="t374" n="374" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t375" n="375" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t376" n="376" lemma="estre1" pos="VERcjg" >estes</w>
                        <w xml:id="t377" n="377" lemma="mon1" pos="DETpos" >mon</w>
                        <w xml:id="t378" n="378" lemma="seignor" pos="NOMcom" >sire</w>
                        <w xml:id="t379" n="379" lemma="lige" pos="ADJqua" >lige</w>
                        <w xml:id="t380" n="380" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t381" n="381" lemma="Marganor" pos="NOMpro" >marganor</w>
                        <w xml:id="t382" n="382" lemma="dire" pos="VERppe" >dit</w>
                        <w xml:id="t383" n="383" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t384" n="384" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t385" n="385" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t386" n="386" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t387" n="387" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t388" n="388" lemma="estre1" pos="VERcjg" >soit</w>
                        <w xml:id="t389" n="389" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t390" n="390" lemma="hardi" pos="ADJqua" >hardy</w>
                        <w xml:id="t391" n="391" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t392" n="392" lemma="demorer" pos="VERinf" >demourer</w>
                        <w xml:id="t393" n="393" lemma="a3+le" pos="PRE.DETdef" >au</w>
                        <w xml:id="t394" n="394" lemma="chastel" pos="NOMcom" >chasteau</w>
                        <w xml:id="t395" n="395" lemma="mais1" pos="CONcoo" >mais</w>
                        <w xml:id="t396" n="396" lemma="revenir" pos="ADJqua" >revienne</w>
                        <w xml:id="t397" n="397" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t398" n="398" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t399" n="399" lemma="por2" pos="PRE" >pour</w>
                        <w xml:id="t400" n="400" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t401" n="401" lemma="faire" pos="VERinf" >faire</w>
                        <w xml:id="t402" n="402" lemma="droit" pos="NOMcom" >droit</w>
                        <w xml:id="t403" n="403" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t404" n="404" lemma="ce1" pos="PROdem" >ce</w>
                        <w xml:id="t405" n="405" lemma="que2" pos="CONsub" >qu</w>
                        <w xml:id="t406" n="406" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t407" n="407" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t408" n="408" lemma="avoir" pos="VERcjg" >a</w>
                        <w xml:id="t409" n="409" lemma="mesfaire" pos="VERppe" >meffait</w>
                        <w xml:id="t410" n="410" lemma="se" pos="ADVgen" >Si</w>
                        <w xml:id="t411" n="411" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t412" n="412" lemma="metre2" pos="VERcjg" >met</w>
                        <w xml:id="t413" n="413" lemma="sus" pos="ADVgen" >sus</w>
                        <w xml:id="t414" n="414" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t415" n="415" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t416" n="416" lemma="avoir" pos="VERcjg" >a</w>
                        <w xml:id="t417" n="417" lemma="son4" pos="DETpos" >ses</w>
                        <w xml:id="t418" n="418" lemma="ome" pos="NOMcom" >hommes</w>
                        <w xml:id="t419" n="419" lemma="ocire" pos="VERppe" >occis</w>
                        <w xml:id="t420" n="420" lemma="en1" pos="PRE" >en</w>
                        <w xml:id="t421" n="421" lemma="tens" pos="NOMcom" >temps</w>
                        <w xml:id="t422" n="422" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t423" n="423" lemma="treue" pos="NOMcom" >treves</w>
                        <w xml:id="t424" n="424" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t425" n="425" lemma="que2" pos="CONsub" >qu</w>
                        <w xml:id="t426" n="426" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t427" n="427" lemma="avoir" pos="VERcjg" >avoit</w>
                        <w xml:id="t428" n="428" lemma="prometre" pos="VERppe" >promis</w>
                        <w xml:id="t429" n="429" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t430" n="430" lemma="il" pos="PROper" >ilz</w>
                        <w xml:id="t431" n="431" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t432" n="432" lemma="avoir" pos="VERcjg" >avoient</w>
                        <w xml:id="t433" n="433" lemma="garde" pos="NOMcom" >garde</w>
                        <w xml:id="t434" n="434" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t435" n="435" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t436" n="436" lemma="Hector" pos="NOMpro" >Hector</w>
                        <w xml:id="t437" n="437" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t438" n="438" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t439" n="439" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t440" n="440" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t441" n="441" lemma="il" pos="PROper" >le</w>
                        <w xml:id="t442" n="442" lemma="prometre" pos="VERcjg" >promist</w>
                        <w xml:id="t443" n="443" lemma="onque" pos="ADVgen" >oncques</w>
                        <w xml:id="t444" n="444" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t445" n="445" lemma="cant1" pos="CONsub" >quant</w>
                        <w xml:id="t446" n="446" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t447" n="447" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t448" n="448" lemma="avoir" pos="VERcjg" >auroit</w>
                        <w xml:id="t449" n="449" lemma="prometre" pos="VERppe" >promis</w>
                        <w xml:id="t450" n="450" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t451" n="451" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t452" n="452" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t453" n="453" lemma="avoir" pos="VERcjg" >a</w>
                        <w xml:id="t454" n="454" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t455" n="455" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t456" n="456" lemma="nul" pos="DETind" >nul</w>
                        <w xml:id="t457" n="457" lemma="tort2" pos="NOMcom" >tort</w>
                        <w xml:id="t458" n="458" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t459" n="459" lemma="il" pos="PROper" >ilz</w>
                        <w xml:id="t460" n="460" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t461" n="461" lemma="estre1" pos="VERcjg" >sont</w>
                        <w xml:id="t462" n="462" lemma="porter" pos="VERppe" >portez</w>
                        <w xml:id="t463" n="463" lemma="deslëaument" pos="ADVgen" >desloyaument</w>
                        <w xml:id="t464" n="464" lemma="envers2" pos="PRE" >envers</w>
                        <w xml:id="t465" n="465" lemma="je" pos="PROper" >moy</w>
                        <w xml:id="t466" n="466" lemma="mais1" pos="CONcoo" >mais</w>
                        <w xml:id="t467" n="467" lemma="je" pos="PROper" >je</w>
                        <w xml:id="t468" n="468" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t469" n="469" lemma="cuidier1" pos="VERcjg" >cuide</w>
                        <w xml:id="t470" n="470" lemma="pas" pos="ADVneg" >pas</w>
                        <w xml:id="t471" n="471" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t472" n="472" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t473" n="473" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t474" n="474" lemma="se" pos="PROper" >se</w>
                        <w xml:id="t475" n="475" lemma="estre1" pos="VERcjg" >feust</w>
                        <w xml:id="t476" n="476" lemma="par" pos="PRE" >par</w>
                        <w xml:id="t477" n="477" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t478" n="478" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t479" n="479" lemma="dieu" pos="NOMcom" >dieu</w>
                        <w xml:id="t480" n="480" lemma="je" pos="PROper" >m</w>
                        <w xml:id="t481" n="481" lemma="aidier" pos="VERcjg" >aist</w>
                        <w xml:id="t482" n="482" lemma="je" pos="PROper" >je</w>
                        <w xml:id="t483" n="483" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t484" n="484" lemma="tenir1" pos="PROpos" >tiens</w>
                        <w xml:id="t485" n="485" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t486" n="486" lemma="lëal" pos="ADJqua" >loyal</w>
                        <w xml:id="t487" n="487" lemma="chevalier" pos="NOMcom" >chevalier</w>
                        <w xml:id="t488" n="488" lemma="por2" pos="PRE" >pour</w>
                        <w xml:id="t489" n="489" lemma="ce1" pos="PROdem" >ce</w>
                        <w xml:id="t490" n="490" lemma="que2" pos="CONsub" >que</w>
                        <w xml:id="t491" n="491" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t492" n="492" lemma="avoir" pos="VERcjg" >avez</w>
                        <w xml:id="t493" n="493" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t494" n="494" lemma="tenir1" pos="VERinf" >tenir</w>
                        <w xml:id="t495" n="495" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t496" n="496" lemma="ce2" pos="DETdem" >ce</w>
                        <w xml:id="t497" n="497" lemma="chevalier" pos="NOMcom" >chevalier</w>
                        <w xml:id="t498" n="498" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t499" n="499" lemma="covenance" pos="NOMcom" >convenance</w>
                        <w xml:id="t500" n="500" lemma="que2" pos="PROrel" >que</w>
                        <w xml:id="t501" n="501" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t502" n="502" lemma="je" pos="PROper" >m</w>
                        <w xml:id="t503" n="503" lemma="avoir" pos="VERcjg" >avez</w>
                        <w xml:id="t504" n="504" lemma="prometre" pos="VERppe" >promise</w>
                        <w xml:id="t505" n="505" lemma="por2" pos="PRE" >pour</w>
                        <w xml:id="t506" n="506" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t507" n="507" lemma="Totose" pos="NOMcom" >Toutesfois</w>
                        <w xml:id="t508" n="508" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t509" n="509" lemma="Marganor" pos="NOMpro" >marganor</w>
                        <w xml:id="t510" n="510" lemma="je" pos="PROper" >je</w>
                        <w xml:id="t511" n="511" lemma="voloir" pos="VERcjg" >vueil</w>
                        <w xml:id="t512" n="512" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t513" n="513" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t514" n="514" lemma="venir" pos="VERcjg" >venez</w>
                        <w xml:id="t515" n="515" lemma="en1" pos="PRE" >en</w>
                        <w xml:id="t516" n="516" lemma="mon1" pos="DETpos" >ma</w>
                        <w xml:id="t517" n="517" lemma="prison" pos="NOMcom" >prison</w>
                        <w xml:id="t518" n="518" lemma="où" pos="PROrel" >ou</w>
                        <w xml:id="t519" n="519" lemma="que2" pos="CONsub" >que</w>
                        <w xml:id="t520" n="520" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t521" n="521" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t522" n="522" lemma="defendre" pos="VERcjg" >deffendez</w>
                        <w xml:id="t523" n="523" lemma="de+le" pos="PRE.DETdef" >du</w>
                        <w xml:id="t524" n="524" lemma="maufé" pos="NOMcom" >malfait</w>
                        <w xml:id="t525" n="525" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t526" n="526" lemma="je" pos="PROper" >je</w>
                        <w xml:id="t527" n="527" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t528" n="528" lemma="apeler" pos="VERcjg" >appelle</w>
                        <w xml:id="t529" n="529" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t530" n="530" lemma="foimentie" pos="NOMcom" >foymentie</w>
                        <w xml:id="t531" n="531" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t532" n="532" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t533" n="533" lemma="deslëauté" pos="NOMcom" >desloyaute</w>
                        <w xml:id="t534" n="534" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t535" n="535" lemma="estre1" pos="VERcjg" >suis</w>
                        <w xml:id="t536" n="536" lemma="tot" pos="ADVgen" >tout</w>
                        <w xml:id="t537" n="537" lemma="prest1" pos="ADJqua" >prest</w>
                        <w xml:id="t538" n="538" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t539" n="539" lemma="le" pos="PROper" >le</w>
                        <w xml:id="t540" n="540" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t541" n="541" lemma="mostrer" pos="VERinf" >monstrer</w>
                        <w xml:id="t542" n="542" lemma="mon1" pos="DETpos" >mon</w>
                        <w xml:id="t543" n="543" lemma="cors1" pos="NOMcom" >corps</w>
                        <w xml:id="t544" n="544" lemma="contre" pos="PRE" >contre</w>
                        <w xml:id="t545" n="545" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t546" n="546" lemma="vostre" pos="PROpos" >vostre</w>
                        <w xml:id="t547" n="547" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t548" n="548" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t549" n="549" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t550" n="550" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t551" n="551" lemma="il" pos="PROimp" >il</w>
                        <w xml:id="t552" n="552" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t553" n="553" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t554" n="554" lemma="corir" pos="NOMcom" >court</w>
                        <w xml:id="t555" n="555" lemma="en1" pos="PRE" >en</w>
                        <w xml:id="t556" n="556" lemma="tot" pos="DETind" >tout</w>
                        <w xml:id="t557" n="557" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t558" n="558" lemma="monde1" pos="NOMcom" >monde</w>
                        <w xml:id="t559" n="559" lemma="où" pos="PROrel" >ou</w>
                        <w xml:id="t560" n="560" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t561" n="561" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t562" n="562" lemma="soi1" pos="PROper" >s</w>
                        <w xml:id="t563" n="563" lemma="en2" pos="PROadv" >en</w>
                        <w xml:id="t564" n="564" lemma="oser" pos="VERcjg" >osast</w>
                        <w xml:id="t565" n="565" lemma="bien1" pos="ADVgen" >bien</w>
                        <w xml:id="t566" n="566" lemma="defendre" pos="VERinf" >deffendre</w>
                        <w xml:id="t567" n="567" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t568" n="568" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t569" n="569" lemma="seignor" pos="NOMcom" >sire</w>
                        <w xml:id="t570" n="570" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t571" n="571" lemma="le" pos="DETdef" >l</w>
                        <w xml:id="t572" n="572" lemma="estroit" pos="ADJqua" >estroite</w>
                        <w xml:id="t573" n="573" lemma="marche1" pos="NOMcom" >marche</w>
                        <w xml:id="t574" n="574" lemma="dire" pos="VERcjg" >dist</w>
                        <w xml:id="t575" n="575" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t576" n="576" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t577" n="577" lemma="nos1" pos="PROper" >nous</w>
                        <w xml:id="t578" n="578" lemma="savoir" pos="VERcjg" >savons</w>
                        <w xml:id="t579" n="579" lemma="bien1" pos="ADVgen" >bien</w>
                        <w xml:id="t580" n="580" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t581" n="581" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t582" n="582" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t583" n="583" lemma="avoir" pos="VERcjg" >avez</w>
                        <w xml:id="t584" n="584" lemma="nul" pos="DETind" >nulle</w>
                        <w xml:id="t585" n="585" lemma="deslëauté" pos="NOMcom" >desloyaute</w>
                        <w xml:id="t586" n="586" lemma="faire" pos="VERppe" >faicte</w>
                        <w xml:id="t587" n="587" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t588" n="588" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t589" n="589" lemma="avoir" pos="VERcjg" >a</w>
                        <w xml:id="t590" n="590" lemma="cort1" pos="NOMcom" >court</w>
                        <w xml:id="t591" n="591" lemma="en1" pos="PRE" >en</w>
                        <w xml:id="t592" n="592" lemma="tot" pos="DETind" >tout</w>
                        <w xml:id="t593" n="593" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t594" n="594" lemma="monde1" pos="NOMcom" >monde</w>
                        <w xml:id="t595" n="595" lemma="où" pos="PROrel" >ou</w>
                        <w xml:id="t596" n="596" lemma="nos1" pos="PROper" >nous</w>
                        <w xml:id="t597" n="597" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t598" n="598" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t599" n="599" lemma="en2" pos="PROadv" >en</w>
                        <w xml:id="t600" n="600" lemma="porter" pos="VERcjg" >portons</w>
                        <w xml:id="t601" n="601" lemma="tesmoignage" pos="NOMcom" >tesmoignage</w>
                        <w xml:id="t602" n="602" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t603" n="603" lemma="se" pos="CONsub" >s</w>
                        <w xml:id="t604" n="604" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t605" n="605" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t606" n="606" lemma="en2" pos="PROadv" >en</w>
                        <w xml:id="t607" n="607" lemma="voloir" pos="VERcjg" >veult</w>
                        <w xml:id="t608" n="608" lemma="apeler" pos="VERinf" >appeller</w>
                        <w xml:id="t609" n="609" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t610" n="610" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t611" n="611" lemma="en2" pos="PROadv" >en</w>
                        <w xml:id="t612" n="612" lemma="apeler" pos="VERcjg" >appellez</w>
                        <w xml:id="t613" n="613" lemma="en1" pos="PRE" >en</w>
                        <w xml:id="t614" n="614" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t615" n="615" lemma="cort1" pos="NOMcom" >court</w>
                        <w xml:id="t616" n="616" lemma="de+le" pos="PRE.DETdef" >du</w>
                        <w xml:id="t617" n="617" lemma="roi2" pos="NOMcom" >roy</w>
                        <w xml:id="t618" n="618" lemma="Artu" pos="VERppe" >artus</w>
                        <w xml:id="t619" n="619" lemma="Marganor" pos="NOMpro" >Marganor</w>
                        <w xml:id="t620" n="620" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t621" n="621" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t622" n="622" lemma="se" pos="CONsub" >s</w>
                        <w xml:id="t623" n="623" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t624" n="624" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t625" n="625" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t626" n="626" lemma="defendre" pos="VERcjg" >deffent</w>
                        <w xml:id="t627" n="627" lemma="ici" pos="ADVgen" >icy</w>
                        <w xml:id="t628" n="628" lemma="il" pos="PROimp" >il</w>
                        <w xml:id="t629" n="629" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t630" n="630" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t631" n="631" lemma="cort1" pos="ADJqua" >court</w>
                        <w xml:id="t632" n="632" lemma="où" pos="PROrel" >ou</w>
                        <w xml:id="t633" n="633" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t634" n="634" lemma="il" pos="PROper" >l</w>
                        <w xml:id="t635" n="635" lemma="aler" pos="VERcjg" >aille</w>
                        <w xml:id="t636" n="636" lemma="apeler" pos="VERinf" >appeller</w>
                        <w xml:id="t637" n="637" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t638" n="638" lemma="deslëauté" pos="NOMcom" >desloyaute</w>
                        <w xml:id="t639" n="639" lemma="por2" pos="PRE" >pour</w>
                        <w xml:id="t640" n="640" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t641" n="641" lemma="faire" pos="VERinf" >faire</w>
                        <w xml:id="t642" n="642" lemma="plus" pos="ADVgen" >plus</w>
                        <w xml:id="t643" n="643" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t644" n="644" lemma="honte" pos="NOMcom" >honte</w>
                        <w xml:id="t645" n="645" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t646" n="646" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t647" n="647" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t648" n="648" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t649" n="649" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t650" n="650" lemma="ja" pos="ADVgen" >ja</w>
                        <w xml:id="t651" n="651" lemma="dieu" pos="NOMcom" >dieu</w>
                        <w xml:id="t652" n="652" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t653" n="653" lemma="le" pos="PROper" >l</w>
                        <w xml:id="t654" n="654" lemma="aidier" pos="VERcjg" >aide</w>
                        <w xml:id="t655" n="655" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t656" n="656" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t657" n="657" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t658" n="658" lemma="tot" pos="ADVgen" >tout</w>
                        <w xml:id="t659" n="659" lemma="prest1" pos="ADJqua" >prest</w>
                        <w xml:id="t660" n="660" lemma="sans" pos="PRE" >sans</w>
                        <w xml:id="t661" n="661" lemma="plus" pos="ADVgen" >plus</w>
                        <w xml:id="t662" n="662" lemma="loing" pos="ADVgen" >loing</w>
                        <w xml:id="t663" n="663" lemma="aler" pos="VERinf" >aler</w>
                        <w xml:id="t664" n="664" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t665" n="665" lemma="son4" pos="PROper" >s</w>
                        <w xml:id="t666" n="666" lemma="en2" pos="PROadv" >en</w>
                        <w xml:id="t667" n="667" lemma="defendre" pos="VERinf" >deffendre</w>
                        <w xml:id="t668" n="668" lemma="se" pos="CONsub" >Se</w>
                        <w xml:id="t669" n="669" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t670" n="670" lemma="je" pos="PROper" >me</w>
                        <w xml:id="t671" n="671" lemma="croire" pos="VERcjg" >croiez</w>
                        <w xml:id="t672" n="672" lemma="faire" pos="VERcjg" >fait</w>
                        <w xml:id="t673" n="673" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t674" n="674" lemma="seignor" pos="NOMcom" >sire</w>
                        <w xml:id="t675" n="675" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t676" n="676" lemma="le" pos="DETdef" >l</w>
                        <w xml:id="t677" n="677" lemma="estroit" pos="ADJqua" >estroite</w>
                        <w xml:id="t678" n="678" lemma="marche1" pos="NOMcom" >marche</w>
                        <w xml:id="t679" n="679" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t680" n="680" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t681" n="681" lemma="il" pos="PROper" >le</w>
                        <w xml:id="t682" n="682" lemma="faire" pos="VERcjg" >ferez</w>
                        <w xml:id="t683" n="683" lemma="mie" pos="ADVneg" >mie</w>
                        <w xml:id="t684" n="684" lemma="ainsi" pos="ADVgen" >ainsi</w>
                        <w xml:id="t685" n="685" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t686" n="686" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t687" n="687" lemma="avoir" pos="VERcjg" >avez</w>
                        <w xml:id="t688" n="688" lemma="enui" pos="VERppe" >ennuy</w>
                        <w xml:id="t689" n="689" lemma="assez" pos="ADVgen" >assez</w>
                        <w xml:id="t690" n="690" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t691" n="691" lemma="de" pos="PRE" >d</w>
                        <w xml:id="t692" n="692" lemma="arme" pos="NOMcom" >armes</w>
                        <w xml:id="t693" n="693" lemma="mais1" pos="CONcoo" >mais</w>
                        <w xml:id="t694" n="694" lemma="demain" pos="ADVgen" >demain</w>
                        <w xml:id="t695" n="695" lemma="estre1" pos="VERcjg" >soit</w>
                        <w xml:id="t696" n="696" lemma="apareillier1" pos="VERppe" >apareillie</w>
                        <w xml:id="t697" n="697" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t698" n="698" lemma="son4" pos="DETpos" >sa</w>
                        <w xml:id="t699" n="699" lemma="bataille" pos="NOMcom" >bataille</w>
                        <w xml:id="t700" n="700" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t701" n="701" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t702" n="702" lemma="de" pos="PRE" >d</w>
                        <w xml:id="t703" n="703" lemma="autre" pos="DETind" >autre</w>
                        <w xml:id="t704" n="704" lemma="part1" pos="NOMcom" >part</w>
                        <w xml:id="t705" n="705" lemma="puis" pos="ADVgen" >puis</w>
                        <w xml:id="t706" n="706" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t707" n="707" lemma="par" pos="PRE" >par</w>
                        <w xml:id="t708" n="708" lemma="bataille" pos="NOMcom" >bataille</w>
                        <w xml:id="t709" n="709" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t710" n="710" lemma="en2" pos="PROadv" >en</w>
                        <w xml:id="t711" n="711" lemma="voloir" pos="VERcjg" >voullez</w>
                        <w xml:id="t712" n="712" lemma="aler" pos="VERinf" >aler</w>
                        <w xml:id="t713" n="713" lemma="non" pos="ADVneg" >Non</w>
                        <w xml:id="t714" n="714" lemma="faire" pos="VERcjg" >feray</w>
                        <w xml:id="t715" n="715" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t716" n="716" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t717" n="717" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t718" n="718" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t719" n="719" lemma="deviser" pos="VERcjg" >devisera</w>
                        <w xml:id="t720" n="720" lemma="ja" pos="ADVgen" >ja</w>
                        <w xml:id="t721" n="721" lemma="chose" pos="NOMcom" >chose</w>
                        <w xml:id="t722" n="722" lemma="que4" pos="PROrel" >que</w>
                        <w xml:id="t723" n="723" lemma="je" pos="PROper" >je</w>
                        <w xml:id="t724" n="724" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t725" n="725" lemma="faire" pos="VERcjg" >face</w>
                        <w xml:id="t726" n="726" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t727" n="727" lemma="je" pos="PROper" >je</w>
                        <w xml:id="t728" n="728" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t729" n="729" lemma="avoir" pos="VERcjg" >ay</w>
                        <w xml:id="t730" n="730" lemma="encore" pos="ADVgen" >encores</w>
                        <w xml:id="t731" n="731" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t732" n="732" lemma="arme" pos="NOMcom" >armes</w>
                        <w xml:id="t733" n="733" lemma="je" pos="PROper" >me</w>
                        <w xml:id="t734" n="734" lemma="qui" pos="PROrel" >qui</w>
                        <w xml:id="t735" n="735" lemma="grever" pos="VERcjg" >grieve</w>
                        <w xml:id="t736" n="736" lemma="en1" pos="PRE" >En</w>
                        <w xml:id="t737" n="737" lemma="verité" pos="NOMcom" >verite</w>
                        <w xml:id="t738" n="738" lemma="faire" pos="VERcjg" >fait</w>
                        <w xml:id="t739" n="739" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t740" n="740" lemma="seignor" pos="NOMcom" >sire</w>
                        <w xml:id="t741" n="741" lemma="je" pos="PROper" >je</w>
                        <w xml:id="t742" n="742" lemma="je" pos="PROper" >me</w>
                        <w xml:id="t743" n="743" lemma="doter2" pos="VERcjg" >doubte</w>
                        <w xml:id="t744" n="744" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t745" n="745" lemma="träison" pos="NOMcom" >trayson</w>
                        <w xml:id="t746" n="746" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t747" n="747" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t748" n="748" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t749" n="749" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t750" n="750" lemma="combatre" pos="VERcjg" >combatez</w>
                        <w xml:id="t751" n="751" lemma="là" pos="ADVgen" >la</w>
                        <w xml:id="t752" n="752" lemma="defors" pos="ADVgen" >dehors</w>
                        <w xml:id="t753" n="753" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t754" n="754" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t755" n="755" lemma="pöoir" pos="VERcjg" >pourra</w>
                        <w xml:id="t756" n="756" lemma="faire" pos="VERinf" >faire</w>
                        <w xml:id="t757" n="757" lemma="prendre" pos="VERinf" >prendre</w>
                        <w xml:id="t758" n="758" lemma="par" pos="PRE" >par</w>
                        <w xml:id="t759" n="759" lemma="son4" pos="DETpos" >ses</w>
                        <w xml:id="t760" n="760" lemma="gent1" pos="NOMcom" >gens</w>
                        <w xml:id="t761" n="761" lemma="o3" pos="CONcoo" >ou</w>
                        <w xml:id="t762" n="762" lemma="ocire" pos="VERinf" >occire</w>
                        <w xml:id="t763" n="763" lemma="se" pos="CONsub" >s</w>
                        <w xml:id="t764" n="764" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t765" n="765" lemma="voloir" pos="VERcjg" >veult</w>
                        <w xml:id="t766" n="766" lemma="ne2" pos="ADVneg" >N</w>
                        <w xml:id="t767" n="767" lemma="avoir" pos="VERcjg" >ayez</w>
                        <w xml:id="t768" n="768" lemma="pëor" pos="NOMcom" >paour</w>
                        <w xml:id="t769" n="769" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t770" n="770" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t771" n="771" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t772" n="772" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t773" n="773" lemma="il" pos="PROper" >le</w>
                        <w xml:id="t774" n="774" lemma="faire" pos="VERcjg" >feroit</w>
                        <w xml:id="t775" n="775" lemma="ja+mais1" pos="ADVgen" >jamais</w>
                        <w xml:id="t776" n="776" lemma="coment1" pos="ADVgen" >Comment</w>
                        <w xml:id="t777" n="777" lemma="faire" pos="VERcjg" >fait</w>
                        <w xml:id="t778" n="778" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t779" n="779" lemma="seignor" pos="NOMcom" >sire</w>
                        <w xml:id="t780" n="780" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t781" n="781" lemma="avoir" pos="VERcjg" >avez</w>
                        <w xml:id="t782" n="782" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t783" n="783" lemma="point" pos="ADVneg" >point</w>
                        <w xml:id="t784" n="784" lemma="vëoir" pos="VERppe" >veu</w>
                        <w xml:id="t785" n="785" lemma="coment1" pos="ADVsub" >comment</w>
                        <w xml:id="t786" n="786" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t787" n="787" lemma="avoir" pos="VERcjg" >a</w>
                        <w xml:id="t788" n="788" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t789" n="789" lemma="depecier" pos="VERinf" >depecer</w>
                        <w xml:id="t790" n="790" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t791" n="791" lemma="pont" pos="NOMcom" >pont</w>
                        <w xml:id="t792" n="792" lemma="por2" pos="PRE" >pour</w>
                        <w xml:id="t793" n="793" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t794" n="794" lemma="retenir" pos="VERinf" >retenir</w>
                        <w xml:id="t795" n="795" lemma="autant" pos="ADVgen" >autant</w>
                        <w xml:id="t796" n="796" lemma="en2" pos="PROadv" >en</w>
                        <w xml:id="t797" n="797" lemma="pöoir" pos="VERcjg" >pourroit</w>
                        <w xml:id="t798" n="798" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t799" n="799" lemma="faire" pos="VERinf" >faire</w>
                        <w xml:id="t800" n="800" lemma="mais1" pos="CONcoo" >mais</w>
                        <w xml:id="t801" n="801" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t802" n="802" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t803" n="803" lemma="voloir" pos="VERcjg" >voullez</w>
                        <w xml:id="t804" n="804" lemma="je" pos="PROper" >je</w>
                        <w xml:id="t805" n="805" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t806" n="806" lemma="enseignier" pos="VERcjg" >enseigneray</w>
                        <w xml:id="t807" n="807" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t808" n="808" lemma="combatre" pos="VERinf" >combatre</w>
                        <w xml:id="t809" n="809" lemma="en1" pos="PRE" >en</w>
                        <w xml:id="t810" n="810" lemma="tel" pos="DETind" >telle</w>
                        <w xml:id="t811" n="811" lemma="maniere" pos="NOMcom" >maniere</w>
                        <w xml:id="t812" n="812" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t813" n="813" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t814" n="814" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t815" n="815" lemma="avoir" pos="VERcjg" >aurez</w>
                        <w xml:id="t816" n="816" lemma="garde" pos="NOMcom" >garde</w>
                        <w xml:id="t817" n="817" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t818" n="818" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t819" n="819" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t820" n="820" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t821" n="821" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t822" n="822" lemma="maniere" pos="NOMcom" >maniere</w>
                        <w xml:id="t823" n="823" lemma="estre1" pos="VERcjg" >sera</w>
                        <w xml:id="t824" n="824" lemma="tel" pos="ADJind" >telle</w>
                        <w xml:id="t825" n="825" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t826" n="826" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t827" n="827" lemma="faire" pos="VERcjg" >fera</w>
                        <w xml:id="t828" n="828" lemma="tot" pos="PROind" >toutes</w>
                        <w xml:id="t829" n="829" lemma="desarmer" pos="VERinf" >desarmer</w>
                        <w xml:id="t830" n="830" lemma="son4" pos="DETpos" >ses</w>
                        <w xml:id="t831" n="831" lemma="gent1" pos="NOMcom" >gens</w>
                        <w xml:id="t832" n="832" lemma="puis" pos="ADVgen" >puis</w>
                        <w xml:id="t833" n="833" lemma="après" pos="ADVgen" >apres</w>
                        <w xml:id="t834" n="834" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t835" n="835" lemma="jurer" pos="VERcjg" >jurera</w>
                        <w xml:id="t836" n="836" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t837" n="837" lemma="ja" pos="ADVgen" >ja</w>
                        <w xml:id="t838" n="838" lemma="nul" pos="PROind" >nul</w>
                        <w xml:id="t839" n="839" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t840" n="840" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t841" n="841" lemma="movoir" pos="VERcjg" >mouvera</w>
                        <w xml:id="t842" n="842" lemma="por2" pos="PRE" >pour</w>
                        <w xml:id="t843" n="843" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t844" n="844" lemma="secorre1" pos="VERinf" >secourir</w>
                        <w xml:id="t845" n="845" lemma="ne2" pos="CONcoo" >ne</w>
                        <w xml:id="t846" n="846" lemma="por2" pos="PRE" >pour</w>
                        <w xml:id="t847" n="847" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t848" n="848" lemma="empëechier" pos="VERinf" >empeschier</w>
                        <w xml:id="t849" n="849" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t850" n="850" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t851" n="851" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t852" n="852" lemma="bataille" pos="NOMcom" >bataille</w>
                        <w xml:id="t853" n="853" lemma="estre1" pos="VERcjg" >soit</w>
                        <w xml:id="t854" n="854" lemma="faire" pos="VERppe" >faicte</w>
                        <w xml:id="t855" n="855" lemma="sor2" pos="PRE" >sur</w>
                        <w xml:id="t856" n="856" lemma="cest" pos="DETdem" >ceste</w>
                        <w xml:id="t857" n="857" lemma="chauciee" pos="NOMcom" >chaucee</w>
                        <w xml:id="t858" n="858" lemma="entre2" pos="PRE" >entre</w>
                        <w xml:id="t859" n="859" lemma="se" pos="PROper" >se</w>
                        <w xml:id="t860" n="860" lemma="grant" pos="ADJqua" >grant</w>
                        <w xml:id="t861" n="861" lemma="pont" pos="NOMcom" >pont</w>
                        <w xml:id="t862" n="862" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t863" n="863" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t864" n="864" lemma="petit" pos="ADJqua" >petit</w>
                        <w xml:id="t865" n="865" lemma="poncel1" pos="NOMcom" >poncel</w>
                        <w xml:id="t866" n="866" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t867" n="867" lemma="cant1" pos="CONsub" >quant</w>
                        <w xml:id="t868" n="868" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t869" n="869" lemma="estre1" pos="VERcjg" >sera</w>
                        <w xml:id="t870" n="870" lemma="deça" pos="ADVgen" >deca</w>
                        <w xml:id="t871" n="871" lemma="se" pos="ADVgen" >si</w>
                        <w xml:id="t872" n="872" lemma="estre1" pos="VERcjg" >soit</w>
                        <w xml:id="t873" n="873" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t874" n="874" lemma="poncel1" pos="NOMcom" >poncel</w>
                        <w xml:id="t875" n="875" lemma="rompre" pos="VERppe" >rompu</w>
                        <w xml:id="t876" n="876" lemma="ainsi" pos="ADVgen" >ainsi</w>
                        <w xml:id="t877" n="877" lemma="pöoir" pos="VERppe" >pourrez</w>
                        <w xml:id="t878" n="878" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t879" n="879" lemma="estre1" pos="VERinf" >estre</w>
                        <w xml:id="t880" n="880" lemma="assëurer" pos="ADVgen" >asseure</w>
                        <w xml:id="t881" n="881" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t882" n="882" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t883" n="883" lemma="si" pos="ADVgen" >Si</w>
                        <w xml:id="t884" n="884" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t885" n="885" lemma="conseillier1" pos="VERcjg" >conseille</w>
                        <w xml:id="t886" n="886" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t887" n="887" lemma="vos" pos="PROper" >vous</w>
                        <w xml:id="t888" n="888" lemma="il" pos="PROper" >le</w>
                        <w xml:id="t889" n="889" lemma="faire" pos="VERcjg" >faictes</w>
                        <w xml:id="t890" n="890" lemma="en1" pos="PRE" >en</w>
                        <w xml:id="t891" n="891" lemma="cel" pos="DETdem" >celle</w>
                        <w xml:id="t892" n="892" lemma="maniere" pos="NOMcom" >maniere</w>
                        <w xml:id="t893" n="893" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t894" n="894" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t895" n="895" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t896" n="896" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t897" n="897" lemma="ainsi" pos="ADVgen" >ainsi</w>
                        <w xml:id="t898" n="898" lemma="estre1" pos="VERcjg" >sera</w>
                        <w xml:id="t899" n="899" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t900" n="900" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t901" n="901" lemma="Marganor" pos="NOMpro" >marganor</w>
                        <w xml:id="t902" n="902" lemma="en2" pos="PROadv" >en</w>
                        <w xml:id="t903" n="903" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t904" n="904" lemma="conter" pos="VERcjg" >content</w>
                        <w xml:id="t905" n="905" lemma="lors" pos="ADVgen" >LOrs</w>
                        <w xml:id="t906" n="906" lemma="soi1" pos="PROper" >s</w>
                        <w xml:id="t907" n="907" lemma="en2" pos="PROadv" >en</w>
                        <w xml:id="t908" n="908" lemma="retorner" pos="VERcjg" >retourne</w>
                        <w xml:id="t909" n="909" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t910" n="910" lemma="a3+le" pos="PRE.DETdef" >au</w>
                        <w xml:id="t911" n="911" lemma="poncel1" pos="NOMcom" >poncel</w>
                        <w xml:id="t912" n="912" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t913" n="913" lemma="comander" pos="VERcjg" >compte</w>
                        <w xml:id="t914" n="914" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t915" n="915" lemma="Marganor" pos="NOMpro" >marganor</w>
                        <w xml:id="t916" n="916" lemma="coment1" pos="ADVsub" >comment</w>
                        <w xml:id="t917" n="917" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t918" n="918" lemma="bataille" pos="NOMcom" >bataille</w>
                        <w xml:id="t919" n="919" lemma="estre1" pos="VERcjg" >sera</w>
                        <w xml:id="t920" n="920" lemma="faire" pos="VERppe" >faicte</w>
                        <w xml:id="t921" n="921" lemma="se" pos="CONsub" >s</w>
                        <w xml:id="t922" n="922" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t923" n="923" lemma="voloir" pos="VERcjg" >veult</w>
                        <w xml:id="t924" n="924" lemma="ainsi" pos="ADVgen" >ainsi</w>
                        <w xml:id="t925" n="925" lemma="come1" pos="CONsub" >comme</w>
                        <w xml:id="t926" n="926" lemma="desus" pos="ADVgen" >dessus</w>
                        <w xml:id="t927" n="927" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t928" n="928" lemma="deviser" pos="VERppe" >devise</w>
                        <w xml:id="t929" n="929" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t930" n="930" lemma="Marganor" pos="NOMpro" >marganor</w>
                        <w xml:id="t931" n="931" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t932" n="932" lemma="demander" pos="VERcjg" >demande</w>
                        <w xml:id="t933" n="933" lemma="quel1" pos="DETint" >quelle</w>
                        <w xml:id="t934" n="934" lemma="asservanter" pos="NOMcom" >asseurance</w>
                        <w xml:id="t935" n="935" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t936" n="936" lemma="avoir" pos="VERcjg" >aura</w>
                        <w xml:id="t937" n="937" lemma="de+le" pos="PRE.DETdef" >du</w>
                        <w xml:id="t938" n="938" lemma="seignor" pos="NOMcom" >seigneur</w>
                        <w xml:id="t939" n="939" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t940" n="940" lemma="le" pos="DETdef" >l</w>
                        <w xml:id="t941" n="941" lemma="estroit" pos="ADJqua" >estroite</w>
                        <w xml:id="t942" n="942" lemma="Marche" pos="NOMcom" >marche</w>
                        <w xml:id="t943" n="943" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t944" n="944" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t945" n="945" lemma="son4" pos="DETpos" >ses</w>
                        <w xml:id="t946" n="946" lemma="gent1" pos="NOMcom" >gens</w>
                        <w xml:id="t947" n="947" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t948" n="948" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t949" n="949" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t950" n="950" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t951" n="951" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t952" n="952" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t953" n="953" lemma="faire" pos="VERcjg" >fera</w>
                        <w xml:id="t954" n="954" lemma="jurer" pos="VERinf" >jurer</w>
                        <w xml:id="t955" n="955" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t956" n="956" lemma="prometre" pos="VERinf" >promettre</w>
                        <w xml:id="t957" n="957" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t958" n="958" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t959" n="959" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t960" n="960" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t961" n="961" lemma="avoir" pos="VERcjg" >aura</w>
                        <w xml:id="t962" n="962" lemma="nul" pos="DETind" >nul</w>
                        <w xml:id="t963" n="963" lemma="mal1" pos="NOMcom" >mal</w>
                        <w xml:id="t964" n="964" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t965" n="965" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t966" n="966" lemma="acorder" pos="NOMcom" >accorde</w>
                        <w xml:id="t967" n="967" lemma="Marganor" pos="NOMpro" >marganor</w>
                        <w xml:id="t968" n="968" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t969" n="969" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t970" n="970" lemma="bataille" pos="NOMcom" >bataille</w>
                        <w xml:id="t971" n="971" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t972" n="972" lemma="venir" pos="VERcjg" >viennent</w>
                        <w xml:id="t973" n="973" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t974" n="974" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t975" n="975" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t976" n="976" lemma="a3+le" pos="PRE.DETdef" >au</w>
                        <w xml:id="t977" n="977" lemma="poncel1" pos="NOMcom" >poncel</w>
                        <w xml:id="t978" n="978" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t979" n="979" lemma="comander" pos="VERcjg" >commande</w>
                        <w xml:id="t980" n="980" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t981" n="981" lemma="son4" pos="DETpos" >ses</w>
                        <w xml:id="t982" n="982" lemma="gent1" pos="NOMcom" >gens</w>
                        <w xml:id="t983" n="983" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t984" n="984" lemma="nul" pos="PROind" >nul</w>
                        <w xml:id="t985" n="985" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t986" n="986" lemma="entre2" pos="PRE" >entre</w>
                        <w xml:id="t987" n="987" lemma="il" pos="PROper" >eulx</w>
                        <w xml:id="t988" n="988" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t989" n="989" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t990" n="990" lemma="movoir" pos="VERcjg" >meuve</w>
                        <w xml:id="t991" n="991" lemma="sor2" pos="PRE" >sur</w>
                        <w xml:id="t992" n="992" lemma="son4" pos="DETpos" >sa</w>
                        <w xml:id="t993" n="993" lemma="vie1" pos="NOMcom" >vie</w>
                        <w xml:id="t994" n="994" lemma="tant" pos="ADVgen" >tant</w>
                        <w xml:id="t995" n="995" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t996" n="996" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t997" n="997" lemma="estre1" pos="VERcjg" >soit</w>
                        <w xml:id="t998" n="998" lemma="conquerre" pos="VERppe" >conquis</w>
                        <w xml:id="t999" n="999" lemma="où" pos="CONcoo" >ou</w>
                        <w xml:id="t1000" n="1000" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t1001" n="1001" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t1002" n="1002" lemma="il" pos="PROper" >le</w>
                        <w xml:id="t1003" n="1003" lemma="avoir" pos="VERcjg" >ait</w>
                        <w xml:id="t1004" n="1004" lemma="mener" pos="VERppe" >mene</w>
                        <w xml:id="t1005" n="1005" lemma="dedenz" pos="PRE" >dedens</w>
                        <w xml:id="t1006" n="1006" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t1007" n="1007" lemma="chastel" pos="NOMcom" >chasteau</w>
                        <w xml:id="t1008" n="1008" lemma="si" pos="ADVgen" >Si</w>
                        <w xml:id="t1009" n="1009" lemma="en2" pos="PROadv" >en</w>
                        <w xml:id="t1010" n="1010" lemma="faire" pos="VERcjg" >fait</w>
                        <w xml:id="t1011" n="1011" lemma="faire" pos="VERinf" >faire</w>
                        <w xml:id="t1012" n="1012" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t1013" n="1013" lemma="serment" pos="NOMcom" >serment</w>
                        <w xml:id="t1014" n="1014" lemma="a3+le" pos="PRE.DETdef" >au</w>
                        <w xml:id="t1015" n="1015" lemma="conestable" pos="NOMcom" >connestable</w>
                        <w xml:id="t1016" n="1016" lemma="en2" pos="PRE" >en</w>
                        <w xml:id="t1017" n="1017" lemma="après" pos="ADVgen" >apres</w>
                        <w xml:id="t1018" n="1018" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t1019" n="1019" lemma="tot" pos="DETind" >tous</w>
                        <w xml:id="t1020" n="1020" lemma="son4" pos="DETpos" >ses</w>
                        <w xml:id="t1021" n="1021" lemma="ome" pos="NOMcom" >hommes</w>
                        <w xml:id="t1022" n="1022" lemma="puis" pos="ADVgen" >puis</w>
                        <w xml:id="t1023" n="1023" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t1024" n="1024" lemma="lacier" pos="VERcjg" >lace</w>
                        <w xml:id="t1025" n="1025" lemma="son4" pos="DETpos" >son</w>
                        <w xml:id="t1026" n="1026" lemma="heaume" pos="NOMcom" >heaume</w>
                        <w xml:id="t1027" n="1027" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1028" n="1028" lemma="venir" pos="VERcjg" >vient</w>
                        <w xml:id="t1029" n="1029" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t1030" n="1030" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t1031" n="1031" lemma="bretesche" pos="NOMcom" >bretesche</w>
                        <w xml:id="t1032" n="1032" lemma="où" pos="PROrel" >ou</w>
                        <w xml:id="t1033" n="1033" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t1034" n="1034" lemma="seignor" pos="NOMcom" >sire</w>
                        <w xml:id="t1035" n="1035" lemma="de+le" pos="PRE.DETdef" >du</w>
                        <w xml:id="t1036" n="1036" lemma="chastel" pos="NOMcom" >chasteau</w>
                        <w xml:id="t1037" n="1037" lemma="estre1" pos="VERcjg" >estoit</w>
                        <w xml:id="t1038" n="1038" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1039" n="1039" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t1040" n="1040" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t1041" n="1041" lemma="prometre" pos="VERinf" >promettre</w>
                        <w xml:id="t1042" n="1042" lemma="a3+le" pos="PRE.DETdef" >au</w>
                        <w xml:id="t1043" n="1043" lemma="seignor" pos="NOMcom" >seigneur</w>
                        <w xml:id="t1044" n="1044" lemma="de+le" pos="PRE.DETdef" >du</w>
                        <w xml:id="t1045" n="1045" lemma="chastel" pos="NOMcom" >chasteau</w>
                        <w xml:id="t1046" n="1046" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t1047" n="1047" lemma="Marganor" pos="NOMpro" >marganor</w>
                        <w xml:id="t1048" n="1048" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t1049" n="1049" lemma="avoir" pos="VERcjg" >a</w>
                        <w xml:id="t1050" n="1050" lemma="garder" pos="NOMcom" >garde</w>
                        <w xml:id="t1051" n="1051" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t1052" n="1052" lemma="ne2" pos="CONcoo" >ne</w>
                        <w xml:id="t1053" n="1053" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t1054" n="1054" lemma="son4" pos="DETpos" >ses</w>
                        <w xml:id="t1055" n="1055" lemma="gent1" pos="NOMcom" >gens</w>
                        <w xml:id="t1056" n="1056" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t1057" n="1057" lemma="premierement" pos="ADVgen" >premierement</w>
                        <w xml:id="t1058" n="1058" lemma="le" pos="DETdef" >les</w>
                        <w xml:id="t1059" n="1059" lemma="suen" pos="PROpos" >siens</w>
                        <w xml:id="t1060" n="1060" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t1061" n="1061" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t1062" n="1062" lemma="movoir" pos="VERcjg" >meuvent</w>
                        <w xml:id="t1063" n="1063" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t1064" n="1064" lemma="avuec" pos="PRE" >avec</w>
                        <w xml:id="t1065" n="1065" lemma="ce1" pos="PROdem" >ce</w>
                        <w xml:id="t1066" n="1066" lemma="tot" pos="DETind" >tous</w>
                        <w xml:id="t1067" n="1067" lemma="le" pos="DETdef" >les</w>
                        <w xml:id="t1068" n="1068" lemma="chevalier" pos="NOMcom" >chevaliers</w>
                        <w xml:id="t1069" n="1069" lemma="de+le" pos="PRE.DETdef" >du</w>
                        <w xml:id="t1070" n="1070" lemma="chastel" pos="NOMcom" >chasteau</w>
                        <w xml:id="t1071" n="1071" lemma="il" pos="PROper" >le</w>
                        <w xml:id="t1072" n="1072" lemma="prometre" pos="VERcjg" >promettent</w>
                        <w xml:id="t1073" n="1073" lemma="por2" pos="PRE" >pour</w>
                        <w xml:id="t1074" n="1074" lemma="le" pos="DETdef" >l</w>
                        <w xml:id="t1075" n="1075" lemma="amor" pos="NOMcom" >amour</w>
                        <w xml:id="t1076" n="1076" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t1077" n="1077" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t1078" n="1078" lemma="atant" pos="ADVgen" >Atant</w>
                        <w xml:id="t1079" n="1079" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t1080" n="1080" lemma="le" pos="DETdef" >le</w>
                        <w xml:id="t1081" n="1081" lemma="poncel1" pos="NOMcom" >poncel</w>
                        <w xml:id="t1082" n="1082" lemma="rompre" pos="VERppe" >rompu</w>
                        <w xml:id="t1083" n="1083" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t1084" n="1084" lemma="demorer" pos="NOMcom" >demeure</w>
                        <w xml:id="t1085" n="1085" lemma="Marganor" pos="NOMpro" >marganor</w>
                        <w xml:id="t1086" n="1086" lemma="par" pos="PRE" >par</w>
                        <w xml:id="t1087" n="1087" lemma="deça" pos="ADVgen" >deca</w>
                        <w xml:id="t1088" n="1088" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1089" n="1089" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t1090" n="1090" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t1091" n="1091" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t1092" n="1092" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t1093" n="1093" lemma="barbacane" pos="NOMcom" >barbaquane</w>
                        <w xml:id="t1094" n="1094" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t1095" n="1095" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t1096" n="1096" lemma="part1" pos="VERcjg" >part</w>
                        <w xml:id="t1097" n="1097" lemma="Marganor" pos="NOMpro" >marganor</w>
                        <w xml:id="t1098" n="1098" lemma="de+le" pos="PRE.DETdef" >du</w>
                        <w xml:id="t1099" n="1099" lemma="poncel1" pos="NOMcom" >poncel</w>
                        <w xml:id="t1100" n="1100" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1101" n="1101" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t1102" n="1102" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t1103" n="1103" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t1104" n="1104" lemma="barbacane" pos="NOMcom" >barbaquane</w>
                        <w xml:id="t1105" n="1105" lemma="il" pos="PROper" >Ilz</w>
                        <w xml:id="t1106" n="1106" lemma="laissier" pos="VERcjg" >laissent</w>
                        <w xml:id="t1107" n="1107" lemma="corir" pos="VERinf" >courrir</w>
                        <w xml:id="t1108" n="1108" lemma="le" pos="DETdef" >l</w>
                        <w xml:id="t1109" n="1109" lemma="un" pos="PROind" >un</w>
                        <w xml:id="t1110" n="1110" lemma="contre" pos="PRE" >contre</w>
                        <w xml:id="t1111" n="1111" lemma="le" pos="DETdef" >l</w>
                        <w xml:id="t1112" n="1112" lemma="autre" pos="PROind" >autre</w>
                        <w xml:id="t1113" n="1113" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1114" n="1114" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t1115" n="1115" lemma="entreconoistre" pos="VERcjg" >entrerencontrent</w>
                        <w xml:id="t1116" n="1116" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t1117" n="1117" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t1118" n="1118" lemma="grant" pos="ADJqua" >grant</w>
                        <w xml:id="t1119" n="1119" lemma="force2" pos="NOMcom" >force</w>
                        <w xml:id="t1120" n="1120" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t1121" n="1121" lemma="Marganor" pos="NOMpro" >marganor</w>
                        <w xml:id="t1122" n="1122" lemma="brisier" pos="VERcjg" >brise</w>
                        <w xml:id="t1123" n="1123" lemma="son4" pos="DETpos" >son</w>
                        <w xml:id="t1124" n="1124" lemma="glaive" pos="NOMcom" >glaive</w>
                        <w xml:id="t1125" n="1125" lemma="sus" pos="PRE" >sus</w>
                        <w xml:id="t1126" n="1126" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t1127" n="1127" lemma="mais1" pos="CONcoo" >mais</w>
                        <w xml:id="t1128" n="1128" lemma="Hector" pos="NOMcom" >hector</w>
                        <w xml:id="t1129" n="1129" lemma="il" pos="PROper" >le</w>
                        <w xml:id="t1130" n="1130" lemma="prendre" pos="VERcjg" >prent</w>
                        <w xml:id="t1131" n="1131" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t1132" n="1132" lemma="fermement" pos="ADVgen" >fermement</w>
                        <w xml:id="t1133" n="1133" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t1134" n="1134" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t1135" n="1135" lemma="porter" pos="VERcjg" >porte</w>
                        <w xml:id="t1136" n="1136" lemma="ome" pos="NOMcom" >homme</w>
                        <w xml:id="t1137" n="1137" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1138" n="1138" lemma="cheval" pos="NOMcom" >cheval</w>
                        <w xml:id="t1139" n="1139" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t1140" n="1140" lemma="terre" pos="NOMcom" >terre</w>
                        <w xml:id="t1141" n="1141" lemma="tot" pos="ADVgen" >tout</w>
                        <w xml:id="t1142" n="1142" lemma="en1" pos="PRE" >en</w>
                        <w xml:id="t1143" n="1143" lemma="un" pos="DETdem" >ung</w>
                        <w xml:id="t1144" n="1144" lemma="mont" pos="NOMcom" >mont</w>
                        <w xml:id="t1145" n="1145" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1146" n="1146" lemma="rompre" pos="VERcjg" >rompist</w>
                        <w xml:id="t1147" n="1147" lemma="son4" pos="DETpos" >son</w>
                        <w xml:id="t1148" n="1148" lemma="glaive" pos="NOMcom" >glaive</w></ab>
            </div>
       </body>
     </text>
</TEI>
''')

# %%
B1 = etree.XML('''
<TEI xmlns="http://www.tei-c.org/ns/1.0">
    <teiHeader>
        <fileDesc>
            <titleStmt>
                <title></title>
            </titleStmt>
            <publicationStmt><p></p></publicationStmt>
            <sourceDesc><p></p></sourceDesc>
        </fileDesc>
        
    </teiHeader>
    <text xml:lang="fr">
        <body xml:lang="fro">
            <div>
                <ab>
                
                        <w xml:id="t1" n="1" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t2" n="2" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t3" n="3" lemma="soi1" pos="PROper" >s</w>
                        <w xml:id="t4" n="4" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t5" n="5" lemma="revenir" pos="VERcjg" >revient</w>
                        <w xml:id="t6" n="6" lemma="par" pos="PRE" >par</w>
                        <w xml:id="t7" n="7" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t8" n="8" lemma="qui" pos="PROrel" >qui</w>
                        <w xml:id="t9" n="9" lemma="avoir" pos="VERcjg" >ot</w>
                        <w xml:id="t10" n="10" lemma="laissier" pos="VERppe" >laissié</w>
                        <w xml:id="t11" n="11" lemma="chëoir" pos="VERinf" >cheoir</w>
                        <w xml:id="t12" n="12" lemma="le" pos="DETdef" >lo</w>
                        <w xml:id="t13" n="13" lemma="glaive" pos="NOMcom" >glaive</w>
                        <w xml:id="t14" n="14" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t15" n="15" lemma="il" pos="PROper" >l</w>
                        <w xml:id="t16" n="16" lemma="aerdre" pos="VERcjg" >aert</w>
                        <w xml:id="t17" n="17" lemma="par" pos="PRE" >par</w>
                        <w xml:id="t18" n="18" lemma="le" pos="DETdef" >lo</w>
                        <w xml:id="t19" n="19" lemma="heaume" pos="NOMcom" >hiaume</w>
                        <w xml:id="t20" n="20" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t21" n="21" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t22" n="22" lemma="destre" pos="ADJqua" >destre</w>
                        <w xml:id="t23" n="23" lemma="main2" pos="NOMcom" >main</w>
                        <w xml:id="t24" n="24" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t25" n="25" lemma="sachier2" pos="VERcjg" >sache</w>
                        <w xml:id="t26" n="26" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t27" n="27" lemma="durement2" pos="ADVgen" >durement</w>
                        <w xml:id="t28" n="28" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t29" n="29" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t30" n="30" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t31" n="31" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t32" n="32" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t33" n="33" lemma="rompre" pos="VERcjg" >ront</w>
                        <w xml:id="t34" n="34" lemma="tot" pos="DETind" >toz</w>
                        <w xml:id="t35" n="35" lemma="le" pos="DETdef" >les</w>
                        <w xml:id="t36" n="36" lemma="laz1" pos="NOMcom" >laz</w>
                        <w xml:id="t37" n="37" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t38" n="38" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t39" n="39" lemma="esrachier2" pos="VERcjg" >esrache</w>
                        <w xml:id="t40" n="40" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t41" n="41" lemma="durement2" pos="ADVgen" >durement</w>
                        <w xml:id="t42" n="42" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t43" n="43" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t44" n="44" lemma="teste" pos="NOMcom" >teste</w>
                        <w xml:id="t45" n="45" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t46" n="46" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t47" n="47" lemma="il" pos="PROper" >l</w>
                        <w xml:id="t48" n="48" lemma="abatre" pos="VERcjg" >abat</w>
                        <w xml:id="t49" n="49" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t50" n="50" lemma="terre" pos="NOMcom" >terre</w>
                        <w xml:id="t51" n="51" lemma="tot" pos="ADVgen" >tot</w>
                        <w xml:id="t52" n="52" lemma="adens" pos="ADVgen" >adenz</w>
                        <w xml:id="t53" n="53" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t54" n="54" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t55" n="55" lemma="par" pos="PRE" >par</w>
                        <w xml:id="t56" n="56" lemma="poi" pos="ADVgen" >po</w>
                        <w xml:id="t57" n="57" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t58" n="58" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t59" n="59" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t60" n="60" lemma="avoir" pos="VERcjg" >a</w>
                        <w xml:id="t61" n="61" lemma="tot" pos="DETind" >totes</w>
                        <w xml:id="t62" n="62" lemma="le" pos="DETdef" >les</w>
                        <w xml:id="t63" n="63" lemma="dent2" pos="NOMcom" >danz</w>
                        <w xml:id="t64" n="64" lemma="brisier" pos="VERppe" >brisiees</w>
                        <w xml:id="t65" n="65" lemma="en1" pos="PRE" >an</w>
                        <w xml:id="t66" n="66" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t67" n="67" lemma="gole" pos="NOMcom" >gole</w>
                        <w xml:id="t68" n="68" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t69" n="69" lemma="tot" pos="DETind" >tot</w>
                        <w xml:id="t70" n="70" lemma="le" pos="DETdef" >lo</w>
                        <w xml:id="t71" n="71" lemma="nés" pos="NOMcom" >nes</w>
                        <w xml:id="t72" n="72" lemma="avoir" pos="PRE" >a</w>
                        <w xml:id="t73" n="73" lemma="escorchier" pos="VERppe" >escorchié</w>
                        <w xml:id="t74" n="74" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t75" n="75" lemma="saignier" pos="VERcjg" >saigne</w>
                        <w xml:id="t76" n="76" lemma="mout" pos="ADVgen" >mout</w>
                        <w xml:id="t77" n="77" lemma="très" pos="ADVgen" >tres</w>
                        <w xml:id="t78" n="78" lemma="durement2" pos="ADVgen" >durement</w>
                        <w xml:id="t79" n="79" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t80" n="80" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t81" n="81" lemma="descendre" pos="VERcjg" >descendist</w>
                        <w xml:id="t82" n="82" lemma="mout" pos="ADVgen" >mout</w>
                        <w xml:id="t83" n="83" lemma="volentiers" pos="ADVgen" >volentiers</w>
                        <w xml:id="t84" n="84" lemma="por2" pos="PRE" >por</w>
                        <w xml:id="t85" n="85" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t86" n="86" lemma="conquerre" pos="VERinf" >conquerre</w>
                        <w xml:id="t87" n="87" lemma="mais1" pos="CONcoo" >mais</w>
                        <w xml:id="t88" n="88" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t89" n="89" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t90" n="90" lemma="doter2" pos="VERcjg" >dotait</w>
                        <w xml:id="t91" n="91" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t92" n="92" lemma="träison" pos="NOMcom" >traïson</w>
                        <w xml:id="t93" n="93" lemma="si" pos="ADVgen" >Si</w>
                        <w xml:id="t94" n="94" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t95" n="95" lemma="descendre" pos="VERcjg" >descendié</w>
                        <w xml:id="t96" n="96" lemma="mie" pos="ADVneg" >mies</w>
                        <w xml:id="t97" n="97" lemma="ainz" pos="ADVgen" >ainz</w>
                        <w xml:id="t98" n="98" lemma="jeter" pos="VERcjg" >giete</w>
                        <w xml:id="t99" n="99" lemma="le" pos="DETdef" >lo</w>
                        <w xml:id="t100" n="100" lemma="heaume" pos="NOMcom" >hiaume</w>
                        <w xml:id="t101" n="101" lemma="tant" pos="ADVgen" >tant</w>
                        <w xml:id="t102" n="102" lemma="come1" pos="CONsub" >com</w>
                        <w xml:id="t103" n="103" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t104" n="104" lemma="pöoir" pos="VERcjg" >pot</w>
                        <w xml:id="t105" n="105" lemma="loing" pos="ADVgen" >loign</w>
                        <w xml:id="t106" n="106" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t107" n="107" lemma="metre2" pos="VERcjg" >met</w>
                        <w xml:id="t108" n="108" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t109" n="109" lemma="main2" pos="NOMcom" >main</w>
                        <w xml:id="t110" n="110" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t111" n="111" lemma="le" pos="DETdef" >l</w>
                        <w xml:id="t112" n="112" lemma="espee" pos="NOMcom" >espee</w>
                        <w xml:id="t113" n="113" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t114" n="114" lemma="venir" pos="VERcjg" >vient</w>
                        <w xml:id="t115" n="115" lemma="a3+le" pos="PRE.DETdef" >au</w>
                        <w xml:id="t116" n="116" lemma="chevalier" pos="NOMcom" >chevalier</w>
                        <w xml:id="t117" n="117" lemma="qui" pos="PROrel" >qui</w>
                        <w xml:id="t118" n="118" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t119" n="119" lemma="lever" pos="VERcjg" >levoit</w>
                        <w xml:id="t120" n="120" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t121" n="121" lemma="il" pos="PROper" >lo</w>
                        <w xml:id="t122" n="122" lemma="ferir" pos="VERcjg" >fiert</w>
                        <w xml:id="t123" n="123" lemma="de+le" pos="PRE.DETdef" >do</w>
                        <w xml:id="t124" n="124" lemma="plat" pos="NOMcom" >plat</w>
                        <w xml:id="t125" n="125" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t126" n="126" lemma="le" pos="DETdef" >l</w>
                        <w xml:id="t127" n="127" lemma="espee" pos="NOMcom" >espee</w>
                        <w xml:id="t128" n="128" lemma="par" pos="PRE" >par</w>
                        <w xml:id="t129" n="129" lemma="deus" pos="DETcar" >deus</w>
                        <w xml:id="t130" n="130" lemma="foiz" pos="NOMcom" >foiz</w>
                        <w xml:id="t131" n="131" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t132" n="132" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t133" n="133" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t134" n="134" lemma="il" pos="PROper" >l</w>
                        <w xml:id="t135" n="135" lemma="abatre" pos="VERcjg" >abat</w>
                        <w xml:id="t136" n="136" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t137" n="137" lemma="terre" pos="NOMcom" >terre</w>
                        <w xml:id="t138" n="138" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t139" n="139" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t140" n="140" lemma="saignier" pos="VERcjg" >saigne</w>
                        <w xml:id="t141" n="141" lemma="autresi" pos="ADVgen" >autresi</w>
                        <w xml:id="t142" n="142" lemma="durement2" pos="ADVgen" >durement</w>
                        <w xml:id="t143" n="143" lemma="come1" pos="CONsub" >comme</w>
                        <w xml:id="t144" n="144" lemma="se" pos="CONsub" >s</w>
                        <w xml:id="t145" n="145" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t146" n="146" lemma="estre1" pos="VERcjg" >fust</w>
                        <w xml:id="t147" n="147" lemma="navrer" pos="VERppe" >navrez</w>
                        <w xml:id="t148" n="148" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t149" n="149" lemma="mort" pos="NOMcom" >mort</w>
                        <w xml:id="t150" n="150" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t151" n="151" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t152" n="152" lemma="torner" pos="VERcjg" >torne</w>
                        <w xml:id="t153" n="153" lemma="le" pos="DETdef" >lo</w>
                        <w xml:id="t154" n="154" lemma="dos" pos="NOMcom" >dos</w>
                        <w xml:id="t155" n="155" lemma="vers2" pos="PRE" >vers</w>
                        <w xml:id="t156" n="156" lemma="le" pos="DETdef" >lo</w>
                        <w xml:id="t157" n="157" lemma="poncel1" pos="NOMcom" >poncel</w>
                        <w xml:id="t158" n="158" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t159" n="159" lemma="jurer" pos="VERcjg" >jure</w>
                        <w xml:id="t160" n="160" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t161" n="161" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t162" n="162" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t163" n="163" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t164" n="164" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t165" n="165" lemma="rendre" pos="VERcjg" >rant</w>
                        <w xml:id="t166" n="166" lemma="por2" pos="PRE" >por</w>
                        <w xml:id="t167" n="167" lemma="outrer" pos="VERppe" >outrez</w>
                        <w xml:id="t168" n="168" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t169" n="169" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t170" n="170" lemma="coper" pos="VERcjg" >copera</w>
                        <w xml:id="t171" n="171" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t172" n="172" lemma="teste" pos="NOMcom" >teste</w>
                        <w xml:id="t173" n="173" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t174" n="174" lemma="cel" pos="PROdem" >cil</w>
                        <w xml:id="t175" n="175" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t176" n="176" lemma="pöoir" pos="VERcjg" >puet</w>
                        <w xml:id="t177" n="177" lemma="mot" pos="NOMcom" >mot</w>
                        <w xml:id="t178" n="178" lemma="dire" pos="VERinf" >dire</w>
                        <w xml:id="t179" n="179" lemma="qui" pos="PROrel" >qui</w>
                        <w xml:id="t180" n="180" lemma="en1" pos="PRE" >an</w>
                        <w xml:id="t181" n="181" lemma="pasmaison" pos="NOMcom" >pasmoisons</w>
                        <w xml:id="t182" n="182" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t183" n="183" lemma="lors" pos="ADVgen" >Lors</w>
                        <w xml:id="t184" n="184" lemma="descendre" pos="VERcjg" >descent</w>
                        <w xml:id="t185" n="185" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t186" n="186" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t187" n="187" lemma="terre" pos="NOMcom" >terre</w>
                        <w xml:id="t188" n="188" lemma="tant" pos="ADVgen" >tant</w>
                        <w xml:id="t189" n="189" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t190" n="190" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t191" n="191" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t192" n="192" lemma="abatre" pos="VERcjg" >abat</w>
                        <w xml:id="t193" n="193" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t194" n="194" lemma="ventaille1" pos="NOMcom" >vantaille</w>
                        <w xml:id="t195" n="195" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t196" n="196" lemma="avaler" pos="VERcjg" >avale</w>
                        <w xml:id="t197" n="197" lemma="jusque" pos="PRE" >juque</w>
                        <w xml:id="t198" n="198" lemma="sus" pos="PRE" >sus</w>
                        <w xml:id="t199" n="199" lemma="le" pos="DETdef" >les</w>
                        <w xml:id="t200" n="200" lemma="espaule" pos="NOMcom" >espaules</w>
                        <w xml:id="t201" n="201" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t202" n="202" lemma="faire" pos="VERcjg" >fait</w>
                        <w xml:id="t203" n="203" lemma="semblant" pos="NOMcom" >sanblant</w>
                        <w xml:id="t204" n="204" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t205" n="205" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t206" n="206" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t207" n="207" lemma="voloir" pos="VERcjg" >voille</w>
                        <w xml:id="t208" n="208" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t209" n="209" lemma="teste" pos="NOMcom" >teste</w>
                        <w xml:id="t210" n="210" lemma="coper" pos="VERinf" >coper</w>
                        <w xml:id="t211" n="211" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t212" n="212" lemma="Marganor" pos="NOMpro" >Marganors</w>
                        <w xml:id="t213" n="213" lemma="i2" pos="PROadv" >i</w>
                        <w xml:id="t214" n="214" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t215" n="215" lemma="venir" pos="VERppe" >venuz</w>
                        <w xml:id="t216" n="216" lemma="poindre" pos="VERppa" >poignant</w>
                        <w xml:id="t217" n="217" lemma="tot" pos="ADVgen" >toz</w>
                        <w xml:id="t218" n="218" lemma="sans" pos="PRE" >sanz</w>
                        <w xml:id="t219" n="219" lemma="heaume" pos="NOMcom" >hiaume</w>
                        <w xml:id="t220" n="220" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t221" n="221" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t222" n="222" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t223" n="223" lemma="i2" pos="PROadv" >i</w>
                        <w xml:id="t224" n="224" lemma="voloir" pos="VERcjg" >voloit</w>
                        <w xml:id="t225" n="225" lemma="mie" pos="ADVneg" >mies</w>
                        <w xml:id="t226" n="226" lemma="venir" pos="VERinf" >venir</w>
                        <w xml:id="t227" n="227" lemma="armer" pos="VERppe" >armez</w>
                        <w xml:id="t228" n="228" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t229" n="229" lemma="le" pos="DETdef" >l</w>
                        <w xml:id="t230" n="230" lemma="on" pos="PROind" >an</w>
                        <w xml:id="t231" n="231" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t232" n="232" lemma="i2" pos="PROadv" >i</w>
                        <w xml:id="t233" n="233" lemma="penser" pos="VERcjg" >pansast</w>
                        <w xml:id="t234" n="234" lemma="träison" pos="NOMcom" >traïson</w>
                        <w xml:id="t235" n="235" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t236" n="236" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t237" n="237" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t238" n="238" lemma="assez" pos="ADVgen" >assez</w>
                        <w xml:id="t239" n="239" lemma="en2" pos="PROadv" >en</w>
                        <w xml:id="t240" n="240" lemma="avoir" pos="VERcjg" >a</w>
                        <w xml:id="t241" n="241" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t242" n="242" lemma="mais1" pos="CONcoo" >Mais</w>
                        <w xml:id="t243" n="243" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t244" n="244" lemma="ne1+il" pos="ADVneg.PROper" >no</w>
                        <w xml:id="t245" n="245" lemma="voloir" pos="VERcjg" >voloit</w>
                        <w xml:id="t246" n="246" lemma="atendre" pos="VERinf" >atandre</w>
                        <w xml:id="t247" n="247" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t248" n="248" lemma="pié" pos="NOMcom" >pié</w>
                        <w xml:id="t249" n="249" lemma="ainz" pos="ADVgen" >ainz</w>
                        <w xml:id="t250" n="250" lemma="salir2" pos="VERcjg" >saut</w>
                        <w xml:id="t251" n="251" lemma="en1+le" pos="PRE.DETdef" >o</w>
                        <w xml:id="t252" n="252" lemma="cheval" pos="NOMcom" >cheval</w>
                        <w xml:id="t253" n="253" lemma="espee" pos="NOMcom" >espee</w>
                        <w xml:id="t254" n="254" lemma="traire" pos="VERppe" >traite</w>
                        <w xml:id="t255" n="255" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t256" n="256" lemma="Marganor" pos="NOMpro" >Marganors</w>
                        <w xml:id="t257" n="257" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t258" n="258" lemma="crïer2" pos="VERcjg" >crie</w>
                        <w xml:id="t259" n="259" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t260" n="260" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t261" n="261" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t262" n="262" lemma="ocire" pos="VERcjg" >ocie</w>
                        <w xml:id="t263" n="263" lemma="mie" pos="ADVneg" >mies</w>
                        <w xml:id="t264" n="264" lemma="le" pos="DETdef" >lo</w>
                        <w xml:id="t265" n="265" lemma="chevalier" pos="NOMcom" >chevalier</w>
                        <w xml:id="t266" n="266" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t267" n="267" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t268" n="268" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t269" n="269" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t270" n="270" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t271" n="271" lemma="faire" pos="VERcjg" >fera</w>
                        <w xml:id="t272" n="272" lemma="où" pos="PROrel" >o</w>
                        <w xml:id="t273" n="273" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t274" n="274" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t275" n="275" lemma="rendre" pos="VERcjg" >randra</w>
                        <w xml:id="t276" n="276" lemma="por2" pos="PRE" >por</w>
                        <w xml:id="t277" n="277" lemma="outrer" pos="VERppe" >outrez</w>
                        <w xml:id="t278" n="278" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t279" n="279" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t280" n="280" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t281" n="281" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t282" n="282" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t283" n="283" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t284" n="284" lemma="faire" pos="VERcjg" >fera</w>
                        <w xml:id="t285" n="285" lemma="tenir1" pos="VERinf" >tenir</w>
                        <w xml:id="t286" n="286" lemma="lors" pos="ADVgen" >Lors</w>
                        <w xml:id="t287" n="287" lemma="relever" pos="VERcjg" >relieve</w>
                        <w xml:id="t288" n="288" lemma="le" pos="DETdef" >li</w>
                        <w xml:id="t289" n="289" lemma="chevalier" pos="NOMcom" >chevaliers</w>
                        <w xml:id="t290" n="290" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t291" n="291" lemma="pasmaison" pos="NOMcom" >pasmoisons</w>
                        <w xml:id="t292" n="292" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t293" n="293" lemma="salir2" pos="VERcjg" >saut</w>
                        <w xml:id="t294" n="294" lemma="sus" pos="ADVgen" >sus</w>
                        <w xml:id="t295" n="295" lemma="là" pos="ADVgen" >la</w>
                        <w xml:id="t296" n="296" lemma="où" pos="PROrel" >ou</w>
                        <w xml:id="t297" n="297" lemma="Marganor" pos="NOMpro" >Marganors</w>
                        <w xml:id="t298" n="298" lemma="parler" pos="VERcjg" >parloit</w>
                        <w xml:id="t299" n="299" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t300" n="300" lemma="Hector" pos="NOMpro" >Hestor</w>
                        <w xml:id="t301" n="301" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t302" n="302" lemma="metre2" pos="VERcjg" >met</w>
                        <w xml:id="t303" n="303" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t304" n="304" lemma="main2" pos="NOMcom" >main</w>
                        <w xml:id="t305" n="305" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t306" n="306" lemma="le" pos="DETdef" >l</w>
                        <w xml:id="t307" n="307" lemma="espee" pos="NOMcom" >espee</w>
                        <w xml:id="t308" n="308" lemma="trop" pos="ADVgen" >trop</w>
                        <w xml:id="t309" n="309" lemma="vigorosement" pos="ADVgen" >viguereusement</w>
                        <w xml:id="t310" n="310" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t311" n="311" lemma="covrir" pos="VERinf" >covre</w>
                        <w xml:id="t312" n="312" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t313" n="313" lemma="teste" pos="NOMcom" >teste</w>
                        <w xml:id="t314" n="314" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t315" n="315" lemma="son4" pos="DETpos" >son</w>
                        <w xml:id="t316" n="316" lemma="escu" pos="NOMcom" >escu</w>
                        <w xml:id="t317" n="317" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t318" n="318" lemma="soi1" pos="PROper" >s</w>
                        <w xml:id="t319" n="319" lemma="apareillier1" pos="VERcjg" >aparoille</w>
                        <w xml:id="t320" n="320" lemma="de" pos="PRE" >d</w>
                        <w xml:id="t321" n="321" lemma="assalir" pos="VERinf" >asaillir</w>
                        <w xml:id="t322" n="322" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t323" n="323" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t324" n="324" lemma="defendre" pos="VERinf" >deffandre</w>
                        <w xml:id="t325" n="325" lemma="coment1" pos="ADVsub" >Commant</w>
                        <w xml:id="t326" n="326" lemma="faire" pos="VERcjg" >fait</w>
                        <w xml:id="t327" n="327" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t328" n="328" lemma="seignor" pos="NOMcom" >sire</w>
                        <w xml:id="t329" n="329" lemma="chevalier" pos="NOMcom" >chevaliers</w>
                        <w xml:id="t330" n="330" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t331" n="331" lemma="voloir" pos="VERcjg" >volez</w>
                        <w xml:id="t332" n="332" lemma="encore" pos="ADVgen" >ancor</w>
                        <w xml:id="t333" n="333" lemma="combatre" pos="VERinf" >conbatre</w>
                        <w xml:id="t334" n="334" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t335" n="335" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t336" n="336" lemma="dire" pos="VERcjg" >dist</w>
                        <w xml:id="t337" n="337" lemma="voir" pos="ADVgen" >voires</w>
                        <w xml:id="t338" n="338" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t339" n="339" lemma="encore" pos="ADVgen" >ancor</w>
                        <w xml:id="t340" n="340" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t341" n="341" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t342" n="342" lemma="tot" pos="ADVgen" >toz</w>
                        <w xml:id="t343" n="343" lemma="fort" pos="ADJqua" >forz</w>
                        <w xml:id="t344" n="344" lemma="a3" pos="PRE" >A</w>
                        <w xml:id="t345" n="345" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t346" n="346" lemma="faire" pos="VERcjg" >fait</w>
                        <w xml:id="t347" n="347" lemma="Marganor" pos="NOMpro" >Marganorz</w>
                        <w xml:id="t348" n="348" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t349" n="349" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t350" n="350" lemma="combatre" pos="VERcjg" >conbatroiz</w>
                        <w xml:id="t351" n="351" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t352" n="352" lemma="plus" pos="ADVgen" >plus</w>
                        <w xml:id="t353" n="353" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t354" n="354" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t355" n="355" lemma="estre1" pos="VERcjg" >iestes</w>
                        <w xml:id="t356" n="356" lemma="son4" pos="DETpos" >ses</w>
                        <w xml:id="t357" n="357" lemma="prison" pos="NOMcom" >prisons</w>
                        <w xml:id="t358" n="358" lemma="o3" pos="CONcoo" >o</w>
                        <w xml:id="t359" n="359" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t360" n="360" lemma="ce1" pos="PROdem" >ce</w>
                        <w xml:id="t361" n="361" lemma="non" pos="ADVneg" >non</w>
                        <w xml:id="t362" n="362" lemma="je" pos="PROper" >ge</w>
                        <w xml:id="t363" n="363" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t364" n="364" lemma="faire" pos="VERcjg" >feroie</w>
                        <w xml:id="t365" n="365" lemma="tort2" pos="NOMcom" >tort</w>
                        <w xml:id="t366" n="366" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t367" n="367" lemma="je" pos="PROper" >ge</w>
                        <w xml:id="t368" n="368" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t369" n="369" lemma="crëanter" pos="VERcjg" >creantai</w>
                        <w xml:id="t370" n="370" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t371" n="371" lemma="je" pos="PROper" >ge</w>
                        <w xml:id="t372" n="372" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t373" n="373" lemma="faire" pos="VERcjg" >feroie</w>
                        <w xml:id="t374" n="374" lemma="tenir1" pos="VERinf" >tenir</w>
                        <w xml:id="t375" n="375" lemma="prison" pos="NOMcom" >prison</w>
                        <w xml:id="t376" n="376" lemma="prison" pos="NOMpro" >Prison</w>
                        <w xml:id="t377" n="377" lemma="faire" pos="VERcjg" >fait</w>
                        <w xml:id="t378" n="378" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t379" n="379" lemma="en1" pos="PRE" >an</w>
                        <w xml:id="t380" n="380" lemma="nom" pos="NOMcom" >non</w>
                        <w xml:id="t381" n="381" lemma="Dieu" pos="NOMpro" >Deu</w>
                        <w xml:id="t382" n="382" lemma="son4" pos="DETpos" >ses</w>
                        <w xml:id="t383" n="383" lemma="prison" pos="NOMcom" >prisons</w>
                        <w xml:id="t384" n="384" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t385" n="385" lemma="estre1" pos="VERcjg" >serai</w>
                        <w xml:id="t386" n="386" lemma="je" pos="PROper" >ge</w>
                        <w xml:id="t387" n="387" lemma="ja" pos="ADVgen" >ja</w>
                        <w xml:id="t388" n="388" lemma="tant" pos="ADVgen" >tant</w>
                        <w xml:id="t389" n="389" lemma="come1" pos="CONsub" >com</w>
                        <w xml:id="t390" n="390" lemma="je" pos="PROper" >ge</w>
                        <w xml:id="t391" n="391" lemma="je" pos="PROper" >me</w>
                        <w xml:id="t392" n="392" lemma="pöoir" pos="VERcjg" >puisse</w>
                        <w xml:id="t393" n="393" lemma="defendre" pos="VERinf" >deffandre</w>
                        <w xml:id="t394" n="394" lemma="si" pos="ADVgen" >Si</w>
                        <w xml:id="t395" n="395" lemma="estre1" pos="VERcjg" >seroiz</w>
                        <w xml:id="t396" n="396" lemma="dire" pos="VERppe" >dist</w>
                        <w xml:id="t397" n="397" lemma="Marganor" pos="NOMpro" >Marganorz</w>
                        <w xml:id="t398" n="398" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t399" n="399" lemma="je" pos="PROper" >ge</w>
                        <w xml:id="t400" n="400" lemma="il" pos="PROper" >l</w>
                        <w xml:id="t401" n="401" lemma="avoir" pos="VERcjg" >ai</w>
                        <w xml:id="t402" n="402" lemma="plevir" pos="VERppe" >plevi</w>
                        <w xml:id="t403" n="403" lemma="puis" pos="ADVgen" >Puis</w>
                        <w xml:id="t404" n="404" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t405" n="405" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t406" n="406" lemma="il" pos="PROper" >lo</w>
                        <w xml:id="t407" n="407" lemma="voloir" pos="VERcjg" >volez</w>
                        <w xml:id="t408" n="408" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t409" n="409" lemma="le" pos="DETdef" >li</w>
                        <w xml:id="t410" n="410" lemma="chevalier" pos="NOMcom" >chevaliers</w>
                        <w xml:id="t411" n="411" lemma="il" pos="PROimp" >il</w>
                        <w xml:id="t412" n="412" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t413" n="413" lemma="je" pos="PROper" >m</w>
                        <w xml:id="t414" n="414" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t415" n="415" lemma="mie" pos="ADVneg" >mies</w>
                        <w xml:id="t416" n="416" lemma="honte" pos="NOMcom" >honte</w>
                        <w xml:id="t417" n="417" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t418" n="418" lemma="vostre" pos="DETpos" >vostre</w>
                        <w xml:id="t419" n="419" lemma="volenté" pos="NOMcom" >volanté</w>
                        <w xml:id="t420" n="420" lemma="otroiier" pos="VERinf" >otroier</w>
                        <w xml:id="t421" n="421" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t422" n="422" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t423" n="423" lemma="estre1" pos="VERcjg" >iestes</w>
                        <w xml:id="t424" n="424" lemma="mon1" pos="DETpos" >mes</w>
                        <w xml:id="t425" n="425" lemma="seignor" pos="NOMcom" >sires</w>
                        <w xml:id="t426" n="426" lemma="lige" pos="ADJqua" >liges</w>
                        <w xml:id="t427" n="427" lemma="lors" pos="ADVgen" >Lors</w>
                        <w xml:id="t428" n="428" lemma="venir" pos="VERcjg" >vient</w>
                        <w xml:id="t429" n="429" lemma="avant" pos="ADVgen" >avant</w>
                        <w xml:id="t430" n="430" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t431" n="431" lemma="tant" pos="ADVgen" >tant</w>
                        <w xml:id="t432" n="432" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t433" n="433" lemma="Hector" pos="NOMpro" >Hestor</w>
                        <w xml:id="t434" n="434" lemma="son4" pos="DETpos" >s</w>
                        <w xml:id="t435" n="435" lemma="espee" pos="NOMcom" >espee</w>
                        <w xml:id="t436" n="436" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t437" n="437" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t438" n="438" lemma="il" pos="PROper" >l</w>
                        <w xml:id="t439" n="439" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t440" n="440" lemma="mener" pos="VERcjg" >moine</w>
                        <w xml:id="t441" n="441" lemma="devant" pos="PRE" >devant</w>
                        <w xml:id="t442" n="442" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t443" n="443" lemma="en1+le" pos="PRE.DETdef" >o</w>
                        <w xml:id="t444" n="444" lemma="chastel" pos="NOMcom" >chastel</w>
                        <w xml:id="t445" n="445" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t446" n="446" lemma="Marganor" pos="NOMpro" >Marganors</w>
                        <w xml:id="t447" n="447" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t448" n="448" lemma="dire" pos="VERcjg" >dist</w>
                        <w xml:id="t449" n="449" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t450" n="450" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t451" n="451" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t452" n="452" lemma="soi1" pos="PROper" >s</w>
                        <w xml:id="t453" n="453" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t454" n="454" lemma="aler" pos="VERcjg" >vont</w>
                        <w xml:id="t455" n="455" lemma="devant" pos="ADVgen" >devant</w>
                        <w xml:id="t456" n="456" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t457" n="457" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t458" n="458" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t459" n="459" lemma="avoir" pos="VERcjg" >ait</w>
                        <w xml:id="t460" n="460" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t461" n="461" lemma="droit" pos="NOMcom" >droit</w>
                        <w xml:id="t462" n="462" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t463" n="463" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t464" n="464" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t465" n="465" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t466" n="466" lemma="ne1+il" pos="ADVneg.PROper" >no</w>
                        <w xml:id="t467" n="467" lemma="faire" pos="VERcjg" >fera</w>
                        <w xml:id="t468" n="468" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t469" n="469" lemma="ainz" pos="ADVgen" >Ainz</w>
                        <w xml:id="t470" n="470" lemma="estre1" pos="VERcjg" >suis</w>
                        <w xml:id="t471" n="471" lemma="dire" pos="VERppe" >dist</w>
                        <w xml:id="t472" n="472" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t473" n="473" lemma="orendroit" pos="ADVgen" >orandroit</w>
                        <w xml:id="t474" n="474" lemma="tot" pos="ADVgen" >toz</w>
                        <w xml:id="t475" n="475" lemma="prest1" pos="ADJqua" >prez</w>
                        <w xml:id="t476" n="476" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t477" n="477" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t478" n="478" lemma="je" pos="PROper" >me</w>
                        <w xml:id="t479" n="479" lemma="voloir" pos="VERcjg" >volez</w>
                        <w xml:id="t480" n="480" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t481" n="481" lemma="rien" pos="PROind" >rien</w>
                        <w xml:id="t482" n="482" lemma="ochoisoner" pos="VERinf" >acheisoner</w>
                        <w xml:id="t483" n="483" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t484" n="484" lemma="cel" pos="PROdem" >cil</w>
                        <w xml:id="t485" n="485" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t486" n="486" lemma="metre2" pos="VERcjg" >met</w>
                        <w xml:id="t487" n="487" lemma="sus" pos="ADVgen" >sus</w>
                        <w xml:id="t488" n="488" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t489" n="489" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t490" n="490" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t491" n="491" lemma="avoir" pos="VERcjg" >a</w>
                        <w xml:id="t492" n="492" lemma="navrer" pos="VERppe" >navré</w>
                        <w xml:id="t493" n="493" lemma="son4" pos="DETpos" >ses</w>
                        <w xml:id="t494" n="494" lemma="ome" pos="NOMcom" >homes</w>
                        <w xml:id="t495" n="495" lemma="en1" pos="PRE" >an</w>
                        <w xml:id="t496" n="496" lemma="droit" pos="ADJqua" >droites</w>
                        <w xml:id="t497" n="497" lemma="trieue" pos="NOMcom" >trives</w>
                        <w xml:id="t498" n="498" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t499" n="499" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t500" n="500" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t501" n="501" lemma="avoir" pos="VERcjg" >avoit</w>
                        <w xml:id="t502" n="502" lemma="crëanter" pos="VERppe" >creanté</w>
                        <w xml:id="t503" n="503" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t504" n="504" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t505" n="505" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t506" n="506" lemma="avoir" pos="VERcjg" >avoient</w>
                        <w xml:id="t507" n="507" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t508" n="508" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t509" n="509" lemma="garde" pos="NOMcom" >garde</w>
                        <w xml:id="t510" n="510" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t511" n="511" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t512" n="512" lemma="il" pos="DETdef" >li</w>
                        <w xml:id="t513" n="513" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t514" n="514" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t515" n="515" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t516" n="516" lemma="ne1+il" pos="ADVneg.PROper" >no</w>
                        <w xml:id="t517" n="517" lemma="crëanter" pos="VERcjg" >creanta</w>
                        <w xml:id="t518" n="518" lemma="onque" pos="ADVgen" >onques</w>
                        <w xml:id="t519" n="519" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t520" n="520" lemma="se" pos="CONsub" >s</w>
                        <w xml:id="t521" n="521" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t522" n="522" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t523" n="523" lemma="avoir" pos="VERcjg" >aüst</w>
                        <w xml:id="t524" n="524" lemma="crëanter" pos="VERppe" >creanté</w>
                        <w xml:id="t525" n="525" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t526" n="526" lemma="il" pos="PROper" >l</w>
                        <w xml:id="t527" n="527" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t528" n="528" lemma="avoir" pos="VERcjg" >aüst</w>
                        <w xml:id="t529" n="529" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t530" n="530" lemma="mie" pos="ADVneg" >mies</w>
                        <w xml:id="t531" n="531" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t532" n="532" lemma="tort2" pos="NOMcom" >tort</w>
                        <w xml:id="t533" n="533" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t534" n="534" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t535" n="535" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t536" n="536" lemma="mener" pos="VERcjg" >menoient</w>
                        <w xml:id="t537" n="537" lemma="deslëaument" pos="ADVgen" >desleiaument</w>
                        <w xml:id="t538" n="538" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t539" n="539" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t540" n="540" lemma="mais1" pos="CONcoo" >Mais</w>
                        <w xml:id="t541" n="541" lemma="je" pos="PROper" >ge</w>
                        <w xml:id="t542" n="542" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t543" n="543" lemma="cuidier1" pos="VERcjg" >cuit</w>
                        <w xml:id="t544" n="544" lemma="mie" pos="ADVneg" >mies</w>
                        <w xml:id="t545" n="545" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t546" n="546" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t547" n="547" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t548" n="548" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t549" n="549" lemma="il" pos="PROper" >lo</w>
                        <w xml:id="t550" n="550" lemma="faire" pos="VERcjg" >feïssent</w>
                        <w xml:id="t551" n="551" lemma="par" pos="PRE" >par</w>
                        <w xml:id="t552" n="552" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t553" n="553" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t554" n="554" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t555" n="555" lemma="Dieu" pos="NOMpro" >Dex</w>
                        <w xml:id="t556" n="556" lemma="je" pos="PROper" >m</w>
                        <w xml:id="t557" n="557" lemma="aidier" pos="VERcjg" >aïst</w>
                        <w xml:id="t558" n="558" lemma="je" pos="PROper" >ge</w>
                        <w xml:id="t559" n="559" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t560" n="560" lemma="tenir1" pos="VERcjg" >taig</w>
                        <w xml:id="t561" n="561" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t562" n="562" lemma="lëal" pos="ADJqua" >leial</w>
                        <w xml:id="t563" n="563" lemma="chevalier" pos="NOMcom" >chevalier</w>
                        <w xml:id="t564" n="564" lemma="por2" pos="PRE" >por</w>
                        <w xml:id="t565" n="565" lemma="ce1" pos="PROdem" >ce</w>
                        <w xml:id="t566" n="566" lemma="que2" pos="CONsub" >que</w>
                        <w xml:id="t567" n="567" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t568" n="568" lemma="avoir" pos="VERcjg" >avez</w>
                        <w xml:id="t569" n="569" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t570" n="570" lemma="tenir1" pos="VERinf" >tenir</w>
                        <w xml:id="t571" n="571" lemma="a3+le" pos="PRE.DETdef" >au</w>
                        <w xml:id="t572" n="572" lemma="chevalier" pos="NOMcom" >chevalier</w>
                        <w xml:id="t573" n="573" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t574" n="574" lemma="covenance" pos="NOMcom" >covenance</w>
                        <w xml:id="t575" n="575" lemma="que2" pos="PROrel" >que</w>
                        <w xml:id="t576" n="576" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t577" n="577" lemma="je" pos="PROper" >m</w>
                        <w xml:id="t578" n="578" lemma="avoir" pos="VERcjg" >aüstes</w>
                        <w xml:id="t579" n="579" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t580" n="580" lemma="totevoies" pos="ADVgen" >totesvoies</w>
                        <w xml:id="t581" n="581" lemma="dire" pos="VERcjg" >dist</w>
                        <w xml:id="t582" n="582" lemma="Marganor" pos="NOMpro" >Marganorz</w>
                        <w xml:id="t583" n="583" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t584" n="584" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t585" n="585" lemma="soi1" pos="PROper" >s</w>
                        <w xml:id="t586" n="586" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t587" n="587" lemma="venir" pos="VERcjg" >veigne</w>
                        <w xml:id="t588" n="588" lemma="en1" pos="PRE" >en</w>
                        <w xml:id="t589" n="589" lemma="son4" pos="DETpos" >sa</w>
                        <w xml:id="t590" n="590" lemma="prison" pos="NOMcom" >prison</w>
                        <w xml:id="t591" n="591" lemma="come1" pos="CONsub" >comme</w>
                        <w xml:id="t592" n="592" lemma="enchëoir" pos="VERppe" >anchaüz</w>
                        <w xml:id="t593" n="593" lemma="où" pos="PROrel" >o</w>
                        <w xml:id="t594" n="594" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t595" n="595" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t596" n="596" lemma="defendre" pos="VERcjg" >deffande</w>
                        <w xml:id="t597" n="597" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t598" n="598" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t599" n="599" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t600" n="600" lemma="il" pos="PROper" >l</w>
                        <w xml:id="t601" n="601" lemma="avoir" pos="VERcjg" >ait</w>
                        <w xml:id="t602" n="602" lemma="mauvaisement" pos="ADVgen" >mauvaissement</w>
                        <w xml:id="t603" n="603" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t604" n="604" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t605" n="605" lemma="totevoies" pos="ADVgen" >totesvoie</w>
                        <w xml:id="t606" n="606" lemma="il" pos="PROper" >l</w>
                        <w xml:id="t607" n="607" lemma="apeler" pos="VERcjg" >apelle</w>
                        <w xml:id="t608" n="608" lemma="cel" pos="PROdem" >cil</w>
                        <w xml:id="t609" n="609" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t610" n="610" lemma="foimentie" pos="NOMcom" >foimantie</w>
                        <w xml:id="t611" n="611" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t612" n="612" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t613" n="613" lemma="deslëauté" pos="NOMcom" >desleiauté</w>
                        <w xml:id="t614" n="614" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t615" n="615" lemma="pré" pos="ADJqua" >prez</w>
                        <w xml:id="t616" n="616" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t617" n="617" lemma="de+le" pos="PRE.PROper" >dou</w>
                        <w xml:id="t618" n="618" lemma="mostrer" pos="VERinf" >mostrer</w>
                        <w xml:id="t619" n="619" lemma="contre" pos="PRE" >contre</w>
                        <w xml:id="t620" n="620" lemma="son4" pos="DETpos" >son</w>
                        <w xml:id="t621" n="621" lemma="cors1" pos="NOMcom" >cors</w>
                        <w xml:id="t622" n="622" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t623" n="623" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t624" n="624" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t625" n="625" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t626" n="626" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t627" n="627" lemma="il" pos="PROimp" >il</w>
                        <w xml:id="t628" n="628" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t629" n="629" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t630" n="630" lemma="cort1" pos="NOMcom" >corz</w>
                        <w xml:id="t631" n="631" lemma="en1+le" pos="PRE.DETdef" >ou</w>
                        <w xml:id="t632" n="632" lemma="monde1" pos="NOMcom" >monde</w>
                        <w xml:id="t633" n="633" lemma="où" pos="PROrel" >ou</w>
                        <w xml:id="t634" n="634" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t635" n="635" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t636" n="636" lemma="soi1" pos="PROper" >s</w>
                        <w xml:id="t637" n="637" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t638" n="638" lemma="oser" pos="VERcjg" >osast</w>
                        <w xml:id="t639" n="639" lemma="bien1" pos="ADVgen" >bien</w>
                        <w xml:id="t640" n="640" lemma="defendre" pos="VERinf" >deffandre</w>
                        <w xml:id="t641" n="641" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t642" n="642" lemma="le" pos="DETdef" >li</w>
                        <w xml:id="t643" n="643" lemma="seignor" pos="NOMcom" >sires</w>
                        <w xml:id="t644" n="644" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t645" n="645" lemma="le" pos="DETdef" >l</w>
                        <w xml:id="t646" n="646" lemma="estroit" pos="ADJqua" >Estroite</w>
                        <w xml:id="t647" n="647" lemma="marche1" pos="NOMcom" >Marche</w>
                        <w xml:id="t648" n="648" lemma="dire" pos="VERcjg" >dist</w>
                        <w xml:id="t649" n="649" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t650" n="650" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t651" n="651" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t652" n="652" lemma="il" pos="PROper" >l</w>
                        <w xml:id="t653" n="653" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t654" n="654" lemma="croire" pos="VERcjg" >croit</w>
                        <w xml:id="t655" n="655" lemma="ja" pos="ADVgen" >ja</w>
                        <w xml:id="t656" n="656" lemma="iluec" pos="ADVgen" >illueques</w>
                        <w xml:id="t657" n="657" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t658" n="658" lemma="soi1" pos="PROper" >s</w>
                        <w xml:id="t659" n="659" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t660" n="660" lemma="defendre" pos="VERcjg" >deffandra</w>
                        <w xml:id="t661" n="661" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t662" n="662" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t663" n="663" lemma="force2" pos="NOMcom" >force</w>
                        <w xml:id="t664" n="664" lemma="estre1" pos="VERcjg" >estoit</w>
                        <w xml:id="t665" n="665" lemma="Marganor" pos="NOMpro" >Marganor</w>
                        <w xml:id="t666" n="666" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t667" n="667" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t668" n="668" lemma="avoir" pos="VERcjg" >aiez</w>
                        <w xml:id="t669" n="669" lemma="garde" pos="NOMcom" >garde</w>
                        <w xml:id="t670" n="670" lemma="faire" pos="VERcjg" >fait</w>
                        <w xml:id="t671" n="671" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t672" n="672" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t673" n="673" lemma="Hector" pos="NOMpro" >Hestor</w>
                        <w xml:id="t674" n="674" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t675" n="675" lemma="nos1" pos="PROper" >nos</w>
                        <w xml:id="t676" n="676" lemma="avoir" pos="VERcjg" >avons</w>
                        <w xml:id="t677" n="677" lemma="bien1" pos="ADVgen" >bien</w>
                        <w xml:id="t678" n="678" lemma="vëoir" pos="VERppe" >veü</w>
                        <w xml:id="t679" n="679" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t680" n="680" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t681" n="681" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t682" n="682" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t683" n="683" lemma="avoir" pos="VERcjg" >avez</w>
                        <w xml:id="t684" n="684" lemma="faire" pos="VERppe" >faite</w>
                        <w xml:id="t685" n="685" lemma="nul" pos="DETind" >nule</w>
                        <w xml:id="t686" n="686" lemma="deslëauté" pos="NOMcom" >desleiauté</w>
                        <w xml:id="t687" n="687" lemma="il" pos="PROimp" >Il</w>
                        <w xml:id="t688" n="688" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t689" n="689" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t690" n="690" lemma="cort1" pos="NOMcom" >corz</w>
                        <w xml:id="t691" n="691" lemma="en1+le" pos="PRE.DETdef" >o</w>
                        <w xml:id="t692" n="692" lemma="monde1" pos="NOMcom" >monde</w>
                        <w xml:id="t693" n="693" lemma="où" pos="PROrel" >o</w>
                        <w xml:id="t694" n="694" lemma="nos1" pos="PROper" >nos</w>
                        <w xml:id="t695" n="695" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t696" n="696" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t697" n="697" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t698" n="698" lemma="porter" pos="VERcjg" >portesiens</w>
                        <w xml:id="t699" n="699" lemma="tesmoin" pos="NOMcom" >tesmoign</w>
                        <w xml:id="t700" n="700" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t701" n="701" lemma="se" pos="CONsub" >s</w>
                        <w xml:id="t702" n="702" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t703" n="703" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t704" n="704" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t705" n="705" lemma="voloir" pos="VERcjg" >viaut</w>
                        <w xml:id="t706" n="706" lemma="apeler" pos="VERinf" >apeler</w>
                        <w xml:id="t707" n="707" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t708" n="708" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t709" n="709" lemma="en2" pos="PROadv" >en</w>
                        <w xml:id="t710" n="710" lemma="apeler" pos="NOMcom" >apiaut</w>
                        <w xml:id="t711" n="711" lemma="en1" pos="PRE" >an</w>
                        <w xml:id="t712" n="712" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t713" n="713" lemma="maison" pos="NOMcom" >maison</w>
                        <w xml:id="t714" n="714" lemma="le" pos="DETdef" >lo</w>
                        <w xml:id="t715" n="715" lemma="roi2" pos="NOMcom" >roi</w>
                        <w xml:id="t716" n="716" lemma="Artu" pos="NOMpro" >Artu</w>
                        <w xml:id="t717" n="717" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t718" n="718" lemma="Marganor" pos="NOMpro" >Marganors</w>
                        <w xml:id="t719" n="719" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t720" n="720" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t721" n="721" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t722" n="722" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t723" n="723" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t724" n="724" lemma="soi1" pos="PROper" >s</w>
                        <w xml:id="t725" n="725" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t726" n="726" lemma="defendre" pos="VERcjg" >deffant</w>
                        <w xml:id="t727" n="727" lemma="ci" pos="ADVgen" >ci</w>
                        <w xml:id="t728" n="728" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t729" n="729" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t730" n="730" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t731" n="731" lemma="cort1" pos="NOMcom" >corz</w>
                        <w xml:id="t732" n="732" lemma="en1+le" pos="PRE.DETdef" >el</w>
                        <w xml:id="t733" n="733" lemma="monde1" pos="NOMcom" >mont</w>
                        <w xml:id="t734" n="734" lemma="où" pos="PROrel" >o</w>
                        <w xml:id="t735" n="735" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t736" n="736" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t737" n="737" lemma="il" pos="PROper" >l</w>
                        <w xml:id="t738" n="738" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t739" n="739" lemma="aler" pos="VERcjg" >alast</w>
                        <w xml:id="t740" n="740" lemma="apeler" pos="VERinf" >apeler</w>
                        <w xml:id="t741" n="741" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t742" n="742" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t743" n="743" lemma="fausseté" pos="NOMcom" >fauseté</w>
                        <w xml:id="t744" n="744" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t745" n="745" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t746" n="746" lemma="deslëauté" pos="NOMcom" >desleiauté</w>
                        <w xml:id="t747" n="747" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t748" n="748" lemma="lors" pos="ADVgen" >lors</w>
                        <w xml:id="t749" n="749" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t750" n="750" lemma="avoir" pos="VERcjg" >avra</w>
                        <w xml:id="t751" n="751" lemma="plus" pos="ADVgen" >plus</w>
                        <w xml:id="t752" n="752" lemma="honte" pos="NOMcom" >honte</w>
                        <w xml:id="t753" n="753" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t754" n="754" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t755" n="755" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t756" n="756" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t757" n="757" lemma="ja" pos="ADVgen" >ja</w>
                        <w xml:id="t758" n="758" lemma="Damnedeu" pos="NOMpro" >Damedex</w>
                        <w xml:id="t759" n="759" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t760" n="760" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t761" n="761" lemma="aidier" pos="VERcjg" >aïst</w>
                        <w xml:id="t762" n="762" lemma="cant1" pos="CONsub" >qant</w>
                        <w xml:id="t763" n="763" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t764" n="764" lemma="ja" pos="ADVgen" >ja</w>
                        <w xml:id="t765" n="765" lemma="en1" pos="PRE" >an</w>
                        <w xml:id="t766" n="766" lemma="autre" pos="DETind" >autre</w>
                        <w xml:id="t767" n="767" lemma="lieu" pos="NOMcom" >leu</w>
                        <w xml:id="t768" n="768" lemma="il" pos="PROper" >l</w>
                        <w xml:id="t769" n="769" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t770" n="770" lemma="aler" pos="VERcjg" >ira</w>
                        <w xml:id="t771" n="771" lemma="apeler" pos="VERinf" >apeler</w>
                        <w xml:id="t772" n="772" lemma="il" pos="PROimp" >il</w>
                        <w xml:id="t773" n="773" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t774" n="774" lemma="prest1" pos="ADJqua" >prez</w>
                        <w xml:id="t775" n="775" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t776" n="776" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t777" n="777" lemma="soi1" pos="PROper" >s</w>
                        <w xml:id="t778" n="778" lemma="en2" pos="PROadv" >en</w>
                        <w xml:id="t779" n="779" lemma="defendre" pos="VERcjg" >deffande</w>
                        <w xml:id="t780" n="780" lemma="se" pos="CONsub" >Se</w>
                        <w xml:id="t781" n="781" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t782" n="782" lemma="je" pos="PROper" >m</w>
                        <w xml:id="t783" n="783" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t784" n="784" lemma="croire" pos="VERppe" >creez</w>
                        <w xml:id="t785" n="785" lemma="dire" pos="VERcjg" >dist</w>
                        <w xml:id="t786" n="786" lemma="le" pos="DETdef" >li</w>
                        <w xml:id="t787" n="787" lemma="seignor" pos="NOMcom" >sires</w>
                        <w xml:id="t788" n="788" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t789" n="789" lemma="le" pos="DETdef" >l</w>
                        <w xml:id="t790" n="790" lemma="estroit" pos="ADJqua" >Estroite</w>
                        <w xml:id="t791" n="791" lemma="marche1" pos="NOMcom" >Marche</w>
                        <w xml:id="t792" n="792" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t793" n="793" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t794" n="794" lemma="il" pos="PROper" >lo</w>
                        <w xml:id="t795" n="795" lemma="faire" pos="VERcjg" >feroiz</w>
                        <w xml:id="t796" n="796" lemma="mie" pos="ADVneg" >mies</w>
                        <w xml:id="t797" n="797" lemma="issi" pos="ADVgen" >issi</w>
                        <w xml:id="t798" n="798" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t799" n="799" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t800" n="800" lemma="avoir" pos="VERcjg" >avez</w>
                        <w xml:id="t801" n="801" lemma="ui" pos="ADVgen" >hui</w>
                        <w xml:id="t802" n="802" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t803" n="803" lemma="assez" pos="ADVgen" >assez</w>
                        <w xml:id="t804" n="804" lemma="de" pos="PRE" >d</w>
                        <w xml:id="t805" n="805" lemma="arme" pos="NOMcom" >armes</w>
                        <w xml:id="t806" n="806" lemma="mais1" pos="CONcoo" >Mais</w>
                        <w xml:id="t807" n="807" lemma="demain" pos="ADVgen" >demain</w>
                        <w xml:id="t808" n="808" lemma="estre1" pos="VERcjg" >soit</w>
                        <w xml:id="t809" n="809" lemma="apareillier1" pos="VERppe" >apareilliez</w>
                        <w xml:id="t810" n="810" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t811" n="811" lemma="son4" pos="DETpos" >sa</w>
                        <w xml:id="t812" n="812" lemma="bataille" pos="NOMcom" >bataille</w>
                        <w xml:id="t813" n="813" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t814" n="814" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t815" n="815" lemma="aussi" pos="ADVgen" >ausi</w>
                        <w xml:id="t816" n="816" lemma="puis" pos="ADVgen" >puis</w>
                        <w xml:id="t817" n="817" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t818" n="818" lemma="par" pos="PRE" >par</w>
                        <w xml:id="t819" n="819" lemma="bataille" pos="NOMcom" >bataille</w>
                        <w xml:id="t820" n="820" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t821" n="821" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t822" n="822" lemma="voloir" pos="VERcjg" >volez</w>
                        <w xml:id="t823" n="823" lemma="escuser2" pos="VERinf" >escuser</w>
                        <w xml:id="t824" n="824" lemma="non" pos="ADVneg" >Non</w>
                        <w xml:id="t825" n="825" lemma="faire" pos="VERcjg" >ferai</w>
                        <w xml:id="t826" n="826" lemma="dire" pos="VERppe" >dist</w>
                        <w xml:id="t827" n="827" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t828" n="828" lemma="il" pos="PROimp" >Il</w>
                        <w xml:id="t829" n="829" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t830" n="830" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t831" n="831" lemma="deviser" pos="VERcjg" >devisera</w>
                        <w xml:id="t832" n="832" lemma="ja" pos="ADVgen" >ja</w>
                        <w xml:id="t833" n="833" lemma="rien" pos="NOMcom" >rien</w>
                        <w xml:id="t834" n="834" lemma="que1" pos="CONsub" >que</w>
                        <w xml:id="t835" n="835" lemma="je" pos="PROper" >ge</w>
                        <w xml:id="t836" n="836" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t837" n="837" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t838" n="838" lemma="faire" pos="VERcjg" >face</w>
                        <w xml:id="t839" n="839" lemma="ne2" pos="CONcoo" >ne</w>
                        <w xml:id="t840" n="840" lemma="je" pos="PROper" >ge</w>
                        <w xml:id="t841" n="841" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t842" n="842" lemma="avoir" pos="VERcjg" >ai</w>
                        <w xml:id="t843" n="843" lemma="rien" pos="PROind" >rien</w>
                        <w xml:id="t844" n="844" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t845" n="845" lemma="de" pos="PRE" >d</w>
                        <w xml:id="t846" n="846" lemma="arme" pos="NOMcom" >armes</w>
                        <w xml:id="t847" n="847" lemma="qui" pos="PROrel" >qui</w>
                        <w xml:id="t848" n="848" lemma="je" pos="PROper" >me</w>
                        <w xml:id="t849" n="849" lemma="grever" pos="VERcjg" >griet</w>
                        <w xml:id="t850" n="850" lemma="certes" pos="ADVgen" >Certes</w>
                        <w xml:id="t851" n="851" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t852" n="852" lemma="le" pos="DETdef" >li</w>
                        <w xml:id="t853" n="853" lemma="seignor" pos="NOMcom" >sires</w>
                        <w xml:id="t854" n="854" lemma="je" pos="PROper" >ge</w>
                        <w xml:id="t855" n="855" lemma="je" pos="PROper" >me</w>
                        <w xml:id="t856" n="856" lemma="criembre" pos="VERcjg" >criem</w>
                        <w xml:id="t857" n="857" lemma="mout" pos="ADVgen" >mout</w>
                        <w xml:id="t858" n="858" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t859" n="859" lemma="träison" pos="NOMcom" >traïson</w>
                        <w xml:id="t860" n="860" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t861" n="861" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t862" n="862" lemma="estre1" pos="VERcjg" >seroit</w>
                        <w xml:id="t863" n="863" lemma="mout" pos="ADVgen" >mout</w>
                        <w xml:id="t864" n="864" lemma="grant" pos="ADJqua" >granz</w>
                        <w xml:id="t865" n="865" lemma="damage" pos="NOMcom" >domage</w>
                        <w xml:id="t866" n="866" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t867" n="867" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t868" n="868" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t869" n="869" lemma="avoir" pos="VERcjg" >avoient</w>
                        <w xml:id="t870" n="870" lemma="en1" pos="PRE" >an</w>
                        <w xml:id="t871" n="871" lemma="prison" pos="NOMcom" >prison</w>
                        <w xml:id="t872" n="872" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t873" n="873" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t874" n="874" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t875" n="875" lemma="acointier" pos="VERcjg" >acoint</w>
                        <w xml:id="t876" n="876" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t877" n="877" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t878" n="878" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t879" n="879" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t880" n="880" lemma="combatre" pos="VERppe" >conbatez</w>
                        <w xml:id="t881" n="881" lemma="là" pos="ADVgen" >la</w>
                        <w xml:id="t882" n="882" lemma="fors1" pos="ADVgen" >fors</w>
                        <w xml:id="t883" n="883" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t884" n="884" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t885" n="885" lemma="pöoir" pos="VERcjg" >porra</w>
                        <w xml:id="t886" n="886" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t887" n="887" lemma="par" pos="PRE" >par</w>
                        <w xml:id="t888" n="888" lemma="son4" pos="DETpos" >ses</w>
                        <w xml:id="t889" n="889" lemma="gent1" pos="NOMcom" >genz</w>
                        <w xml:id="t890" n="890" lemma="o3" pos="CONcoo" >o</w>
                        <w xml:id="t891" n="891" lemma="prendre" pos="VERinf" >panre</w>
                        <w xml:id="t892" n="892" lemma="o3" pos="CONcoo" >o</w>
                        <w xml:id="t893" n="893" lemma="veintre" pos="VERinf" >vaintre</w>
                        <w xml:id="t894" n="894" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t895" n="895" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t896" n="896" lemma="voloir" pos="VERcjg" >velt</w>
                        <w xml:id="t897" n="897" lemma="oster2" pos="VERppe" >Ostez</w>
                        <w xml:id="t898" n="898" lemma="seignor" pos="NOMcom" >sire</w>
                        <w xml:id="t899" n="899" lemma="faire" pos="VERppe" >fait</w>
                        <w xml:id="t900" n="900" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t901" n="901" lemma="il" pos="PROper" >Il</w>
                        <w xml:id="t902" n="902" lemma="ne1+il" pos="ADVneg.PROper" >nel</w>
                        <w xml:id="t903" n="903" lemma="faire" pos="VERcjg" >feroit</w>
                        <w xml:id="t904" n="904" lemma="mie" pos="ADVneg" >mies</w>
                        <w xml:id="t905" n="905" lemma="donc" pos="ADVgen" >Donc</w>
                        <w xml:id="t906" n="906" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t907" n="907" lemma="vëoir" pos="VERcjg" >veïstes</w>
                        <w xml:id="t908" n="908" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t909" n="909" lemma="faire" pos="VERcjg" >fait</w>
                        <w xml:id="t910" n="910" lemma="le" pos="DETdef" >li</w>
                        <w xml:id="t911" n="911" lemma="seignor" pos="NOMcom" >sires</w>
                        <w xml:id="t912" n="912" lemma="que2" pos="CONsub" >qu</w>
                        <w xml:id="t913" n="913" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t914" n="914" lemma="faire" pos="VERcjg" >fist</w>
                        <w xml:id="t915" n="915" lemma="depecier" pos="VERinf" >depecier</w>
                        <w xml:id="t916" n="916" lemma="le" pos="DETdef" >lo</w>
                        <w xml:id="t917" n="917" lemma="pont" pos="NOMcom" >pont</w>
                        <w xml:id="t918" n="918" lemma="por2" pos="PRE" >por</w>
                        <w xml:id="t919" n="919" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t920" n="920" lemma="retenir" pos="VERinf" >retenir</w>
                        <w xml:id="t921" n="921" lemma="en1" pos="PRE" >An</w>
                        <w xml:id="t922" n="922" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t923" n="923" lemma="fin1" pos="NOMcom" >fin</w>
                        <w xml:id="t924" n="924" lemma="avoir" pos="VERcjg" >ai</w>
                        <w xml:id="t925" n="925" lemma="je" pos="PROper" >ge</w>
                        <w xml:id="t926" n="926" lemma="pëor" pos="NOMcom" >paor</w>
                        <w xml:id="t927" n="927" lemma="de" pos="PRE" >d</w>
                        <w xml:id="t928" n="928" lemma="autre" pos="DETind" >autre</w>
                        <w xml:id="t929" n="929" lemma="engin" pos="NOMcom" >angin</w>
                        <w xml:id="t930" n="930" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t931" n="931" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t932" n="932" lemma="nos1" pos="PROper" >nos</w>
                        <w xml:id="t933" n="933" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t934" n="934" lemma="pöoir" pos="VERcjg" >porriez</w>
                        <w xml:id="t935" n="935" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t936" n="936" lemma="avoir" pos="VERinf" >avoir</w>
                        <w xml:id="t937" n="937" lemma="secors" pos="NOMcom" >secors</w>
                        <w xml:id="t938" n="938" lemma="car" pos="CONcoo" >car</w>
                        <w xml:id="t939" n="939" lemma="il" pos="PROimp" >il</w>
                        <w xml:id="t940" n="940" lemma="avoir" pos="VERcjg" >a</w>
                        <w xml:id="t941" n="941" lemma="trop" pos="ADVgen" >trop</w>
                        <w xml:id="t942" n="942" lemma="grant" pos="ADJqua" >grant</w>
                        <w xml:id="t943" n="943" lemma="gent1" pos="NOMcom" >gent</w>
                        <w xml:id="t944" n="944" lemma="mais1" pos="CONcoo" >Mais</w>
                        <w xml:id="t945" n="945" lemma="je" pos="PROper" >ge</w>
                        <w xml:id="t946" n="946" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t947" n="947" lemma="enseignier" pos="VERcjg" >anseignerai</w>
                        <w xml:id="t948" n="948" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t949" n="949" lemma="combatre" pos="VERinf" >conbatre</w>
                        <w xml:id="t950" n="950" lemma="en1" pos="PRE" >an</w>
                        <w xml:id="t951" n="951" lemma="tel" pos="DETind" >tel</w>
                        <w xml:id="t952" n="952" lemma="maniere" pos="NOMcom" >maniere</w>
                        <w xml:id="t953" n="953" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t954" n="954" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t955" n="955" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t956" n="956" lemma="avoir" pos="VERcjg" >avroiz</w>
                        <w xml:id="t957" n="957" lemma="garde" pos="NOMcom" >garde</w>
                        <w xml:id="t958" n="958" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t959" n="959" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t960" n="960" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t961" n="961" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t962" n="962" lemma="estre1" pos="VERcjg" >est</w>
                        <w xml:id="t963" n="963" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t964" n="964" lemma="un" pos="PROind" >uns</w>
                        <w xml:id="t965" n="965" lemma="de+le" pos="PRE.DETdef" >des</w>
                        <w xml:id="t966" n="966" lemma="meillor" pos="ADJqua" >meillors</w>
                        <w xml:id="t967" n="967" lemma="chevalier" pos="NOMcom" >chevaliers</w>
                        <w xml:id="t968" n="968" lemma="de+le" pos="PRE.DETdef" >do</w>
                        <w xml:id="t969" n="969" lemma="monde1" pos="NOMcom" >monde</w>
                        <w xml:id="t970" n="970" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t971" n="971" lemma="qui" pos="PROrel" >qui</w>
                        <w xml:id="t972" n="972" lemma="plus" pos="ADVgen" >plus</w>
                        <w xml:id="t973" n="973" lemma="savoir" pos="VERcjg" >set</w>
                        <w xml:id="t974" n="974" lemma="de" pos="PRE" >d</w>
                        <w xml:id="t975" n="975" lemma="arme" pos="NOMcom" >armes</w>
                        <w xml:id="t976" n="976" lemma="mais1" pos="CONcoo" >Mais</w>
                        <w xml:id="t977" n="977" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t978" n="978" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t979" n="979" lemma="faire" pos="VERcjg" >fait</w>
                        <w xml:id="t980" n="980" lemma="tot" pos="DETind" >tote</w>
                        <w xml:id="t981" n="981" lemma="son4" pos="ADJpos" >sa</w>
                        <w xml:id="t982" n="982" lemma="gent1" pos="NOMcom" >gent</w>
                        <w xml:id="t983" n="983" lemma="desarmer" pos="VERinf" >desarmer</w>
                        <w xml:id="t984" n="984" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t985" n="985" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t986" n="986" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t987" n="987" lemma="afïer" pos="VERcjg" >afit</w>
                        <w xml:id="t988" n="988" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t989" n="989" lemma="ja" pos="ADVgen" >ja</w>
                        <w xml:id="t990" n="990" lemma="nul" pos="PROind" >nus</w>
                        <w xml:id="t991" n="991" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t992" n="992" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t993" n="993" lemma="movoir" pos="VERcjg" >movra</w>
                        <w xml:id="t994" n="994" lemma="por2" pos="PRE" >por</w>
                        <w xml:id="t995" n="995" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t996" n="996" lemma="secorre1" pos="VERinf" >secorre</w>
                        <w xml:id="t997" n="997" lemma="ne2" pos="CONcoo" >ne</w>
                        <w xml:id="t998" n="998" lemma="por2" pos="PRE" >por</w>
                        <w xml:id="t999" n="999" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t1000" n="1000" lemma="encombrer" pos="VERinf" >encombrer</w>
                        <w xml:id="t1001" n="1001" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1002" n="1002" lemma="puis" pos="ADVgen" >puis</w>
                        <w xml:id="t1003" n="1003" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t1004" n="1004" lemma="combatre" pos="VERcjg" >combatez</w>
                        <w xml:id="t1005" n="1005" lemma="en1" pos="PRE" >en</w>
                        <w xml:id="t1006" n="1006" lemma="cest" pos="DETdem" >ceste</w>
                        <w xml:id="t1007" n="1007" lemma="chauciee" pos="NOMcom" >chauciee</w>
                        <w xml:id="t1008" n="1008" lemma="entre2" pos="PRE" >antre</w>
                        <w xml:id="t1009" n="1009" lemma="ce2" pos="DETdem" >ce</w>
                        <w xml:id="t1010" n="1010" lemma="grant" pos="ADJqua" >grant</w>
                        <w xml:id="t1011" n="1011" lemma="pont" pos="NOMcom" >pont</w>
                        <w xml:id="t1012" n="1012" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1013" n="1013" lemma="ce2" pos="DETdem" >ce</w>
                        <w xml:id="t1014" n="1014" lemma="poncel1" pos="NOMcom" >poncel</w>
                        <w xml:id="t1015" n="1015" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1016" n="1016" lemma="come1" pos="CONsub" >com</w>
                        <w xml:id="t1017" n="1017" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t1018" n="1018" lemma="estre1" pos="VERcjg" >sera</w>
                        <w xml:id="t1019" n="1019" lemma="deça" pos="ADVgen" >deça</w>
                        <w xml:id="t1020" n="1020" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t1021" n="1021" lemma="estre1" pos="VERcjg" >soit</w>
                        <w xml:id="t1022" n="1022" lemma="le" pos="DETdef" >li</w>
                        <w xml:id="t1023" n="1023" lemma="poncel1" pos="NOMcom" >ponciaus</w>
                        <w xml:id="t1024" n="1024" lemma="tot" pos="ADVgen" >toz</w>
                        <w xml:id="t1025" n="1025" lemma="depecier" pos="VERppe" >depeciez</w>
                        <w xml:id="t1026" n="1026" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t1027" n="1027" lemma="nul" pos="PROind" >nus</w>
                        <w xml:id="t1028" n="1028" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t1029" n="1029" lemma="i2" pos="PROadv" >i</w>
                        <w xml:id="t1030" n="1030" lemma="pöoir" pos="VERcjg" >poïst</w>
                        <w xml:id="t1031" n="1031" lemma="passer1" pos="VERinf" >passer</w>
                        <w xml:id="t1032" n="1032" lemma="tant" pos="ADVgen" >tant</w>
                        <w xml:id="t1033" n="1033" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t1034" n="1034" lemma="le" pos="DETdef" >li</w>
                        <w xml:id="t1035" n="1035" lemma="un" pos="PROind" >uns</w>
                        <w xml:id="t1036" n="1036" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t1037" n="1037" lemma="estre1" pos="VERcjg" >soit</w>
                        <w xml:id="t1038" n="1038" lemma="outrer" pos="VERppe" >outrez</w>
                        <w xml:id="t1039" n="1039" lemma="issi" pos="ADVgen" >issi</w>
                        <w xml:id="t1040" n="1040" lemma="pöoir" pos="VERcjg" >porroit</w>
                        <w xml:id="t1041" n="1041" lemma="estre1" pos="VERinf" >estre</w>
                        <w xml:id="t1042" n="1042" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t1043" n="1043" lemma="bataille" pos="NOMcom" >bataille</w>
                        <w xml:id="t1044" n="1044" lemma="mais1" pos="CONcoo" >Mais</w>
                        <w xml:id="t1045" n="1045" lemma="autrement" pos="ADVgen" >autrement</w>
                        <w xml:id="t1046" n="1046" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t1047" n="1047" lemma="il" pos="PROper" >lo</w>
                        <w xml:id="t1048" n="1048" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t1049" n="1049" lemma="löer1" pos="VERcjg" >loeroie</w>
                        <w xml:id="t1050" n="1050" lemma="je" pos="PROper" >ge</w>
                        <w xml:id="t1051" n="1051" lemma="mie" pos="ADVneg" >mies</w>
                        <w xml:id="t1052" n="1052" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t1053" n="1053" lemma="vos" pos="PROper" >vos</w>
                        <w xml:id="t1054" n="1054" lemma="il" pos="PROper" >lo</w>
                        <w xml:id="t1055" n="1055" lemma="voloir" pos="VERcjg" >voliez</w>
                        <w xml:id="t1056" n="1056" lemma="por2" pos="PRE" >por</w>
                        <w xml:id="t1057" n="1057" lemma="je" pos="PROper" >moi</w>
                        <w xml:id="t1058" n="1058" lemma="laissier" pos="VERinf" >laissier</w>
                        <w xml:id="t1059" n="1059" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t1060" n="1060" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t1061" n="1061" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t1062" n="1062" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t1063" n="1063" lemma="ainsi" pos="ADVgen" >ansi</w>
                        <w xml:id="t1064" n="1064" lemma="estre1" pos="VERcjg" >sera</w>
                        <w xml:id="t1065" n="1065" lemma="il" pos="PROper" >ele</w>
                        <w xml:id="t1066" n="1066" lemma="se" pos="CONsub" >s</w>
                        <w xml:id="t1067" n="1067" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t1068" n="1068" lemma="il" pos="PROper" >l</w>
                        <w xml:id="t1069" n="1069" lemma="oser" pos="VERcjg" >ose</w>
                        <w xml:id="t1070" n="1070" lemma="faire" pos="VERinf" >faire</w>
                        <w xml:id="t1071" n="1071" lemma="lors" pos="ADVgen" >Lors</w>
                        <w xml:id="t1072" n="1072" lemma="venir" pos="VERcjg" >vint</w>
                        <w xml:id="t1073" n="1073" lemma="ariere" pos="ADVgen" >arriers</w>
                        <w xml:id="t1074" n="1074" lemma="armer" pos="VERppe" >armez</w>
                        <w xml:id="t1075" n="1075" lemma="jusque" pos="PRE" >juque</w>
                        <w xml:id="t1076" n="1076" lemma="a3+le" pos="PRE.DETdef" >au</w>
                        <w xml:id="t1077" n="1077" lemma="poncel1" pos="NOMcom" >poncel</w>
                        <w xml:id="t1078" n="1078" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1079" n="1079" lemma="deviser" pos="VERcjg" >devise</w>
                        <w xml:id="t1080" n="1080" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t1081" n="1081" lemma="Marganor" pos="NOMpro" >Marganors</w>
                        <w xml:id="t1082" n="1082" lemma="le" pos="DETdef" >les</w>
                        <w xml:id="t1083" n="1083" lemma="covenance" pos="NOMcom" >covenances</w>
                        <w xml:id="t1084" n="1084" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t1085" n="1085" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t1086" n="1086" lemma="demander" pos="VERcjg" >demande</w>
                        <w xml:id="t1087" n="1087" lemma="coment1" pos="ADVsub" >comment</w>
                        <w xml:id="t1088" n="1088" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t1089" n="1089" lemma="estre1" pos="VERcjg" >seroit</w>
                        <w xml:id="t1090" n="1090" lemma="sëur2" pos="ADJqua" >seürs</w>
                        <w xml:id="t1091" n="1091" lemma="de+le" pos="PRE.DETdef" >do</w>
                        <w xml:id="t1092" n="1092" lemma="seignor" pos="NOMcom" >seignor</w>
                        <w xml:id="t1093" n="1093" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t1094" n="1094" lemma="le" pos="DETdef" >l</w>
                        <w xml:id="t1095" n="1095" lemma="estroit" pos="ADJqua" >Estroite</w>
                        <w xml:id="t1096" n="1096" lemma="marche1" pos="NOMcom" >Marche</w>
                        <w xml:id="t1097" n="1097" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1098" n="1098" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t1099" n="1099" lemma="son4" pos="DETpos" >ses</w>
                        <w xml:id="t1100" n="1100" lemma="gent1" pos="NOMcom" >genz</w>
                        <w xml:id="t1101" n="1101" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t1102" n="1102" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t1103" n="1103" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t1104" n="1104" lemma="que4" pos="CONsub" >qu</w>
                        <w xml:id="t1105" n="1105" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t1106" n="1106" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t1107" n="1107" lemma="faire" pos="VERcjg" >fera</w>
                        <w xml:id="t1108" n="1108" lemma="jurer" pos="VERinf" >jurer</w>
                        <w xml:id="t1109" n="1109" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1110" n="1110" lemma="fïancier1" pos="VERinf" >fïancier</w>
                        <w xml:id="t1111" n="1111" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t1112" n="1112" lemma="Marganor" pos="NOMpro" >Marganors</w>
                        <w xml:id="t1113" n="1113" lemma="il" pos="PROper" >l</w>
                        <w xml:id="t1114" n="1114" lemma="otroiier" pos="VERcjg" >otroie</w>
                        <w xml:id="t1115" n="1115" lemma="cui" pos="PROrel" >cui</w>
                        <w xml:id="t1116" n="1116" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t1117" n="1117" lemma="mout" pos="ADVgen" >mout</w>
                        <w xml:id="t1118" n="1118" lemma="tarder" pos="VERcjg" >tarde</w>
                        <w xml:id="t1119" n="1119" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t1120" n="1120" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t1121" n="1121" lemma="bataille" pos="NOMcom" >bataille</w>
                        <w xml:id="t1122" n="1122" lemma="avoir" pos="VERinf" >avoir</w>
                        <w xml:id="t1123" n="1123" lemma="lors" pos="ADVgen" >Lors</w>
                        <w xml:id="t1124" n="1124" lemma="venir" pos="VERcjg" >vienent</w>
                        <w xml:id="t1125" n="1125" lemma="entre2" pos="PRE" >antre</w>
                        <w xml:id="t1126" n="1126" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t1127" n="1127" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1128" n="1128" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t1129" n="1129" lemma="desor" pos="PRE" >desor</w>
                        <w xml:id="t1130" n="1130" lemma="le" pos="DETdef" >lo</w>
                        <w xml:id="t1131" n="1131" lemma="poncel1" pos="NOMcom" >poncel</w>
                        <w xml:id="t1132" n="1132" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t1133" n="1133" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t1134" n="1134" lemma="dire" pos="VERcjg" >dit</w>
                        <w xml:id="t1135" n="1135" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t1136" n="1136" lemma="son4" pos="DETpos" >ses</w>
                        <w xml:id="t1137" n="1137" lemma="gent1" pos="NOMcom" >genz</w>
                        <w xml:id="t1138" n="1138" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t1139" n="1139" lemma="chier" pos="ADJqua" >chier</w>
                        <w xml:id="t1140" n="1140" lemma="come1" pos="CONsub" >com</w>
                        <w xml:id="t1141" n="1141" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t1142" n="1142" lemma="avoir" pos="VERcjg" >ont</w>
                        <w xml:id="t1143" n="1143" lemma="lor2" pos="DETpos" >lor</w>
                        <w xml:id="t1144" n="1144" lemma="onor" pos="NOMcom" >annors</w>
                        <w xml:id="t1145" n="1145" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t1146" n="1146" lemma="nul" pos="PROind" >nus</w>
                        <w xml:id="t1147" n="1147" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t1148" n="1148" lemma="soi1" pos="PROper" >s</w>
                        <w xml:id="t1149" n="1149" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t1150" n="1150" lemma="movoir" pos="VERcjg" >move</w>
                        <w xml:id="t1151" n="1151" lemma="devant" pos="ADVgen" >devant</w>
                        <w xml:id="t1152" n="1152" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t1153" n="1153" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t1154" n="1154" lemma="estre1" pos="VERcjg" >soit</w>
                        <w xml:id="t1155" n="1155" lemma="conquerre" pos="VERppe" >conquis</w>
                        <w xml:id="t1156" n="1156" lemma="o3" pos="CONcoo" >ou</w>
                        <w xml:id="t1157" n="1157" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t1158" n="1158" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t1159" n="1159" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t1160" n="1160" lemma="mener" pos="VERcjg" >maint</w>
                        <w xml:id="t1161" n="1161" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t1162" n="1162" lemma="dedenz" pos="PRE" >dedanz</w>
                        <w xml:id="t1163" n="1163" lemma="le" pos="DETdef" >lo</w>
                        <w xml:id="t1164" n="1164" lemma="chastel" pos="NOMcom" >chastel</w>
                        <w xml:id="t1165" n="1165" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t1166" n="1166" lemma="ainsi" pos="ADVgen" >ansi</w>
                        <w xml:id="t1167" n="1167" lemma="il" pos="PROper" >lo</w>
                        <w xml:id="t1168" n="1168" lemma="faire" pos="VERcjg" >fait</w>
                        <w xml:id="t1169" n="1169" lemma="fïancier1" pos="VERinf" >fïancier</w>
                        <w xml:id="t1170" n="1170" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t1171" n="1171" lemma="son4" pos="DETpos" >son</w>
                        <w xml:id="t1172" n="1172" lemma="conestable" pos="NOMcom" >conestable</w>
                        <w xml:id="t1173" n="1173" lemma="qui" pos="PROrel" >qui</w>
                        <w xml:id="t1174" n="1174" lemma="estre1" pos="VERcjg" >estoit</w>
                        <w xml:id="t1175" n="1175" lemma="son4" pos="DETpos" >ses</w>
                        <w xml:id="t1176" n="1176" lemma="ome" pos="NOMcom" >hom</w>
                        <w xml:id="t1177" n="1177" lemma="lige" pos="ADJqua" >liges</w>
                        <w xml:id="t1178" n="1178" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1179" n="1179" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t1180" n="1180" lemma="tot" pos="DETind" >toz</w>
                        <w xml:id="t1181" n="1181" lemma="le" pos="DETdef" >les</w>
                        <w xml:id="t1182" n="1182" lemma="autre" pos="PROind" >autres</w>
                        <w xml:id="t1183" n="1183" lemma="qui" pos="PROrel" >qui</w>
                        <w xml:id="t1184" n="1184" lemma="son4" pos="DETpos" >si</w>
                        <w xml:id="t1185" n="1185" lemma="ome" pos="NOMcom" >home</w>
                        <w xml:id="t1186" n="1186" lemma="estre1" pos="VERcjg" >estoient</w>
                        <w xml:id="t1187" n="1187" lemma="puis" pos="ADVgen" >Puis</w>
                        <w xml:id="t1188" n="1188" lemma="lacier" pos="VERcjg" >lace</w>
                        <w xml:id="t1189" n="1189" lemma="son4" pos="DETpos" >son</w>
                        <w xml:id="t1190" n="1190" lemma="heaume" pos="NOMcom" >hiaume</w>
                        <w xml:id="t1191" n="1191" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1192" n="1192" lemma="venir" pos="VERcjg" >vient</w>
                        <w xml:id="t1193" n="1193" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t1194" n="1194" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t1195" n="1195" lemma="bretesche" pos="NOMcom" >bretesche</w>
                        <w xml:id="t1196" n="1196" lemma="là" pos="ADVgen" >la</w>
                        <w xml:id="t1197" n="1197" lemma="où" pos="PROrel" >ou</w>
                        <w xml:id="t1198" n="1198" lemma="le" pos="DETdef" >li</w>
                        <w xml:id="t1199" n="1199" lemma="seignor" pos="NOMcom" >sires</w>
                        <w xml:id="t1200" n="1200" lemma="de+le" pos="PRE.DETdef" >do</w>
                        <w xml:id="t1201" n="1201" lemma="chastel" pos="NOMcom" >chastel</w>
                        <w xml:id="t1202" n="1202" lemma="estre1" pos="VERcjg" >estoit</w>
                        <w xml:id="t1203" n="1203" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t1204" n="1204" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t1205" n="1205" lemma="il" pos="PROper" >li</w>
                        <w xml:id="t1206" n="1206" lemma="faire" pos="VERcjg" >fait</w>
                        <w xml:id="t1207" n="1207" lemma="fïancier1" pos="VERinf" >fïancier</w>
                        <w xml:id="t1208" n="1208" lemma="a3+le" pos="PRE.DETdef" >au</w>
                        <w xml:id="t1209" n="1209" lemma="seignor" pos="NOMcom" >seignor</w>
                        <w xml:id="t1210" n="1210" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1211" n="1211" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t1212" n="1212" lemma="son4" pos="DETpos" >ses</w>
                        <w xml:id="t1213" n="1213" lemma="gent1" pos="NOMcom" >genz</w>
                        <w xml:id="t1214" n="1214" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t1215" n="1215" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t1216" n="1216" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t1217" n="1217" lemma="avoir" pos="VERcjg" >a</w>
                        <w xml:id="t1218" n="1218" lemma="garde" pos="NOMcom" >garde</w>
                        <w xml:id="t1219" n="1219" lemma="ne2" pos="CONcoo" >ne</w>
                        <w xml:id="t1220" n="1220" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t1221" n="1221" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t1222" n="1222" lemma="ne2" pos="CONcoo" >ne</w>
                        <w xml:id="t1223" n="1223" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t1224" n="1224" lemma="son4" pos="DETpos" >ses</w>
                        <w xml:id="t1225" n="1225" lemma="gent1" pos="NOMcom" >genz</w>
                        <w xml:id="t1226" n="1226" lemma="se" pos="CONsub" >se</w>
                        <w xml:id="t1227" n="1227" lemma="avant" pos="ADVgen" >avant</w>
                        <w xml:id="t1228" n="1228" lemma="ne1" pos="ADVneg" >ne</w>
                        <w xml:id="t1229" n="1229" lemma="soi1" pos="PROper" >se</w>
                        <w xml:id="t1230" n="1230" lemma="movoir" pos="VERcjg" >muevent</w>
                        <w xml:id="t1231" n="1231" lemma="le" pos="DETdef" >les</w>
                        <w xml:id="t1232" n="1232" lemma="suen" pos="ADJpos" >soes</w>
                        <w xml:id="t1233" n="1233" lemma="gent1" pos="NOMcom" >genz</w>
                        <w xml:id="t1234" n="1234" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t1235" n="1235" lemma="avuec" pos="PRE" >avoc</w>
                        <w xml:id="t1236" n="1236" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t1237" n="1237" lemma="fïancier1" pos="VERcjg" >fïancent</w>
                        <w xml:id="t1238" n="1238" lemma="tot" pos="DETind" >tuit</w>
                        <w xml:id="t1239" n="1239" lemma="le" pos="DETdef" >li</w>
                        <w xml:id="t1240" n="1240" lemma="chevalier" pos="NOMcom" >chevalier</w>
                        <w xml:id="t1241" n="1241" lemma="par" pos="PRE" >par</w>
                        <w xml:id="t1242" n="1242" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t1243" n="1243" lemma="priiere" pos="NOMcom" >proiere</w>
                        <w xml:id="t1244" n="1244" lemma="de" pos="PRE" >d</w>
                        <w xml:id="t1245" n="1245" lemma="Hector" pos="NOMpro" >Estor</w>
                        <w xml:id="t1246" n="1246" lemma="lors" pos="ADVgen" >Lors</w>
                        <w xml:id="t1247" n="1247" lemma="avoir" pos="VERcjg" >ont</w>
                        <w xml:id="t1248" n="1248" lemma="le" pos="DETdef" >lo</w>
                        <w xml:id="t1249" n="1249" lemma="poncel1" pos="NOMcom" >poncel</w>
                        <w xml:id="t1250" n="1250" lemma="depecier" pos="VERppe" >depecié</w>
                        <w xml:id="t1251" n="1251" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t1252" n="1252" lemma="le" pos="DETdef" >li</w>
                        <w xml:id="t1253" n="1253" lemma="marois2" pos="NOMcom" >marés</w>
                        <w xml:id="t1254" n="1254" lemma="estre1" pos="VERcjg" >estoit</w>
                        <w xml:id="t1255" n="1255" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t1256" n="1256" lemma="grant" pos="ADJqua" >granz</w>
                        <w xml:id="t1257" n="1257" lemma="entor" pos="ADVgen" >antor</w>
                        <w xml:id="t1258" n="1258" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1259" n="1259" lemma="desoz" pos="ADVgen" >desoz</w>
                        <w xml:id="t1260" n="1260" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t1261" n="1261" lemma="nul" pos="DETind" >nule</w>
                        <w xml:id="t1262" n="1262" lemma="rien" pos="NOMcom" >riens</w>
                        <w xml:id="t1263" n="1263" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t1264" n="1264" lemma="i2" pos="PROadv" >i</w>
                        <w xml:id="t1265" n="1265" lemma="entrer" pos="VERcjg" >antrast</w>
                        <w xml:id="t1266" n="1266" lemma="qui" pos="PROrel" >qui</w>
                        <w xml:id="t1267" n="1267" lemma="ja" pos="ADVgen" >ja</w>
                        <w xml:id="t1268" n="1268" lemma="mais1" pos="ADVgen" >mais</w>
                        <w xml:id="t1269" n="1269" lemma="en2" pos="PROadv" >an</w>
                        <w xml:id="t1270" n="1270" lemma="issir" pos="VERcjg" >isist</w>
                        <w xml:id="t1271" n="1271" lemma="si" pos="ADVgen" >Si</w>
                        <w xml:id="t1272" n="1272" lemma="tost1" pos="ADVgen" >tost</w>
                        <w xml:id="t1273" n="1273" lemma="come1" pos="CONsub" >com</w>
                        <w xml:id="t1274" n="1274" lemma="le" pos="DETdef" >li</w>
                        <w xml:id="t1275" n="1275" lemma="poncel1" pos="NOMcom" >ponciaus</w>
                        <w xml:id="t1276" n="1276" lemma="estre1" pos="VERcjg" >fu</w>
                        <w xml:id="t1277" n="1277" lemma="depecier" pos="VERppe" >depeciez</w>
                        <w xml:id="t1278" n="1278" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1279" n="1279" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t1280" n="1280" lemma="nul" pos="DETind" >nule</w>
                        <w xml:id="t1281" n="1281" lemma="rien" pos="PROind" >rien</w>
                        <w xml:id="t1282" n="1282" lemma="ne1" pos="ADVneg" >n</w>
                        <w xml:id="t1283" n="1283" lemma="i2" pos="PROadv" >i</w>
                        <w xml:id="t1284" n="1284" lemma="pöoir" pos="VERcjg" >peüst</w>
                        <w xml:id="t1285" n="1285" lemma="passer1" pos="VERinf" >passer</w>
                        <w xml:id="t1286" n="1286" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t1287" n="1287" lemma="movoir" pos="ADVgen" >mut</w>
                        <w xml:id="t1288" n="1288" lemma="Marganor" pos="NOMpro" >Marganors</w>
                        <w xml:id="t1289" n="1289" lemma="de+le" pos="PRE.DETdef" >do</w>
                        <w xml:id="t1290" n="1290" lemma="poncel1" pos="NOMcom" >poncel</w>
                        <w xml:id="t1291" n="1291" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1292" n="1292" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t1293" n="1293" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t1294" n="1294" lemma="vers2" pos="PRE" >vers</w>
                        <w xml:id="t1295" n="1295" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t1296" n="1296" lemma="bretesche" pos="NOMcom" >bretesche</w>
                        <w xml:id="t1297" n="1297" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t1298" n="1298" lemma="soi1" pos="PROper" >s</w>
                        <w xml:id="t1299" n="1299" lemma="envener" pos="VERcjg" >anrevienent</w>
                        <w xml:id="t1300" n="1300" lemma="entrevenir" pos="VERcjg" >antrevienent</w>
                        <w xml:id="t1301" n="1301" lemma="le" pos="DETdef" >les</w>
                        <w xml:id="t1302" n="1302" lemma="escu" pos="NOMcom" >escuz</w>
                        <w xml:id="t1303" n="1303" lemma="a3+le" pos="PRE.DETdef" >as</w>
                        <w xml:id="t1304" n="1304" lemma="col" pos="NOMcom" >cox</w>
                        <w xml:id="t1305" n="1305" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t1306" n="1306" lemma="tost1" pos="ADVgen" >tost</w>
                        <w xml:id="t1307" n="1307" lemma="come1" pos="CONsub" >comme</w>
                        <w xml:id="t1308" n="1308" lemma="cheval" pos="NOMcom" >cheval</w>
                        <w xml:id="t1309" n="1309" lemma="il" pos="PROper" >lor</w>
                        <w xml:id="t1310" n="1310" lemma="pöoir" pos="VERcjg" >porent</w>
                        <w xml:id="t1311" n="1311" lemma="corir" pos="VERinf" >corre</w>
                        <w xml:id="t1312" n="1312" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t1313" n="1313" lemma="chascun" pos="PROind" >chascuns</w>
                        <w xml:id="t1314" n="1314" lemma="de" pos="PRE" >d</w>
                        <w xml:id="t1315" n="1315" lemma="il" pos="PROper" >aus</w>
                        <w xml:id="t1316" n="1316" lemma="avoir" pos="VERcjg" >ot</w>
                        <w xml:id="t1317" n="1317" lemma="assez" pos="ADVgen" >assez</w>
                        <w xml:id="t1318" n="1318" lemma="cuer2" pos="NOMcom" >cuer</w>
                        <w xml:id="t1319" n="1319" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1320" n="1320" lemma="vertu" pos="NOMcom" >vertu</w>
                        <w xml:id="t1321" n="1321" lemma="grant" pos="ADJqua" >grant</w>
                        <w xml:id="t1322" n="1322" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t1323" n="1323" lemma="le" pos="DETdef" >li</w>
                        <w xml:id="t1324" n="1324" lemma="un" pos="PROind" >uns</w>
                        <w xml:id="t1325" n="1325" lemma="estre1" pos="VERcjg" >fu</w>
                        <w xml:id="t1326" n="1326" lemma="chaut" pos="ADJqua" >chauz</w>
                        <w xml:id="t1327" n="1327" lemma="de" pos="PRE" >d</w>
                        <w xml:id="t1328" n="1328" lemma="ire" pos="NOMcom" >ire</w>
                        <w xml:id="t1329" n="1329" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1330" n="1330" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t1331" n="1331" lemma="mautalent" pos="NOMcom" >mautalant</w>
                        <w xml:id="t1332" n="1332" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1333" n="1333" lemma="le" pos="DETdef" >li</w>
                        <w xml:id="t1334" n="1334" lemma="autre" pos="PROind" >autres</w>
                        <w xml:id="t1335" n="1335" lemma="angoissos" pos="ADJqua" >angoisos</w>
                        <w xml:id="t1336" n="1336" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1337" n="1337" lemma="volentif" pos="ADJqua" >volenteïs</w>
                        <w xml:id="t1338" n="1338" lemma="de" pos="PRE" >d</w>
                        <w xml:id="t1339" n="1339" lemma="onor" pos="NOMcom" >anor</w>
                        <w xml:id="t1340" n="1340" lemma="conquerre" pos="VERinf" >conquerre</w>
                        <w xml:id="t1341" n="1341" lemma="si" pos="ADVgen" >Si</w>
                        <w xml:id="t1342" n="1342" lemma="avoir" pos="VERcjg" >orent</w>
                        <w xml:id="t1343" n="1343" lemma="glaive" pos="NOMcom" >glaives</w>
                        <w xml:id="t1344" n="1344" lemma="fort" pos="ADJqua" >forz</w>
                        <w xml:id="t1345" n="1345" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1346" n="1346" lemma="roit1" pos="ADJqua" >roides</w>
                        <w xml:id="t1347" n="1347" lemma="a3" pos="PRE" >a</w>
                        <w xml:id="t1348" n="1348" lemma="fer" pos="NOMcom" >fers</w>
                        <w xml:id="t1349" n="1349" lemma="grant" pos="ADJqua" >granz</w>
                        <w xml:id="t1350" n="1350" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1351" n="1351" lemma="trenchier1" pos="VERppa" >tranchanz</w>
                        <w xml:id="t1352" n="1352" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t1353" n="1353" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t1354" n="1354" lemma="estre1" pos="VERcjg" >fu</w>
                        <w xml:id="t1355" n="1355" lemma="monter" pos="VERppe" >montez</w>
                        <w xml:id="t1356" n="1356" lemma="sor2" pos="PRE" >sor</w>
                        <w xml:id="t1357" n="1357" lemma="le" pos="DETdef" >lo</w>
                        <w xml:id="t1358" n="1358" lemma="cheval" pos="NOMcom" >cheval</w>
                        <w xml:id="t1359" n="1359" lemma="a3+le" pos="PRE.DETdef" >au</w>
                        <w xml:id="t1360" n="1360" lemma="chevalier" pos="NOMcom" >chevalier</w>
                        <w xml:id="t1361" n="1361" lemma="que2" pos="PROrel" >que</w>
                        <w xml:id="t1362" n="1362" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t1363" n="1363" lemma="avoir" pos="VERcjg" >avoit</w>
                        <w xml:id="t1364" n="1364" lemma="conquerre" pos="VERppe" >conquis</w>
                        <w xml:id="t1365" n="1365" lemma="defors" pos="PRE" >dehors</w>
                        <w xml:id="t1366" n="1366" lemma="le" pos="DETdef" >lo</w>
                        <w xml:id="t1367" n="1367" lemma="poncel1" pos="NOMcom" >poncel</w>
                        <w xml:id="t1368" n="1368" lemma="qui" pos="PROrel" >qui</w>
                        <w xml:id="t1369" n="1369" lemma="mout" pos="ADVgen" >mout</w>
                        <w xml:id="t1370" n="1370" lemma="estre1" pos="VERcjg" >estoit</w>
                        <w xml:id="t1371" n="1371" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t1372" n="1372" lemma="grant" pos="ADJqua" >grant</w>
                        <w xml:id="t1373" n="1373" lemma="bonté" pos="NOMcom" >bonté</w>
                        <w xml:id="t1374" n="1374" lemma="si" pos="ADVgen" >Si</w>
                        <w xml:id="t1375" n="1375" lemma="soi1" pos="PROper" >s</w>
                        <w xml:id="t1376" n="1376" lemma="entrevenir" pos="VERcjg" >antrevienent</w>
                        <w xml:id="t1377" n="1377" lemma="de" pos="PRE" >de</w>
                        <w xml:id="t1378" n="1378" lemma="grant" pos="ADJqua" >grant</w>
                        <w xml:id="t1379" n="1379" lemma="alëure" pos="NOMcom" >aleüre</w>
                        <w xml:id="t1380" n="1380" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1381" n="1381" lemma="soi1" pos="PROper" >s</w>
                        <w xml:id="t1382" n="1382" lemma="entreferir" pos="VERcjg" >antrefierent</w>
                        <w xml:id="t1383" n="1383" lemma="sus" pos="PRE" >sus</w>
                        <w xml:id="t1384" n="1384" lemma="le" pos="DETdef" >les</w>
                        <w xml:id="t1385" n="1385" lemma="escu" pos="NOMcom" >escuz</w>
                        <w xml:id="t1386" n="1386" lemma="si" pos="ADVgen" >Si</w>
                        <w xml:id="t1387" n="1387" lemma="peçoiier" pos="VERcjg" >peçoie</w>
                        <w xml:id="t1388" n="1388" lemma="Marganor" pos="NOMpro" >Marganors</w>
                        <w xml:id="t1389" n="1389" lemma="son4" pos="DETpos" >son</w>
                        <w xml:id="t1390" n="1390" lemma="glaive" pos="NOMcom" >glaive</w>
                        <w xml:id="t1391" n="1391" lemma="sus" pos="PRE" >sus</w>
                        <w xml:id="t1392" n="1392" lemma="Hector" pos="NOMpro" >Hestor</w>
                        <w xml:id="t1393" n="1393" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t1394" n="1394" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t1395" n="1395" lemma="ferir" pos="VERcjg" >fiert</w>
                        <w xml:id="t1396" n="1396" lemma="il" pos="PROper" >lui</w>
                        <w xml:id="t1397" n="1397" lemma="qui" pos="PROrel" >qui</w>
                        <w xml:id="t1398" n="1398" lemma="tot" pos="ADVgen" >tot</w>
                        <w xml:id="t1399" n="1399" lemma="i2" pos="PROadv" >i</w>
                        <w xml:id="t1400" n="1400" lemma="metre2" pos="VERcjg" >met</w>
                        <w xml:id="t1401" n="1401" lemma="le" pos="DETdef" >lo</w>
                        <w xml:id="t1402" n="1402" lemma="cuer2" pos="NOMcom" >cuer</w>
                        <w xml:id="t1403" n="1403" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1404" n="1404" lemma="le" pos="DETdef" >la</w>
                        <w xml:id="t1405" n="1405" lemma="vertu" pos="NOMcom" >vertu</w>
                        <w xml:id="t1406" n="1406" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t1407" n="1407" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t1408" n="1408" lemma="il" pos="PROper" >lo</w>
                        <w xml:id="t1409" n="1409" lemma="ploiier" pos="VERcjg" >ploie</w>
                        <w xml:id="t1410" n="1410" lemma="tot" pos="ADVgen" >tot</w>
                        <w xml:id="t1411" n="1411" lemma="desus" pos="PRE" >desus</w>
                        <w xml:id="t1412" n="1412" lemma="le" pos="DETdef" >l</w>
                        <w xml:id="t1413" n="1413" lemma="arçon" pos="NOMcom" >arçon</w>
                        <w xml:id="t1414" n="1414" lemma="derrier(e)" pos="ADVgen" >darrieres</w>
                        <w xml:id="t1415" n="1415" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1416" n="1416" lemma="il" pos="PROper" >l</w>
                        <w xml:id="t1417" n="1417" lemma="empoindre" pos="VERcjg" >ampoint</w>
                        <w xml:id="t1418" n="1418" lemma="si" pos="ADVgen" >si</w>
                        <w xml:id="t1419" n="1419" lemma="que4" pos="CONsub" >que</w>
                        <w xml:id="t1420" n="1420" lemma="il" pos="PROper" >il</w>
                        <w xml:id="t1421" n="1421" lemma="faire" pos="VERcjg" >fait</w>
                        <w xml:id="t1422" n="1422" lemma="voler" pos="VERinf" >voler</w>
                        <w xml:id="t1423" n="1423" lemma="en1" pos="PRE" >an</w>
                        <w xml:id="t1424" n="1424" lemma="un" pos="DETndf" >un</w>
                        <w xml:id="t1425" n="1425" lemma="mont" pos="NOMcom" >mont</w>
                        <w xml:id="t1426" n="1426" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1427" n="1427" lemma="Marganor" pos="NOMpro" >Marganor</w>
                        <w xml:id="t1428" n="1428" lemma="et" pos="CONcoo" >et</w>
                        <w xml:id="t1429" n="1429" lemma="le" pos="DETdef" >lo</w>
                        <w xml:id="t1430" n="1430" lemma="cheval" pos="NOMcom" >cheval</w>
                        <w xml:id="t1431" n="1431" lemma="et" pos="CONcoo" >Et</w>
                        <w xml:id="t1432" n="1432" lemma="a3+le" pos="PRE.DETdef" >au</w>
                        <w xml:id="t1433" n="1433" lemma="parchëoir" pos="NOMcom" >parcheoir</w>
                        <w xml:id="t1434" n="1434" lemma="peçoiier" pos="VERcjg" >peçoie</w>
                        <w xml:id="t1435" n="1435" lemma="Hector" pos="NOMpro" >Hestors</w>
                        <w xml:id="t1436" n="1436" lemma="son4" pos="DETpos" >son</w>
                        <w xml:id="t1437" n="1437" lemma="glaive" pos="NOMcom" >glaive</w>
                    </ab>
            </div>
       </body>
     </text>
</TEI>
''')

# %%
#on charge le ns car ce sont des docs tei
tei = {'tei':'http://www.tei-c.org/ns/1.0'}

# %%
#on récupère les lemmes grâce à xpath et en déclarant le ns : exemple :
monXML.xpath("/tei:TEI/tei:text/tei:body/tei:div/tei:ab/tei:w/@lemma", namespaces=tei)
# Out:
# ['et',
#  'Hector',
#  'qui',
#  'avoir',
#  'laissier',
#  'chëoir',
#  'son4',
#  'glaive',
#  'revenir',
#  'a3',
#  'il',
#  'et',
#  'il',
#  'prendre',
#  'par',
#  'le',
#  'heaume',
#  'et',
#  'il',
#  'tirer',
#  'a3',
#  'il',
#  'si',
#  'robement',
#  'que4',
#  'il',
#  'il',
#  'arrachier',
#  'de',
#  'le',
#  'teste',
#  'si',
#  'felonessement',
#  'que4',
#  'il',
#  'il',
#  'faire',
#  'tomber',
#  'le',
#  'visage',
#  'contre',
#  'terre',
#  'si',
#  'que4',
#  'par',
#  'un',
#  'poi',
#  'que4',
#  'il',
#  'ne1',
#  'avoir',
#  'le',
#  'dent2',
#  'tot',
#  'brisier',
#  'en1',
#  'le',
#  'boche',
#  'et',
#  'tot',
#  'le',
#  'nef2',
#  'escorchier',
#  'si',
#  'seignier',
#  'mout',
#  'fort',
#  'Hector',
#  'descendre',
#  'volentiers',
#  'mais1',
#  'il',
#  'soi1',
#  'doter2',
#  'de',
#  'träison',
#  'il',
#  'jeter',
#  'le',
#  'heaume',
#  'a3+le',
#  'loing',
#  'et',
#  'metre2',
#  'le',
#  'main2',
#  'a3',
#  'le',
#  'espee',
# ...

# %%
#récupération des lemmes
vA = []
for w in A1.xpath("/tei:TEI/tei:text/tei:body/tei:div/tei:ab/tei:w", namespaces=tei):
    valL = w.get("lemma")
    print(valL)
    vA.append(valL)
# Out:
# et
# Hector
# qui
# avoir
# laissier
# chëoir
# son4
# glaive
# revenir
# a3
# il
# et
# il
# prendre
# par
# le
# heaume
# et
# il
# tirer
# a3
# il
# si
# robement
# que4
# il
# il
# arrachier
# de
# le
# teste
# si
# felonessement
# que4
# il
# il
# faire
# tomber
# le
# visage
# contre
# terre
# si
# que4
# par
# un
# poi
# que4
# il
# ne1
# avoir
# le
# dent2
# tot
# brisier
# en1
# le
# boche
# et
# tot
# le
# nef2
# escorchier
# si
# seignier
# mout
# fort
# Hector
# descendre
# volentiers
# mais1
# il
# soi1
# doter2
# de
# träison
# il
# jeter
# le
# heaume
# a3+le
# loing
# et
# metre2
# le
# main2
# a3
# le
# espee
# puis
# venir
# a3+le
# chevalier
# qui
# soi1
# relever
# et
# il
# doner
# de+le
# plat
# de
# le
# espee
# par
# deus
# foiz
# tant
# que4
# il
# il
# abatre
# a3
# terre
# et
# saignier
# aussi
# fort
# come1
# se
# il
# estre1
# navrer
# avoir
# morir
# Hector
# torner
# le
# dos
# vers2
# le
# poncel1
# et
# soi1
# arester
# sor2
# le
# poncel1
# et
# ...

# %%
#idem pour B
vB = []
for w in B1.xpath("/tei:TEI/tei:text/tei:body/tei:div/tei:ab/tei:w", namespaces=tei):
    valL = w.get("lemma")
    print(valL)
    vB.append(valL)
# Out:
# et
# Hector
# soi1
# en2
# revenir
# par
# il
# qui
# avoir
# laissier
# chëoir
# le
# glaive
# si
# il
# aerdre
# par
# le
# heaume
# a3
# le
# destre
# main2
# si
# sachier2
# si
# durement2
# a3
# il
# que4
# il
# il
# rompre
# tot
# le
# laz1
# si
# il
# esrachier2
# si
# durement2
# de
# le
# teste
# que4
# il
# il
# abatre
# a3
# terre
# tot
# adens
# si
# que4
# par
# poi
# que4
# il
# ne1
# avoir
# tot
# le
# dent2
# brisier
# en1
# le
# gole
# et
# tot
# le
# nés
# avoir
# escorchier
# si
# saignier
# mout
# très
# durement2
# et
# Hector
# descendre
# mout
# volentiers
# por2
# il
# conquerre
# mais1
# il
# soi1
# doter2
# de
# träison
# si
# ne1
# descendre
# mie
# ainz
# jeter
# le
# heaume
# tant
# come1
# il
# pöoir
# loing
# et
# metre2
# le
# main2
# a3
# le
# espee
# si
# venir
# a3+le
# chevalier
# qui
# soi1
# lever
# et
# il
# ferir
# de+le
# plat
# de
# le
# espee
# par
# deus
# foiz
# si
# que4
# il
# il
# abatre
# a3
# terre
# et
# il
# saignier
# autresi
# ...

# %%
#on crée sous forme de texte
txt = ' '.join(vA)
#on utilise une fonction qui permet de compter le nombre de mots, après voir splité sur l'espace
counts = collections.Counter(txt.split())
motsComptesA = counts.most_common()

# %%
#idem pour B
txtB = ' '.join(vB)
countsB = collections.Counter(txtB.split())
motsComptesB = countsB.most_common()
#on obtient une liste come suit
motsComptesB
# Out:
# [('il', 135),
#  ('et', 85),
#  ('le', 65),
#  ('que4', 49),
#  ('ne1', 41),
#  ('de', 37),
#  ('vos', 35),
#  ('estre1', 34),
#  ('faire', 34),
#  ('avoir', 32),
#  ('si', 29),
#  ('Hector', 26),
#  ('en2', 25),
#  ('a3', 23),
#  ('je', 23),
#  ('dire', 21),
#  ('soi1', 20),
#  ('son4', 20),
#  ('se', 18),
#  ('Marganor', 14),
#  ('tot', 13),
#  ('en1', 12),
#  ('qui', 10),
#  ('chevalier', 10),
#  ('voloir', 10),
#  ('seignor', 10),
#  ('car', 10),
#  ('mie', 9),
#  ('pöoir', 9),
#  ('poncel1', 9),
#  ('par', 8),
#  ('por2', 8),
#  ('mais1', 8),
#  ('come1', 8),
#  ('venir', 8),
#  ('grant', 8),
#  ('gent1', 8),
#  ('a3+le', 7),
#  ('de+le', 7),
#  ('lors', 7),
#  ('i2', 7),
#  ('où', 7),
#  ('defendre', 7),
#  ('ja', 7),
#  ('mout', 6),
#  ('prison', 6),
#  ('nul', 6),
#  ('tant', 5),
#  ('espee', 5),
#  ('sus', 5),
#  ('en1+le', 5),
#  ('combatre', 5),
#  ('rien', 5),
#  ('apeler', 5),
#  ('glaive', 4),
#  ('heaume', 4),
#  ('durement2', 4),
#  ('teste', 4),
#  ('conquerre', 4),
# ...

# %%
#on crée l'élément racine du XML dans lequel on va enregisrer les données
documentL = et.Element('donneesL')

# %%
#pour chaque élément de la liste
for x in motsComptesA:
    print(x)
    #on crée un élément mo
    mot = et.SubElement(documentL,'mot')
    #on récupère l'index de ce sur quoi on itère
    index = motsComptesA.index(x)
    #on crée des sous-éléments lemme et occA
    lemme = et.SubElement(mot, 'lemme')
    occA = et.SubElement(mot, 'occA')
    #on récupère les valeurs de la liste : occ et lemme
    nbeOccA = motsComptesA[index][1]
    motRet = motsComptesA[index][0]
    #on met ces valeurs dans nos éléments
    lemme.text = str(motRet)
    occA.text = str(nbeOccA)
    print(occA.text)
    #on crée un sous-élément occB
    occB = et.SubElement(mot, 'occB')
    #si le mot se trouve dans la liste des B
    if motRet in vB:
        #on vérifie
        print(motRet)
        #on transforme grâce à numpy en array pour réussir à récupérer l'index de là où est le mot
        lst = np.array(motsComptesB)
        result = np.where(lst == motRet )
        #on récupère l'array et on le transforme en entier : correspond à l'index de la liste
        resultInt = result[0]
        indexB= resultInt.item()
        #on a donc l'index, et on peut récupérer l'occ
        nbeOccB = motsComptesB[indexB][1]
        #on met l'occ dans notre élément
        occB.text = str(nbeOccB)
        #si le mot n'est pas dans la liste, la valeur = 0
    else:
        occB.text= str('0')
# Out:
# ('il', 94)
# 94
# il
# ('le', 58)
# 58
# le
# ('et', 53)
# 53
# et
# ('que4', 43)
# 43
# que4
# ('faire', 37)
# 37
# faire
# ('ne1', 36)
# 36
# ne1
# ('vos', 36)
# 36
# vos
# ('de', 34)
# 34
# de
# ('estre1', 30)
# 30
# estre1
# ('Hector', 27)
# 27
# Hector
# ('avoir', 25)
# 25
# avoir
# ('a3', 23)
# 23
# a3
# ('je', 20)
# 20
# je
# ('se', 19)
# 19
# se
# ('son4', 18)
# 18
# son4
# ('soi1', 17)
# 17
# soi1
# ('Marganor', 17)
# 17
# Marganor
# ('si', 16)
# 16
# si
# ('dire', 15)
# 15
# dire
# ('en1', 12)
# 12
# en1
# ('en2', 12)
# 12
# en2
# ('tot', 11)
# 11
# tot
# ('por2', 10)
# 10
# por2
# ('voloir', 10)
# 10
# voloir
# ('car', 9)
# 9
# car
# ('chevalier', 8)
# 8
# chevalier
# ('de+le', 8)
# 8
# de+le
# ('poncel1', 8)
# 8
# poncel1
# ('prometre', 8)
# 8
# ('seignor', 8)
# 8
# seignor
# ('par', 7)
# 7
# par
# ('mais1', 7)
# 7
# mais1
# ('a3+le', 7)
# 7
# a3+le
# ('où', 7)
# 7
# où
# ('puis', 6)
# 6
# puis
# ('venir', 6)
# 6
# venir
# ('defendre', 6)
# 6
# defendre
# ('tenir1', 5)
# ...

# %%
#création de la racine de l'élément xml
tree = et.ElementTree(documentL)

# %%
#on crée un dossier
if not os.path.isdir("./sortiesPropreTexte"):
    os.makedirs("./sortiesPropreTexte")
    
#ElementTree a une fonction write
#on écrit le fichier de sortie
tree.write("./sortiesPropreTexte/lemmesEtFreq.xml")

# %%
##on va passer à la collation

#défintion de la fonction qui permet la transformation vers du json, puisque collatex doit prendre du json
#on utilise une feuille de transformation
def XMLtoJson(id,xmlInput):
    #défition de witness comme un dictionnaire
    witness = {}
    #on donne la première valeur de l'id
    witness['id'] = id
    #on transforme le document XML
    monXSL = etree.XML('''
<xsl:stylesheet xmlns:xsl="http://www.w3.org/1999/XSL/Transform"
    xmlns:xs="http://www.w3.org/2001/XMLSchema"
    xmlns:tei="http://www.tei-c.org/ns/1.0"
    exclude-result-prefixes="xs"
    version="1.0">
    
    <xsl:output method="text" xml:space="default"/>
    
    <xsl:template match="/">
        <xsl:apply-templates/>
    </xsl:template>
   
    
    <xsl:template match="tei:TEI">
        <xsl:apply-templates />
    </xsl:template>
     
    <xsl:template match="tei:teiHeader"/>
    
    <xsl:template match="tei:text|tei:body|tei:div|tei:ab">
        <xsl:apply-templates/>
    </xsl:template>
       
    <xsl:template match="tei:w">
        <xsl:text>{"text": "</xsl:text>
        <xsl:apply-templates/>
        <xsl:text>", "i": "</xsl:text>
        <xsl:value-of select="@xml:id"/>
        <xsl:text>", "t": "</xsl:text>
        <xsl:value-of select="@lemma"/>
        <xsl:text>", "pos": "</xsl:text>
        <xsl:value-of select="@pos"/>
        <xsl:text>"}</xsl:text>
        <xsl:if test="following::tei:w">
            <xsl:text>, </xsl:text>
        </xsl:if>
    </xsl:template>
    
    
</xsl:stylesheet>
    ''')
    #on applique l'XSL
    monXSL = etree.XSLT(monXSL)
    #on charge le résultat de l'XSL dans la valeur de l'entrée du dicitonnaire "tokens"
    witness['tokens'] = json.loads( '[' +"".join(str(monXSL(xmlInput)).split()) +']')
    return witness

# %%
#le dictionnaire niveau général
json_input = {}
#la première entrée qui contient les witnesses
json_input['witnesses'] = []

# %%
#application de la fonction de transformation sur A puis sur B et on met dans le dictionnaires des témoins
json_input['witnesses'].append(XMLtoJson('A',A1))
json_input['witnesses'].append(XMLtoJson('B',B1))

# %%
#définition de la fonction notre export (comme tout à l'heure)

def notre_export_xml(collation):
    readings = []
    for column in table.columns:
        #création élément app
        app = et.Element('app')
        for key, value in sorted(column.tokens_per_witness.items()):
            child = et.Element('rdg')
            child.attrib['wit'] = "#" + key
            #on créer les attributs pour garder nos valeurs
            for item in value:
                #on ajoute la clé pour chaque id soit unique dans le XML
                child.attrib['xml:id'] = key + "_" + item.token_data["i"]
                child.attrib['lemma']= item.token_data["t"]
                child.attrib['pos'] = item.token_data["pos"]
            child.text = "".join(str(item.token_data["text"]) for item in value)
            app.append(child)
        result = et.tostring(app, encoding="unicode")
        readings.append(result)
    return "".join(readings)

# %%
#collation sur le json créé : un peu long
json_collation = Collation()
#pour chaque témoin dans le json
for witness in json_input["witnesses"]:
#on utilise la fonction add_witness de la classe Collation
    json_collation.add_witness(witness)
    #changement de nom    
    collation = json_collation
    print(collation)
    #on collationne avec une sortie table
    table = collate(collation, output="table",segmentation=False)
    #on utilise la fonction export
    result = notre_export_xml(table)
    #on crée un élément p pour chacune des collations réalisées
    docC = '<ab>' + result + '</ab>'
    #on ajoute à la liste l'ensemble créé
   # listeDesP.append(doc)

# %%
#on vérifique que tout s'est bien passé
table

# %%
#on crée un objet dans lequel on place notre liste, à l'intérieur d'une balise racine <text>
docColl = "<text>" + ''.join(docC) + "</text>"

#on écrit le résultat (une simple chaîne de caractères) dans notre document XML
with open("./sortiesPropreTexte/resultatCollationDepuisTEI.xml", "w") as text_file:
    text_file.write(docColl)

# %%
#on regarde
docColl
# Out:
# '<text><ab><app><rdg lemma="et" pos="CONcoo" wit="#A" xml:id="A_t1">et</rdg><rdg lemma="et" pos="CONcoo" wit="#B" xml:id="B_t1">Et</rdg></app><app><rdg lemma="Hector" pos="NOMcom" wit="#A" xml:id="A_t2">hector</rdg><rdg lemma="Hector" pos="NOMpro" wit="#B" xml:id="B_t2">Hestors</rdg></app><app><rdg lemma="soi1" pos="PROper" wit="#B" xml:id="B_t3">s</rdg></app><app><rdg lemma="en2" pos="PROadv" wit="#B" xml:id="B_t4">an</rdg></app><app><rdg lemma="revenir" pos="VERcjg" wit="#B" xml:id="B_t5">revient</rdg></app><app><rdg lemma="par" pos="PRE" wit="#B" xml:id="B_t6">par</rdg></app><app><rdg lemma="il" pos="PROper" wit="#B" xml:id="B_t7">lui</rdg></app><app><rdg lemma="qui" pos="PROrel" wit="#A" xml:id="A_t3">qui</rdg><rdg lemma="qui" pos="PROrel" wit="#B" xml:id="B_t8">qui</rdg></app><app><rdg lemma="avoir" pos="VERcjg" wit="#A" xml:id="A_t4">avoit</rdg><rdg lemma="avoir" pos="VERcjg" wit="#B" xml:id="B_t9">ot</rdg></app><app><rdg lemma="laissier" pos="VERppe" wit="#A" xml:id="A_t5">lai
# ...

# %%
#on va récupérer le document XML qu'on a créé sur les occurrences
docLAsList = []
#pour que l'élément soit du str, donc écrivable
r = et.tostring(documentL, encoding="unicode")
docLAsList.append(r)
#on regarde
docLAsList
# Out:
# ['<donneesL><mot><lemme>il</lemme><occA>94</occA><occB>135</occB></mot><mot><lemme>le</lemme><occA>58</occA><occB>65</occB></mot><mot><lemme>et</lemme><occA>53</occA><occB>85</occB></mot><mot><lemme>que4</lemme><occA>43</occA><occB>49</occB></mot><mot><lemme>faire</lemme><occA>37</occA><occB>34</occB></mot><mot><lemme>ne1</lemme><occA>36</occA><occB>41</occB></mot><mot><lemme>vos</lemme><occA>36</occA><occB>35</occB></mot><mot><lemme>de</lemme><occA>34</occA><occB>37</occB></mot><mot><lemme>estre1</lemme><occA>30</occA><occB>34</occB></mot><mot><lemme>Hector</lemme><occA>27</occA><occB>26</occB></mot><mot><lemme>avoir</lemme><occA>25</occA><occB>32</occB></mot><mot><lemme>a3</lemme><occA>23</occA><occB>23</occB></mot><mot><lemme>je</lemme><occA>20</occA><occB>23</occB></mot><mot><lemme>se</lemme><occA>19</occA><occB>18</occB></mot><mot><lemme>son4</lemme><occA>18</occA><occB>20</occB></mot><mot><lemme>soi1</lemme><occA>17</occA><occB>20</occB></mot><mot><lemme>Marganor</lemme><occA>1
# ...

# %%
#on créé un document complet, contenant les données sur les lexèmes et le résultat de la collation
docComplet = "<document>" + ''.join(docLAsList) +  "\n<text>" + ''.join(docC) + "</text>\n</document>"

# %%
#on regarde
docComplet
# Out:
# '<document><donneesL><mot><lemme>il</lemme><occA>135</occA><occB>94</occB></mot><mot><lemme>et</lemme><occA>85</occA><occB>53</occB></mot><mot><lemme>le</lemme><occA>65</occA><occB>58</occB></mot><mot><lemme>que4</lemme><occA>49</occA><occB>43</occB></mot><mot><lemme>ne1</lemme><occA>41</occA><occB>36</occB></mot><mot><lemme>de</lemme><occA>37</occA><occB>34</occB></mot><mot><lemme>vos</lemme><occA>35</occA><occB>36</occB></mot><mot><lemme>estre1</lemme><occA>34</occA><occB>30</occB></mot><mot><lemme>faire</lemme><occA>34</occA><occB>37</occB></mot><mot><lemme>avoir</lemme><occA>32</occA><occB>25</occB></mot><mot><lemme>si</lemme><occA>29</occA><occB>16</occB></mot><mot><lemme>Hector</lemme><occA>26</occA><occB>27</occB></mot><mot><lemme>en2</lemme><occA>25</occA><occB>12</occB></mot><mot><lemme>a3</lemme><occA>23</occA><occB>23</occB></mot><mot><lemme>je</lemme><occA>23</occA><occB>20</occB></mot><mot><lemme>dire</lemme><occA>21</occA><occB>15</occB></mot><mot><lemme>soi1</lemme><oc
# ...

# %%
#on écrit le doc Complet
with open("./sortiesPropreTexte/collationEtComptes.xml", "w") as text_file:
    text_file.write(docComplet)

# %%
#on importe le doc complet (pour que ça fonctionne bien)
docCompletImport = etree.parse('sortiesPropreTexte/collationEtComptes.xml')
docCompletImport
#on vérifie
docCompletImport.xpath('/document/donneesL')
# Out:
# [<Element donneesL at 0x7fd9d8d11e48>]

# %%
#définition de l'XSL qui va faire passer le document XML complet aux fiches
monXSL = etree.XML('''
<xsl:stylesheet version="1.0" xmlns:xsl="http://www.w3.org/1999/XSL/Transform"  exclude-result-prefixes="xsl">
    
    <!-- génération de la sortie -->
    <xsl:output method="xml" version="1.0" indent="yes" omit-xml-declaration="no" encoding="UTF-8"/>
    <xsl:strip-space elements="*"/>
      
    
    <xsl:template match="document">
        <xsl:element name="fiches">
        <xsl:apply-templates/>
        </xsl:element>
    </xsl:template>
    
<!-- on garde que les lexèmes intéressants -->    
    <xsl:template match="mot">
        <xsl:if test="child::occB=0">
            <xsl:apply-templates select="lemme"/>
        </xsl:if>
    </xsl:template>
    
    <!-- règle sur les éléments -->

    <xsl:template match="lemme">
        <!-- on stocke la valeur de chaque mot dans une variable -->
        <xsl:variable name="mot">
            <xsl:value-of select="."/>            
        </xsl:variable>
        <xsl:if test="node() = $mot">
            <xsl:element name="fiche">
                <xsl:attribute name="xml:id">
                    <xsl:value-of select="$mot"/>
                </xsl:attribute>
                <xsl:element name="lemme">
                    <xsl:value-of select="$mot"/>
                </xsl:element>
                <xsl:element name="freqA">
                    <xsl:value-of select="parent::mot/occA"/>
                </xsl:element>
                <xsl:element name="freqB">
                    <xsl:value-of select="parent::mot/occB"/>
                </xsl:element>
                <xsl:element name="definition"></xsl:element>
                <xsl:element name="datePremAtt"></xsl:element>
                <xsl:element name="dateDernAtt"></xsl:element>
                <xsl:element name="source">
                    <!-- valeur par défaut -->
                    <xsl:text>Mats</xsl:text>
                </xsl:element>
                <xsl:element name="corrLemm">
                    <!-- valeur par défaut -->
                    <xsl:text>-</xsl:text>
                </xsl:element>
                <xsl:element name="etymon"></xsl:element>
                
                <!-- pour chacune des occurrences du mot -->
                   <xsl:for-each
                       select="ancestor::document/text/ab/app[descendant::rdg/@lemma = $mot]">
                       <xsl:variable name="num">
                           <xsl:variable name="numRdg">
                               <xsl:number count="rdg[@lemma = $mot]" level="any" format="000"/>
                           </xsl:variable>
                           <xsl:value-of select="concat($mot, '-', $numRdg)"/>
                       </xsl:variable>
                    
                    <xsl:element name="contexte">
                        <!-- on prend l'identifiant de la div pour le mettre dans un att-->
                        
                        <xsl:attribute name="xml:id">
                            <xsl:value-of select="$num"/>
                        </xsl:attribute>
         
                        <!-- on donne le contexte de A -->
                        
                        <xsl:element name="contexteA">
                            
                            <!-- on prend l'id du mot en A -->
                                    <xsl:attribute name="ref">
                                        <xsl:text>#</xsl:text>
                                        <xsl:value-of select="descendant::rdg[@wit = '#A']/@xml:id"/>
                                    </xsl:attribute>
                            
                            <!-- on obtient le contexte qui précède -->
                            <xsl:value-of
                                select="concat(preceding::app[20]/rdg[@wit = '#A'], ' ', preceding::app[19]/rdg[@wit = '#A'], ' ', preceding::app[18]/rdg[@wit = '#A'], ' ', preceding::app[17]/rdg[@wit = '#A'], ' ', preceding::app[16]/rdg[@wit = '#A'], ' ', preceding::app[15]/rdg[@wit = '#A'], ' ', preceding::app[14]/rdg[@wit = '#A'], ' ', preceding::app[13]/rdg[@wit = '#A'], ' ', preceding::app[12]/rdg[@wit = '#A'], ' ', preceding::app[11]/rdg[@wit = '#A'], ' ', preceding::app[10]/rdg[@wit = '#A'], ' ', preceding::app[9]/rdg[@wit = '#A'], ' ', preceding::app[8]/rdg[@wit = '#A'], ' ', preceding::app[7]/rdg[@wit = '#A'], ' ', preceding::app[6]/rdg[@wit = '#A'], ' ', preceding::app[5]/rdg[@wit = '#A'], ' ', preceding::app[4]/rdg[@wit = '#A'], ' ', preceding::app[3]/rdg[@wit = '#A'], ' ', preceding::app[2]/rdg[@wit = '#A'], ' ', preceding::app[1]/rdg[@wit = '#A'])"/>
                            <xsl:text> </xsl:text>
                            <!-- on écrit la forme du lexème concerné -->
                                    <xsl:element name="bold">
                                        <xsl:apply-templates select="child::rdg[@wit = '#A']"/>
                                        
                                    </xsl:element>
                                    <xsl:text> </xsl:text>

                            <!-- on obtient le contexte qui suit -->
                            <xsl:value-of
                                select="concat(following::app[1]/rdg[@wit = '#A'], ' ', following::app[2]/rdg[@wit = '#A'], ' ', following::app[3]/rdg[@wit = '#A'], ' ', following::app[4]/rdg[@wit = '#A'], ' ', following::app[5]/rdg[@wit = '#A'], ' ', following::app[6]/rdg[@wit = '#A'], ' ', following::app[7]/rdg[@wit = '#A'], ' ', following::app[8]/rdg[@wit = '#A'], ' ', following::app[9]/rdg[@wit = '#A'], ' ', following::app[10]/rdg[@wit = '#A'],  ' ', following::app[11]/rdg[@wit = '#A'],  ' ', following::app[12]/rdg[@wit = '#A'],  ' ', following::app[13]/rdg[@wit = '#A'],  ' ', following::app[14]/rdg[@wit = '#A'],  ' ', following::app[15]/rdg[@wit = '#A'],  ' ', following::app[16]/rdg[@wit = '#A'],  ' ', following::app[17]/rdg[@wit = '#A'],  ' ', following::app[18]/rdg[@wit = '#A'],  ' ', following::app[19]/rdg[@wit = '#A'],  ' ', following::app[20]/rdg[@wit = '#A'])"/>   
                        </xsl:element>
                        
                        <!-- on donne le contexte de B -->
                        
                        <xsl:element name="contexteB">
                            <!-- on prend l'id du mot en B -->

                                    <xsl:attribute name="ref">
                                        <xsl:text>#</xsl:text>
                                        <xsl:value-of select="child::rdg[@wit = '#B']/@xml:id"/>
                                    </xsl:attribute>                           
                            
                            <!-- on prend le contexte qui précède -->
                            <xsl:value-of
                                select="concat(preceding::app[20]/rdg[@wit = '#B'], ' ',preceding::app[19]/rdg[@wit = '#B'], ' ',preceding::app[18]/rdg[@wit = '#B'], ' ',preceding::app[17]/rdg[@wit = '#B'], ' ',preceding::app[16]/rdg[@wit = '#B'], ' ',preceding::app[15]/rdg[@wit = '#B'], ' ',preceding::app[14]/rdg[@wit = '#B'], ' ',preceding::app[13]/rdg[@wit = '#B'], ' ',preceding::app[12]/rdg[@wit = '#B'], ' ',preceding::app[11]/rdg[@wit = '#B'], ' ',preceding::app[10]/rdg[@wit = '#B'], ' ', preceding::app[9]/rdg[@wit = '#B'], ' ', preceding::app[8]/rdg[@wit = '#B'], ' ', preceding::app[7]/rdg[@wit = '#B'], ' ', preceding::app[6]/rdg[@wit = '#B'], ' ', preceding::app[5]/rdg[@wit = '#B'], ' ', preceding::app[4]/rdg[@wit = '#B'], ' ', preceding::app[3]/rdg[@wit = '#B'], ' ', preceding::app[2]/rdg[@wit = '#B'], ' ', preceding::app[1]/rdg[@wit = '#B'])"/>
                            
                            <xsl:text> </xsl:text>
                            <!-- on écrit la forme du lexème concerné -->
                                   <xsl:element name="bold"> 
                                       <xsl:apply-templates select="child::rdg[@wit = '#B']"/>
                                   </xsl:element>
                                    <xsl:text> </xsl:text>

                            <xsl:text> </xsl:text>
                            <!-- on obtient le contexte qui suit -->
                            <xsl:value-of
                                select="concat(following::app[1]/rdg[@wit = '#B'], ' ', following::app[2]/rdg[@wit = '#B'], ' ', following::app[3]/rdg[@wit = '#B'], ' ', following::app[4]/rdg[@wit = '#B'], ' ', following::app[5]/rdg[@wit = '#B'], ' ', following::app[6]/rdg[@wit = '#B'], ' ', following::app[7]/rdg[@wit = '#B'], ' ', following::app[8]/rdg[@wit = '#B'], ' ', following::app[9]/rdg[@wit = '#B'], ' ', following::app[10]/rdg[@wit = '#B'], ' ', following::app[11]/rdg[@wit = '#B'], ' ', following::app[12]/rdg[@wit = '#B'], ' ', following::app[13]/rdg[@wit = '#B'], ' ', following::app[14]/rdg[@wit = '#B'], ' ', following::app[15]/rdg[@wit = '#B'], ' ', following::app[16]/rdg[@wit = '#B'], ' ', following::app[17]/rdg[@wit = '#B'], ' ', following::app[18]/rdg[@wit = '#B'], ' ', following::app[19]/rdg[@wit = '#B'], ' ', following::app[20]/rdg[@wit = '#B'])"/>
                            
                            </xsl:element>
              
                    </xsl:element>                   
                </xsl:for-each>
                
                <xsl:element name="note"></xsl:element>
              
            </xsl:element>

        </xsl:if>
    </xsl:template>
                   
</xsl:stylesheet>
''')

# %%
#on enregistre l'xsl
monXSLVersFiches = etree.XSLT(monXSL)

# %%
#on applique l'XSL sur le document complet
monXSLVersFiches(docCompletImport)

# %%
#on enregistre le résultat dans une variable
xmlSortie = monXSLVersFiches(docCompletImport)

# %%
#on produit en version texte le résultat
etree.tostring(xmlSortie,encoding="unicode")
# Out:
# '<fiches><fiche xml:id="prometre"><lemme>prometre</lemme><freqA>8</freqA><freqB>0</freqB><definition/><datePremAtt/><dateDernAtt/><source>Mats</source><corrLemm>-</corrLemm><etymon/><contexte xml:id="prometre-0"><contexteA ref="#A_t356">je ja tant que je vive et que je me puisse deffendre Si serez fait marganor car je lui ay <bold>promis</bold> Puis que vous le voullez fait le chevalier ce ne m est pas honte de vostre voulente  car vous</contexteA><contexteB ref="#B_t402">ge ja tant com     ge me puisse deffandre Si seroiz dist Marganorz car ge l ai <bold>plevi</bold>  Puis que vos lo volez fait li chevaliers il ne m est mies honte de vostre volanté otroier car vos</contexteB></contexte><contexte xml:id="prometre-1"><contexteA ref="#A_t428"> lui met sus qu  il a  ses hommes occis en temps de treves et qu il avoit <bold>promis</bold> qu ilz n avoient garde de lui   Hector  dit qu il ne le promist oncques et quant</contexteA><contexteB ref="#B_t502">cil li met sus que il li a navré ses
# ...

# %%
#on enregistre dans un objet, et on écrit le fichier !
resultatFiches = etree.tostring(xmlSortie,encoding="unicode")
type(resultatFiches)
with open("sortiesPropreTexte/resultatFiches.xml", "w") as text_file:
    text_file.write(resultatFiches)
